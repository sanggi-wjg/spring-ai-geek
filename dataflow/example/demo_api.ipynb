# %%
import os

import requests
import xmltodict
from dotenv import load_dotenv

load_dotenv()

SERVICE_KEY = os.getenv("DATA_GO_KR_SERVICE_KEY")
query_param = {
    "serviceKey": SERVICE_KEY,
    "strtYymm": "201601",
    "endYymm": "201601",
    # "hsSgn": "1001999090",
    "cntyCd": "US",
}
response = requests.get("http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList", params=query_param)
response.raise_for_status()

data = xmltodict.parse(response.content)

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '1709825452',
#       'expDlr': '5027618286',
#       'expWgt': '1241496326',
#       'hsCd': '-',
#       'impDlr': '3317792834',
#       'impWgt': '1509874932',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '-579245',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0101211000',
#       'impDlr': '579245',
#       'impWgt': '5000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '농가 사육용',
#       'year': '2016.01'},
#      {'balPayments': '-519540',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0101219000',
#       'impDlr': '519540',
#       'impWgt': '3050',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-1263787',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0105111000',
#       'impDlr': '1263787',
#       'impWgt': '1431',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '번식용',
#       'year': '2016.01'},
#      {'balPayments': '18072',
#       'expDlr': '21179',
#       'expWgt': '889',
#       'hsCd': '0106191000',
#       'impDlr': '3107',
#       'impWgt': '116',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개',
#       'year': '2016.01'},
#      {'balPayments': '-257562',
#       'expDlr': '717',
#       'expWgt': '33',
#       'hsCd': '0106199000',
#       'impDlr': '258279',
#       'impWgt': '420',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-11274',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106201000',
#       'impDlr': '11274',
#       'impWgt': '27',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뱀',
#       'year': '2016.01'},
#      {'balPayments': '-70723',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106203000',
#       'impDlr': '70723',
#       'impWgt': '102',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '거북',
#       'year': '2016.01'},
#      {'balPayments': '-8047',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106209000',
#       'impDlr': '8047',
#       'impWgt': '11',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-874',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106490000',
#       'impDlr': '874',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-5947',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106901000',
#       'impDlr': '5947',
#       'impWgt': '15',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '양서류',
#       'year': '2016.01'},
#      {'balPayments': '-449',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106903090',
#       'impDlr': '449',
#       'impWgt': '19',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-3473005',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201201000',
#       'impDlr': '3473005',
#       'impWgt': '564215',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈비',
#       'year': '2016.01'},
#      {'balPayments': '-117705',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201209000',
#       'impDlr': '117705',
#       'impWgt': '5941',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-13982729',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201300000',
#       'impDlr': '13982729',
#       'impWgt': '1496969',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2016.01'},
#      {'balPayments': '-52845450',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202201000',
#       'impDlr': '52845450',
#       'impWgt': '8785565',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈비',
#       'year': '2016.01'},
#      {'balPayments': '-589591',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202209000',
#       'impDlr': '589591',
#       'impWgt': '200644',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-40168250',
#       'expDlr': '150822',
#       'expWgt': '18003',
#       'hsCd': '0202300000',
#       'impDlr': '40319072',
#       'impWgt': '5823625',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2016.01'},
#      {'balPayments': '-1096781',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203191000',
#       'impDlr': '1096781',
#       'impWgt': '194529',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2016.01'},
#      {'balPayments': '-553470',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203199000',
#       'impDlr': '553470',
#       'impWgt': '101702',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-279936',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203291000',
#       'impDlr': '279936',
#       'impWgt': '73650',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2016.01'},
#      {'balPayments': '-45599066',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203299000',
#       'impDlr': '45599066',
#       'impWgt': '18170229',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-1619386',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206100000',
#       'impDlr': '1619386',
#       'impWgt': '168126',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 것(신선한 것이나 냉장한 것으로 한정한다)',
#       'year': '2016.01'},
#      {'balPayments': '-39072',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206291000',
#       'impDlr': '39072',
#       'impWgt': '5291',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꼬리',
#       'year': '2016.01'},
#      {'balPayments': '-575508',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206292000',
#       'impDlr': '575508',
#       'impWgt': '308180',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '족',
#       'year': '2016.01'},
#      {'balPayments': '-5731101',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206299000',
#       'impDlr': '5731101',
#       'impWgt': '968467',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-72647',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206491000',
#       'impDlr': '72647',
#       'impWgt': '44398',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '족',
#       'year': '2016.01'},
#      {'balPayments': '-957478',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206499000',
#       'impDlr': '957478',
#       'impWgt': '357702',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-836',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141010',
#       'impDlr': '836',
#       'impWgt': '64',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '다리',
#       'year': '2016.01'},
#      {'balPayments': '-37',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0208909090',
#       'impDlr': '37',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-124951',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0209100000',
#       'impDlr': '124951',
#       'impWgt': '115723',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '돼지의 것',
#       'year': '2016.01'},
#      {'balPayments': '-1038139',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210120000',
#       'impDlr': '1038139',
#       'impWgt': '148773',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '복부살(삼겹살)과 이를 절단한 것',
#       'year': '2016.01'},
#      {'balPayments': '-3579',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210190000',
#       'impDlr': '3579',
#       'impWgt': '71',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-17152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301190000',
#       'impDlr': '17152',
#       'impWgt': '34',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '608',
#       'expDlr': '608',
#       'expWgt': '18',
#       'hsCd': '0301995000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2016.01'},
#      {'balPayments': '-863352',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301997000',
#       'impDlr': '863352',
#       'impWgt': '95924',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '먹장어',
#       'year': '2016.01'},
#      {'balPayments': '841785',
#       'expDlr': '841785',
#       'expWgt': '37456',
#       'hsCd': '0301998000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '넙치류[플루로넥티대(Pleuronectidae)과ㆍ바디대(Bothidae)과ㆍ사이노글로시대(Cynoglossidae)과ㆍ솔레이대(Soleidae)과ㆍ스코프탈미대(Scophthalmidae)과ㆍ시타리대(Citharidae)과]',
#       'year': '2016.01'},
#      {'balPayments': '2507',
#       'expDlr': '2507',
#       'expWgt': '104',
#       'hsCd': '0301999040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '볼락(적어를 포함한다)',
#       'year': '2016.01'},
#      {'balPayments': '6016',
#       'expDlr': '6016',
#       'expWgt': '364',
#       'hsCd': '0301999070',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '미꾸라지',
#       'year': '2016.01'},
#      {'balPayments': '224',
#       'expDlr': '224',
#       'expWgt': '5',
#       'hsCd': '0301999099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-16616',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302190000',
#       'impDlr': '16616',
#       'impWgt': '1414',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '217920',
#       'expDlr': '217920',
#       'expWgt': '11859',
#       'hsCd': '0302210000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '넙치[레인하드티우스 히포글러소이데스(Reinhardtius hippoglossoides)ㆍ히포글러서스 히포글러서스(Hippoglossus hippoglossus)ㆍ히포글러서스 스테노레피스(Hippoglossus stenolepis)]',
#       'year': '2016.01'},
#      {'balPayments': '66119',
#       'expDlr': '66119',
#       'expWgt': '2460',
#       'hsCd': '0302240000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '터벗(turbots)[프세타 맥시마(Psetta maxima)]',
#       'year': '2016.01'},
#      {'balPayments': '23696',
#       'expDlr': '23696',
#       'expWgt': '1655',
#       'hsCd': '0302290000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '0',
#       'expDlr': '0',
#       'expWgt': '1',
#       'hsCd': '0302440000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어[스콤버 스콤브루스(Scomber scombrus)ㆍ스콤버 오스트랄라시쿠스(Scomber australasicus)ㆍ스콤버 자포니쿠스(Scomber japonicus)]',
#       'year': '2016.01'},
#      {'balPayments': '-295',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302510000',
#       'impDlr': '295',
#       'impWgt': '21',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2016.01'},
#      {'balPayments': '1927',
#       'expDlr': '1927',
#       'expWgt': '70',
#       'hsCd': '0302820000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가오리와 홍어[라지대(Rajidae)과]',
#       'year': '2016.01'},
#      {'balPayments': '3406',
#       'expDlr': '3406',
#       'expWgt': '115',
#       'hsCd': '0302892000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2016.01'},
#      {'balPayments': '1795',
#       'expDlr': '1795',
#       'expWgt': '49',
#       'hsCd': '0302893000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2016.01'},
#      {'balPayments': '4424',
#       'expDlr': '4424',
#       'expWgt': '227',
#       'hsCd': '0302896000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '돔[스파리대(Sparidae)과는 제외한다]',
#       'year': '2016.01'},
#      {'balPayments': '384',
#       'expDlr': '384',
#       'expWgt': '10',
#       'hsCd': '0302899030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '병어',
#       'year': '2016.01'},
#      {'balPayments': '6158',
#       'expDlr': '6158',
#       'expWgt': '458',
#       'hsCd': '0302899090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-613',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303110000',
#       'impDlr': '613',
#       'impWgt': '360',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소크아이 연어[홍연어(red salmon)][옹코링쿠스 넬카(Oncorhynchus nerka)]',
#       'year': '2016.01'},
#      {'balPayments': '-684612',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303120000',
#       'impDlr': '684612',
#       'impWgt': '284744',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 태평양 연어[옹코링쿠스 고르부스카(Oncorhynchus gorbuscha)ㆍ옹코링쿠스 케타(Oncorhynchus keta)ㆍ옹코링쿠스 차비차(Oncorhynchus tschawytscha)ㆍ옹코링쿠스 키수츠(Oncorhynchus kisutch)ㆍ옹코링쿠스 마소(Oncorhynchus masou)ㆍ옹코링쿠스 로두루스(Oncorhynchus rhodurus)]',
#       'year': '2016.01'},
#      {'balPayments': '-48740',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303320000',
#       'impDlr': '48740',
#       'impWgt': '23000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미[플루로넥테스 플라테사(Pleuronectes platessa)]',
#       'year': '2016.01'},
#      {'balPayments': '-4637865',
#       'expDlr': '3400',
#       'expWgt': '815',
#       'hsCd': '0303390000',
#       'impDlr': '4641265',
#       'impWgt': '3307128',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '512',
#       'expDlr': '660',
#       'expWgt': '60',
#       'hsCd': '0303490000',
#       'impDlr': '148',
#       'impWgt': '27',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '17450',
#       'expDlr': '17450',
#       'expWgt': '11000',
#       'hsCd': '0303510000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '청어[클루페아 하렌구스(Clupea harengus)ㆍ클루페아 팔라시(Clupea pallasii)]',
#       'year': '2016.01'},
#      {'balPayments': '1170',
#       'expDlr': '1170',
#       'expWgt': '1000',
#       'hsCd': '0303550000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전갱이[트라커러스(Trachurus)속]',
#       'year': '2016.01'},
#      {'balPayments': '-1433413',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303630000',
#       'impDlr': '1433413',
#       'impWgt': '510295',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2016.01'},
#      {'balPayments': '-35625',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303650000',
#       'impDlr': '35625',
#       'impWgt': '2155',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '검정대구[폴라치우스 비렌스(Pollachius virens)]',
#       'year': '2016.01'},
#      {'balPayments': '-486949',
#       'expDlr': '66774',
#       'expWgt': '16065',
#       'hsCd': '0303670000',
#       'impDlr': '553723',
#       'impWgt': '382290',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태[테라그라 찰코그라마(Theragra chalcogramma)]',
#       'year': '2016.01'},
#      {'balPayments': '-22399',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303810000',
#       'impDlr': '22399',
#       'impWgt': '17230',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '곱상어와 그 밖의 상어',
#       'year': '2016.01'},
#      {'balPayments': '-521498',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303821000',
#       'impDlr': '521498',
#       'impWgt': '256487',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가오리',
#       'year': '2016.01'},
#      {'balPayments': '-735941',
#       'expDlr': '67',
#       'expWgt': '10',
#       'hsCd': '0303822000',
#       'impDlr': '736008',
#       'impWgt': '101661',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '홍어',
#       'year': '2016.01'},
#      {'balPayments': '2071008',
#       'expDlr': '2071008',
#       'expWgt': '81083',
#       'hsCd': '0303830000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '이빨고기[디소스티쿠스(Dissostichus)속]',
#       'year': '2016.01'},
#      {'balPayments': '-191859',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303891000',
#       'impDlr': '191859',
#       'impWgt': '10932',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '은대구',
#       'year': '2016.01'},
#      {'balPayments': '41754',
#       'expDlr': '41754',
#       'expWgt': '9902',
#       'hsCd': '0303892000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2016.01'},
#      {'balPayments': '1903',
#       'expDlr': '1903',
#       'expWgt': '245',
#       'hsCd': '0303895000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기',
#       'year': '2016.01'},
#      {'balPayments': '20572',
#       'expDlr': '20572',
#       'expWgt': '10537',
#       'hsCd': '0303896000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '학꽁치(Hyporhampus sajori)',
#       'year': '2016.01'},
#      {'balPayments': '-388004',
#       'expDlr': '1283',
#       'expWgt': '360',
#       'hsCd': '0303899040',
#       'impDlr': '389287',
#       'impWgt': '146500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '임연수어',
#       'year': '2016.01'},
#      {'balPayments': '-292851',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303899050',
#       'impDlr': '292851',
#       'impWgt': '177254',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '볼낙(적어를 포함한다)',
#       'year': '2016.01'},
#      {'balPayments': '-428373',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303899060',
#       'impDlr': '428373',
#       'impWgt': '83940',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아귀',
#       'year': '2016.01'},
#      {'balPayments': '-428169',
#       'expDlr': '1807',
#       'expWgt': '154',
#       'hsCd': '0303899070',
#       'impDlr': '429976',
#       'impWgt': '141002',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '먹장어(대서양 또는 태평양)',
#       'year': '2016.01'},
#      {'balPayments': '21335',
#       'expDlr': '21335',
#       'expWgt': '3802',
#       'hsCd': '0303899091',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '민어',
#       'year': '2016.01'},
#      {'balPayments': '27237',
#       'expDlr': '27237',
#       'expWgt': '14775',
#       'hsCd': '0303899099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-123',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303901000',
#       'impDlr': '123',
#       'impWgt': '72',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '간',
#       'year': '2016.01'},
#      {'balPayments': '-878067',
#       'expDlr': '84',
#       'expWgt': '8',
#       'hsCd': '0303902010',
#       'impDlr': '878151',
#       'impWgt': '251951',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명란',
#       'year': '2016.01'},
#      {'balPayments': '-208281',
#       'expDlr': '12809',
#       'expWgt': '1190',
#       'hsCd': '0303902090',
#       'impDlr': '221090',
#       'impWgt': '105516',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '14634',
#       'expDlr': '14634',
#       'expWgt': '500',
#       'hsCd': '0304431000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미',
#       'year': '2016.01'},
#      {'balPayments': '-309',
#       'expDlr': '732',
#       'expWgt': '30',
#       'hsCd': '0304439000',
#       'impDlr': '1041',
#       'impWgt': '23',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '4681',
#       'expDlr': '4681',
#       'expWgt': '176',
#       'hsCd': '0304491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2016.01'},
#      {'balPayments': '-225552',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304710000',
#       'impDlr': '225552',
#       'impWgt': '37267',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2016.01'},
#      {'balPayments': '-213755',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304750000',
#       'impDlr': '213755',
#       'impWgt': '73772',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태[테라그라 찰코그라마(Theragra chalcogramma)]',
#       'year': '2016.01'},
#      {'balPayments': '-130970',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304810000',
#       'impDlr': '130970',
#       'impWgt': '16624',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '태평양 연어[옹코링쿠스 넬카(Oncorhynchus nerka)ㆍ옹코링쿠스 고르부스카(Oncorhynchus gorbuscha)ㆍ옹코링쿠스 케타(Oncorhynchus keta)ㆍ옹코링쿠스 차비차(Oncorhynchus tschawytscha)ㆍ옹코링쿠스 키수츠(Oncorhynchus kisutch)ㆍ옹코링쿠스 마소(Oncorhynchus masou)ㆍ옹코링쿠스 로두루스(Oncorhynchus rhodurus)], 대서양 연어[살모 살라(Salmo salar)], 다뉴브 연어[후코 후코(Hucho hucho)]',
#       'year': '2016.01'},
#      {'balPayments': '-150842',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304831000',
#       'impDlr': '150842',
#       'impWgt': '49678',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미',
#       'year': '2016.01'},
#      {'balPayments': '271827',
#       'expDlr': '271827',
#       'expWgt': '18147',
#       'hsCd': '0304879000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '967705',
#       'expDlr': '967705',
#       'expWgt': '78054',
#       'hsCd': '0304899000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-2977027',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304941000',
#       'impDlr': '2977027',
#       'impWgt': '1024820',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동 연육',
#       'year': '2016.01'},
#      {'balPayments': '-22620',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304991000',
#       'impDlr': '22620',
#       'impWgt': '22620',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동 연육',
#       'year': '2016.01'},
#      {'balPayments': '1846',
#       'expDlr': '1862',
#       'expWgt': '110',
#       'hsCd': '0305100000',
#       'impDlr': '16',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '어류의 고운 가루ㆍ거친 가루와 펠릿(pellet)(식용에 적합한 것으로 한정한다)',
#       'year': '2016.01'},
#      {'balPayments': '9106',
#       'expDlr': '9106',
#       'expWgt': '385',
#       'hsCd': '0305204010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태의 것',
#       'year': '2016.01'},
#      {'balPayments': '492170',
#       'expDlr': '533780',
#       'expWgt': '60511',
#       'hsCd': '0305592000',
#       'impDlr': '41610',
#       'impWgt': '2520',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치',
#       'year': '2016.01'},
#      {'balPayments': '134203',
#       'expDlr': '134203',
#       'expWgt': '12036',
#       'hsCd': '0305593000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태(북어)',
#       'year': '2016.01'},
#      {'balPayments': '17387',
#       'expDlr': '17387',
#       'expWgt': '1550',
#       'hsCd': '0305594000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기(굴비)',
#       'year': '2016.01'},
#      {'balPayments': '-3168',
#       'expDlr': '8232',
#       'expWgt': '211',
#       'hsCd': '0305599000',
#       'impDlr': '11400',
#       'impWgt': '140',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '2148',
#       'expDlr': '2148',
#       'expWgt': '1686',
#       'hsCd': '0305631000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치젓',
#       'year': '2016.01'},
#      {'balPayments': '8137',
#       'expDlr': '8137',
#       'expWgt': '975',
#       'hsCd': '0305693000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2016.01'},
#      {'balPayments': '-46',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305694000',
#       'impDlr': '46',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '정어리',
#       'year': '2016.01'},
#      {'balPayments': '26186',
#       'expDlr': '26186',
#       'expWgt': '5749',
#       'hsCd': '0305695000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어',
#       'year': '2016.01'},
#      {'balPayments': '184251',
#       'expDlr': '184251',
#       'expWgt': '27587',
#       'hsCd': '0305699000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-620102',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306129000',
#       'impDlr': '620102',
#       'impWgt': '15946',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-18',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306141011',
#       'impDlr': '18',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '밀폐용기에 넣은 것',
#       'year': '2016.01'},
#      {'balPayments': '-11740',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306142090',
#       'impDlr': '11740',
#       'impWgt': '68',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '5862',
#       'expDlr': '5862',
#       'expWgt': '200',
#       'hsCd': '0306143090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-5789',
#       'expDlr': '330',
#       'expWgt': '20',
#       'hsCd': '0306149090',
#       'impDlr': '6119',
#       'impWgt': '500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-180',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306169090',
#       'impDlr': '180',
#       'impWgt': '9',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-8126',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306219000',
#       'impDlr': '8126',
#       'impWgt': '182',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-3002380',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306229000',
#       'impDlr': '3002380',
#       'impWgt': '159453',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-8303',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306241020',
#       'impDlr': '8303',
#       'impWgt': '392',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대게',
#       'year': '2016.01'},
#      {'balPayments': '590068',
#       'expDlr': '613390',
#       'expWgt': '15380',
#       'hsCd': '0306241090',
#       'impDlr': '23322',
#       'impWgt': '897',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '76168',
#       'expDlr': '76188',
#       'expWgt': '3949',
#       'hsCd': '0306272000',
#       'impDlr': '20',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2016.01'},
#      {'balPayments': '43304',
#       'expDlr': '43304',
#       'expWgt': '8900',
#       'hsCd': '0306273000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2016.01'},
#      {'balPayments': '987',
#       'expDlr': '987',
#       'expWgt': '50',
#       'hsCd': '0306292000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2016.01'},
#      {'balPayments': '14088',
#       'expDlr': '14088',
#       'expWgt': '1368',
#       'hsCd': '0306293000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2016.01'},
#      {'balPayments': '-4018',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307291000',
#       'impDlr': '4018',
#       'impWgt': '109',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '펙텐(Pecten)ㆍ클라미스(Chlamys)ㆍ플라코펙텐(Placopecten)속의 것',
#       'year': '2016.01'},
#      {'balPayments': '7540',
#       'expDlr': '7540',
#       'expWgt': '760',
#       'hsCd': '0307293000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2016.01'},
#      {'balPayments': '1010',
#       'expDlr': '1010',
#       'expWgt': '117',
#       'hsCd': '0307412000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오징어',
#       'year': '2016.01'},
#      {'balPayments': '1437164',
#       'expDlr': '1437164',
#       'expWgt': '1122127',
#       'hsCd': '0307491020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오징어',
#       'year': '2016.01'},
#      {'balPayments': '216565',
#       'expDlr': '216603',
#       'expWgt': '22519',
#       'hsCd': '0307493000',
#       'impDlr': '38',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2016.01'},
#      {'balPayments': '52304',
#       'expDlr': '52304',
#       'expWgt': '2204',
#       'hsCd': '0307511000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '낙지',
#       'year': '2016.01'},
#      {'balPayments': '11690',
#       'expDlr': '11690',
#       'expWgt': '357',
#       'hsCd': '0307519000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-3584',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307591010',
#       'impDlr': '3584',
#       'impWgt': '1024',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '문어',
#       'year': '2016.01'},
#      {'balPayments': '51474',
#       'expDlr': '51474',
#       'expWgt': '8179',
#       'hsCd': '0307592000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2016.01'},
#      {'balPayments': '22714',
#       'expDlr': '22714',
#       'expWgt': '590',
#       'hsCd': '0307810000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아있거나, 신선하거나 냉장한 전복[할리오티스(Haliotis)속]',
#       'year': '2016.01'},
#      {'balPayments': '935',
#       'expDlr': '935',
#       'expWgt': '50',
#       'hsCd': '0307911000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소라',
#       'year': '2016.01'},
#      {'balPayments': '-3744',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307913000',
#       'impDlr': '3744',
#       'impWgt': '40',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조개관자',
#       'year': '2016.01'},
#      {'balPayments': '17239',
#       'expDlr': '17239',
#       'expWgt': '1322',
#       'hsCd': '0307919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-41565',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307991100',
#       'impDlr': '41565',
#       'impWgt': '1475',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개아지살',
#       'year': '2016.01'},
#      {'balPayments': '125290',
#       'expDlr': '125290',
#       'expWgt': '8370',
#       'hsCd': '0307991900',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '1188',
#       'expDlr': '1188',
#       'expWgt': '35',
#       'hsCd': '0307994900',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '31397',
#       'expDlr': '31397',
#       'expWgt': '1582',
#       'hsCd': '0308110000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2016.01'},
#      {'balPayments': '-32',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308192000',
#       'impDlr': '32',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2016.01'},
#      {'balPayments': '-21794',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308210000',
#       'impDlr': '21794',
#       'impWgt': '283',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2016.01'},
#      {'balPayments': '-3152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308291000',
#       'impDlr': '3152',
#       'impWgt': '51',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2016.01'},
#      {'balPayments': '32034',
#       'expDlr': '32034',
#       'expWgt': '3025',
#       'hsCd': '0308901019',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '1236',
#       'expDlr': '1236',
#       'expWgt': '38',
#       'hsCd': '0308901090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '53361',
#       'expDlr': '53361',
#       'expWgt': '14181',
#       'hsCd': '0308902010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '우렁쉥이(멍게)',
#       'year': '2016.01'},
#      {'balPayments': '110',
#       'expDlr': '110',
#       'expWgt': '5',
#       'hsCd': '0308903090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-2510',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401100000',
#       'impDlr': '2510',
#       'impWgt': '520',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '지방분이 전 중량의 100분의 1 이하인 것',
#       'year': '2016.01'},
#      {'balPayments': '-39',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401409000',
#       'impDlr': '39',
#       'impWgt': '3',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-31',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401509000',
#       'impDlr': '31',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '103476',
#       'expDlr': '105944',
#       'expWgt': '49128',
#       'hsCd': '0402999000',
#       'impDlr': '2468',
#       'impWgt': '513',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-32869',
#       'expDlr': '29732',
#       'expWgt': '36122',
#       'hsCd': '0403101000',
#       'impDlr': '62601',
#       'impWgt': '11638',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '액체 상태인 것',
#       'year': '2016.01'},
#      {'balPayments': '190584',
#       'expDlr': '190584',
#       'expWgt': '198389',
#       'hsCd': '0403102000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2016.01'},
#      {'balPayments': '-2803',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0403109000',
#       'impDlr': '2803',
#       'impWgt': '33',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-441828',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404101011',
#       'impDlr': '441828',
#       'impWgt': '739851',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2016.01'},
#      {'balPayments': '-39203',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404101019',
#       'impDlr': '39203',
#       'impWgt': '28197',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-122095',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102191',
#       'impDlr': '122095',
#       'impWgt': '289875',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2016.01'},
#      {'balPayments': '-15405',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102199',
#       'impDlr': '15405',
#       'impWgt': '1950',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-57',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404901000',
#       'impDlr': '57',
#       'impWgt': '3',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '지방분이 전 중량의 100분의 1.5 이하인 것',
#       'year': '2016.01'},
#      {'balPayments': '-35820',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404902000',
#       'impDlr': '35820',
#       'impWgt': '1020',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '지방분이 전 중량의 100분의 1.5를 초과하는 것',
#       'year': '2016.01'},
#      {'balPayments': '-116311',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0405100000',
#       'impDlr': '116311',
#       'impWgt': '16794',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '버터',
#       'year': '2016.01'},
#      {'balPayments': '-117',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0405900000',
#       'impDlr': '117',
#       'impWgt': '12',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-8328943',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101010',
#       'impDlr': '8328943',
#       'impWgt': '1983053',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '모차렐라 치즈(Mozzarella cheese)',
#       'year': '2016.01'},
#      {'balPayments': '-2442998',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101020',
#       'impDlr': '2442998',
#       'impWgt': '638362',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '크림 치즈',
#       'year': '2016.01'},
#      {'balPayments': '-251760',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101090',
#       'impDlr': '251760',
#       'impWgt': '48584',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-35',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406102000',
#       'impDlr': '35',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '커드(curd)',
#       'year': '2016.01'},
#      {'balPayments': '-843153',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406200000',
#       'impDlr': '843153',
#       'impWgt': '149513',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈았거나 가루 모양으로 한 모든 종류의 치즈',
#       'year': '2016.01'},
#      {'balPayments': '-980913',
#       'expDlr': '43648',
#       'expWgt': '7294',
#       'hsCd': '0406300000',
#       'impDlr': '1024561',
#       'impWgt': '198876',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가공치즈(갈았거나 가루 모양의 것은 제외한다)',
#       'year': '2016.01'},
#      {'balPayments': '-43603',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406400000',
#       'impDlr': '43603',
#       'impWgt': '4250',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '블루바인 치즈(blue-veined cheese)와 페니실리움 로우크포티(Penicillium roqueforti)로 생산된 바인(vein)을 함유한 그 밖의 치즈',
#       'year': '2016.01'},
#      {'balPayments': '-1706201',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406901000',
#       'impDlr': '1706201',
#       'impWgt': '411406',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '체더 치즈(Cheddar cheese)',
#       'year': '2016.01'},
#      {'balPayments': '-86170',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406902000',
#       'impDlr': '86170',
#       'impWgt': '23130',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '하우다 치즈(Gouda cheese)',
#       'year': '2016.01'},
#      {'balPayments': '-579571',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406909000',
#       'impDlr': '579571',
#       'impWgt': '118023',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-50599',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0407290000',
#       'impDlr': '50599',
#       'impWgt': '1995',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-140596',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0409000000',
#       'impDlr': '140596',
#       'impWgt': '4076',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '천연꿀',
#       'year': '2016.01'},
#      {'balPayments': '-38052',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0410003000',
#       'impDlr': '38052',
#       'impWgt': '541',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '로열젤리',
#       'year': '2016.01'},
#      {'balPayments': '-165037',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504001021',
#       'impDlr': '165037',
#       'impWgt': '14501',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소시지 케이싱용',
#       'year': '2016.01'},
#      {'balPayments': '-1642289',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504001029',
#       'impDlr': '1642289',
#       'impWgt': '676076',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-592874',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504001090',
#       'impDlr': '592874',
#       'impWgt': '200132',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-804828',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504003000',
#       'impDlr': '804828',
#       'impWgt': '210046',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '위',
#       'year': '2016.01'},
#      {'balPayments': '-117',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0506901090',
#       'impDlr': '117',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-199628',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511100000',
#       'impDlr': '199628',
#       'impWgt': '8',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 정액',
#       'year': '2016.01'},
#      {'balPayments': '-68595',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511911010',
#       'impDlr': '68595',
#       'impWgt': '837',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '브라인 슈림프(brine shrimp) 알',
#       'year': '2016.01'},
#      {'balPayments': '-93',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511911090',
#       'impDlr': '93',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-5504',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511991000',
#       'impDlr': '5504',
#       'impWgt': '3',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '동물의 피',
#       'year': '2016.01'},
#      {'balPayments': '-47560',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0601109000',
#       'impDlr': '47560',
#       'impWgt': '1400',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-73',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602109000',
#       'impDlr': '73',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-750',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602209000',
#       'impDlr': '750',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '3285',
#       'expDlr': '3478',
#       'expWgt': '230',
#       'hsCd': '0602901060',
#       'impDlr': '193',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '선인장류',
#       'year': '2016.01'},
#      {'balPayments': '-25554',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602901090',
#       'impDlr': '25554',
#       'impWgt': '1761',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-1652',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602902099',
#       'impDlr': '1652',
#       'impWgt': '65',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-18089',
#       'expDlr': '0',
#       'expWgt': '0',
# ...
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2508502000',
#       'impDlr': '8907',
#       'impWgt': '20000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '남정석(藍晶石)',
#       'year': '2016.01'},
#      {'balPayments': '-76',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2510209000',
#       'impDlr': '76',
#       'impWgt': '4',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-100694',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2512000000',
#       'impDlr': '100694',
#       'impWgt': '144615',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '규조토[예: 키절구어(kieselguhr)ㆍ트리폴리트(tripolite)ㆍ다이어토마이트(diatomite)]와 이와 유사한 규산질의 흙[하소(煆燒)한 것인지에 상관없으며 겉보기 비중이 1 이하인 것으로 한정한다]',
#       'year': '2016.01'},
#      {'balPayments': '-461',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2513109000',
#       'impDlr': '461',
#       'impWgt': '4',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-27250',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2513201090',
#       'impDlr': '27250',
#       'impWgt': '6205',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-445',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2516209000',
#       'impDlr': '445',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '톱질이나 그 밖의 방법으로 단순히 절단하여 직사각형(정사각형을 포함한다)의 블록 모양이나 슬래브 모양으로 한 것',
#       'year': '2016.01'},
#      {'balPayments': '10',
#       'expDlr': '10',
#       'expWgt': '2',
#       'hsCd': '2519100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '천연 탄산마그네슘(마그네사이트)',
#       'year': '2016.01'},
#      {'balPayments': '-66989',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2519909000',
#       'impDlr': '66989',
#       'impWgt': '61226',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-15037',
#       'expDlr': '145',
#       'expWgt': '50',
#       'hsCd': '2520101000',
#       'impDlr': '15182',
#       'impWgt': '19187',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '석고',
#       'year': '2016.01'},
#      {'balPayments': '-49',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2520201000',
#       'impDlr': '49',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '치과용으로 사용하기 위하여 특별히 하소하거나 미세하게 분쇄한 것',
#       'year': '2016.01'},
#      {'balPayments': '-27352',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2520209000',
#       'impDlr': '27352',
#       'impWgt': '21435',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-51',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2521001000',
#       'impDlr': '51',
#       'impWgt': '14',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '석회석',
#       'year': '2016.01'},
#      {'balPayments': '-18693',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2523210000',
#       'impDlr': '18693',
#       'impWgt': '5647',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '백색 시멘트(인위적으로 착색한 것인지에 상관없다)',
#       'year': '2016.01'},
#      {'balPayments': '1210152',
#       'expDlr': '1227150',
#       'expWgt': '30300000',
#       'hsCd': '2523290000',
#       'impDlr': '16998',
#       'impWgt': '5377',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '26943',
#       'expDlr': '26943',
#       'expWgt': '32658',
#       'hsCd': '2523300000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '알루미나(aluminous) 시멘트',
#       'year': '2016.01'},
#      {'balPayments': '30497',
#       'expDlr': '58378',
#       'expWgt': '5260',
#       'hsCd': '2525200000',
#       'impDlr': '27881',
#       'impWgt': '27835',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '운모 가루',
#       'year': '2016.01'},
#      {'balPayments': '-1597',
#       'expDlr': '25209',
#       'expWgt': '13600',
#       'hsCd': '2526200000',
#       'impDlr': '26806',
#       'impWgt': '44033',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '부수거나 가루인 것',
#       'year': '2016.01'},
#      {'balPayments': '-775',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2528001000',
#       'impDlr': '775',
#       'impWgt': '20',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '천연 붕산나트륨과 그 정광(精鑛)[하소(煆燒)한 것인지에 상관없다]',
#       'year': '2016.01'},
#      {'balPayments': '-124848',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2530102000',
#       'impDlr': '124848',
#       'impWgt': '871005',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '진주암(眞珠巖)과 녹니석(綠泥石)',
#       'year': '2016.01'},
#      {'balPayments': '-9011',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2530905000',
#       'impDlr': '9011',
#       'impWgt': '20412',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '납석(蠟石)',
#       'year': '2016.01'},
#      {'balPayments': '-116552',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2530908000',
#       'impDlr': '116552',
#       'impWgt': '117921',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '규회석(硅灰石)',
#       'year': '2016.01'},
#      {'balPayments': '55224',
#       'expDlr': '55224',
#       'expWgt': '3412',
#       'hsCd': '2530909020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '견운모(絹雲母)',
#       'year': '2016.01'},
#      {'balPayments': '-44656',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2530909099',
#       'impDlr': '44656',
#       'impWgt': '1600',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-925',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2601129000',
#       'impDlr': '925',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-45562',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2602000000',
#       'impDlr': '45562',
#       'impWgt': '34000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '망간광과 그 정광(精鑛)[건조 상태에서 측정한 망간의 함유량이 전 중량의 100분의 20 이상인 철망간광과 그 정광(精鑛)을 포함한다]',
#       'year': '2016.01'},
#      {'balPayments': '-16105',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2605000000',
#       'impDlr': '16105',
#       'impWgt': '23572',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '코발트광과 그 정광(精鑛)',
#       'year': '2016.01'},
#      {'balPayments': '-12284117',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2607000000',
#       'impDlr': '12284117',
#       'impWgt': '4808994',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '납광과 그 정광(精鑛)',
#       'year': '2016.01'},
#      {'balPayments': '-3572917',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2608000000',
#       'impDlr': '3572917',
#       'impWgt': '6038495',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아연광과 그 정광(精鑛)',
#       'year': '2016.01'},
#      {'balPayments': '-1268',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2609000000',
#       'impDlr': '1268',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '주석광과 그 정광(精鑛)',
#       'year': '2016.01'},
#      {'balPayments': '-780959',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2613100000',
#       'impDlr': '780959',
#       'impWgt': '126000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '배소(焙燒)한 것',
#       'year': '2016.01'},
#      {'balPayments': '-2591972',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2616901000',
#       'impDlr': '2591972',
#       'impWgt': '44996',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '금광과 그 정광',
#       'year': '2016.01'},
#      {'balPayments': '-421330',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2620110000',
#       'impDlr': '421330',
#       'impWgt': '298945',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '경(硬)아연 스펠터(spelter)',
#       'year': '2016.01'},
#      {'balPayments': '-78',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2620190000',
#       'impDlr': '78',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-62815',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2620300000',
#       'impDlr': '62815',
#       'impWgt': '25931',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '주로 구리를 함유하는 것',
#       'year': '2016.01'},
#      {'balPayments': '-362',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2620400000',
#       'impDlr': '362',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '주로 알루미늄을 함유하는 것',
#       'year': '2016.01'},
#      {'balPayments': '-273861',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2620990000',
#       'impDlr': '273861',
#       'impWgt': '1766197',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-700',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2621900000',
#       'impDlr': '700',
#       'impWgt': '454',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-30',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2701110000',
#       'impDlr': '30',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '무연탄',
#       'year': '2016.01'},
#      {'balPayments': '-5879117',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2701121000',
#       'impDlr': '5879117',
#       'impWgt': '58045000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '강점결성 코크스용 탄',
#       'year': '2016.01'},
#      {'balPayments': '-15659840',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2701122000',
#       'impDlr': '15659840',
#       'impWgt': '161106000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 코크스용 탄',
#       'year': '2016.01'},
#      {'balPayments': '-4928967',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2701129010',
#       'impDlr': '4928967',
#       'impWgt': '48312000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '휘발성 물질의 함유량이 전 중량의 100분의 22 미만인 것(건조하고 광물질이 없는 상태 기준에 의한다)',
#       'year': '2016.01'},
#      {'balPayments': '41354',
#       'expDlr': '41354',
#       'expWgt': '49880',
#       'hsCd': '2705000000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '석탄가스ㆍ수성(水性)가스ㆍ발생로(發生爐)가스와 이와 유사한 가스(석유가스와 그 밖의 가스 상태의 탄화수소는 제외한다)',
#       'year': '2016.01'},
#      {'balPayments': '-11',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2706001000',
#       'impDlr': '11',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '콜타르(coal tar)',
#       'year': '2016.01'},
#      {'balPayments': '15949',
#       'expDlr': '15949',
#       'expWgt': '7120',
#       'hsCd': '2707500000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 방향족(芳香族) 탄화수소의 혼합물[아이ㆍ에스ㆍ오(ISO) 3405방법(에이ㆍ에스ㆍ티ㆍ엠 디(ASTM D)86과 동등)에 의하여 섭씨 250도에서 전 용량의 100분의 65 이상(손실분을 포함한다)이 증류되는 것으로 한정한다]',
#       'year': '2016.01'},
#      {'balPayments': '-8860',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2707991000',
#       'impDlr': '8860',
#       'impWgt': '3060',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '솔벤트 나프타(solvent naphtha)',
#       'year': '2016.01'},
#      {'balPayments': '-701',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2707999000',
#       'impDlr': '701',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-4968',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710121000',
#       'impDlr': '4968',
#       'impWgt': '684',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '자동차 휘발유',
#       'year': '2016.01'},
#      {'balPayments': '65852',
#       'expDlr': '65852',
#       'expWgt': '64672',
#       'hsCd': '2710122000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '항공 휘발유',
#       'year': '2016.01'},
#      {'balPayments': '-2504605',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710123000',
#       'impDlr': '2504605',
#       'impWgt': '2527352',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '프로필렌테트라머(propylene tetramer)',
#       'year': '2016.01'},
#      {'balPayments': '-32614610',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710124000',
#       'impDlr': '32614610',
#       'impWgt': '79708392',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '나프타',
#       'year': '2016.01'},
#      {'balPayments': '-54622',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710129000',
#       'impDlr': '54622',
#       'impWgt': '9606',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '-5680',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710191090',
#       'impDlr': '5680',
#       'impWgt': '880',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '65708829',
#       'expDlr': '65714522',
#       'expWgt': '218555563',
#       'hsCd': '2710192020',
#       'impDlr': '5693',
#       'impWgt': '16103',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '제트 연료유',
#       'year': '2016.01'},
#      {'balPayments': '2116005',
#       'expDlr': '2116005',
#       'expWgt': '3000404',
#       'hsCd': '2710192030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '노르말-파라핀(n-paraffin)',
#       'year': '2016.01'},
#      {'balPayments': '-10',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710192090',
#       'impDlr': '10',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '12',
#       'expDlr': '117',
#       'expWgt': '594',
#       'hsCd': '2710193000',
#       'impDlr': '105',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '경유',
#       'year': '2016.01'},
#      {'balPayments': '-200',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710194090',
#       'impDlr': '200',
#       'impWgt': '35',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2016.01'},
#      {'balPayments': '32923674',
#       'expDlr': '33018248',
#       'expWgt': '50721340',
#       'hsCd': '2710195020',
#       'impDlr': '94574',
#       'impWgt': '21673',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '윤활유 기유(基油)',
#       'year': '2016.01'},
#      {'balPayments': '-7670',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710196000',
#       'impDlr': '7670',
#       'impWgt': '2908',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '신전유(extender oil)',
#       'year': '2016.01'},
#      {'balPayments': '-15714',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710197110',
#       'impDlr': '15714',
#       'impWgt': '1035',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '항공기용 기관오일',
#       'year': '2016.01'},
#      ...]}}}}

# %%
import pandas as pd

pd.set_option('display.max_rows', 10)
dataset = pd.DataFrame(data["response"]["body"]["items"]["item"])
dataset
# Out:
#      balPayments      expDlr      expWgt        hsCd      impDlr      impWgt  \
# 0     1709825452  5027618286  1241496326           -  3317792834  1509874932
# 1        -579245           0           0  0101211000      579245        5000
# 2        -519540           0           0  0101219000      519540        3050
# 3       -1263787           0           0  0105111000     1263787        1431
# 4          18072       21179         889  0106191000        3107         116
# ...          ...         ...         ...         ...         ...         ...
# 6401       -7231           0           0  9703002000        7231        1979
# 6402       -1512           0           0  9704001000        1512           2
# 6403      -37615           0           0  9705000000       37615         145
# 6404      -40304           0           0  9706009000       40304         155
# 6405        -163           0           0  9999999290         163      388633
#
#      statCd statCdCntnKor1                                            statKor  \
# 0         -              -                                                  -
# 1        US             미국                                             농가 사육용
# 2        US             미국                                                 기타
# 3        US             미국                                                번식용
# 4        US             미국                                                  개
# ...     ...            ...                                                ...
# 6401     US             미국                                             조상(彫像)
# 6402     US             미국                                                 우표
# 6403     US             미국  수집품과 표본[동물학ㆍ식물학ㆍ광물학ㆍ해부학ㆍ사학ㆍ고고학ㆍ고생물학ㆍ민족학ㆍ고전학(古錢...
# 6404     US             미국                                                 기타
# 6405     US             미국                                                  -
#
#          year
# 0          총계
# 1     2016.01
# 2     2016.01
# 3     2016.01
# 4     2016.01
# ...       ...
# 6401  2016.01
# 6402  2016.01
# 6403  2016.01
# 6404  2016.01
# 6405  2016.01
#
# [6406 rows x 10 columns]

# %% [markdown]
# ## 무역 데이터 API 응답 필드
#
# | 필드       | 설명                        | 예시                  | 상세 설명       |
# |-------------|---------------------------|----------------------|-------------|
# | year       | 연도                        | 2016.01             | 기간 정보       |
# | statCdCntnKor1 | 국가명                      | 미국                 | 국가명 정보      |
# | statCd     | 국가코드                    | US                   | ISO 국가 코드   |
# | statKor    | 품목명                      | 쇠고기(냉동한 것으로 한정) | 품목명 정보      |
# | hsCd       | HS코드                      | 0202                 | 국제 무역 품목 코드 |
# | expWgt     | 수출중량 (kg)               | 18,003               | 수출된 상품의 중량  |
# | expDlr     | 수출금액 (달러)             | 150,822              | 수출된 상품의 금액  |
# | impWgt     | 수입중량 (kg)               | 14,809,834           | 수입된 상품의 중량  |
# | impDlr     | 수입금액 (달러)             | 93,754,113           | 수입된 상품의 금액  |
# | balPayments | 무역수지 (달러)             | -93,603,291          | 수출금액 - 수입금액 |
