# %%
import os

import requests
import xmltodict
from dotenv import load_dotenv

load_dotenv()

SERVICE_KEY = os.getenv("DATA_GO_KR_SERVICE_KEY")
query_param = {
    "serviceKey": SERVICE_KEY,
    "strtYymm": "202408",
    "endYymm": "202412",
    # "hsSgn": "1001999090",
    "cntyCd": "US",
}
response = requests.get("http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList", params=query_param)
response.raise_for_status()

data = xmltodict.parse(response.content)

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '24423569423',
#       'expDlr': '52935826042',
#       'expWgt': '8378999837',
#       'hsCd': '-',
#       'impDlr': '28512256619',
#       'impWgt': '21394331041',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '98044',
#       'expDlr': '98044',
#       'expWgt': '650',
#       'hsCd': '0101291000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '경주말',
#       'year': '2024.08'},
#      {'balPayments': '-1906163',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0105111000',
#       'impDlr': '1906163',
#       'impWgt': '1855',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '번식용',
#       'year': '2024.08'},
#      {'balPayments': '85',
#       'expDlr': '85',
#       'expWgt': '1',
#       'hsCd': '0106149000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '19581',
#       'expDlr': '26734',
#       'expWgt': '165',
#       'hsCd': '0106191000',
#       'impDlr': '7153',
#       'impWgt': '92',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개',
#       'year': '2024.08'},
#      {'balPayments': '-236332',
#       'expDlr': '1800',
#       'expWgt': '3',
#       'hsCd': '0106199000',
#       'impDlr': '238132',
#       'impWgt': '150',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-18650',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106201000',
#       'impDlr': '18650',
#       'impWgt': '8',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뱀',
#       'year': '2024.08'},
#      {'balPayments': '-9400',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106203000',
#       'impDlr': '9400',
#       'impWgt': '20',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '거북',
#       'year': '2024.08'},
#      {'balPayments': '-6850',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106209000',
#       'impDlr': '6850',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-1670',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106490000',
#       'impDlr': '1670',
#       'impWgt': '6',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-389',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106909000',
#       'impDlr': '389',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-9942262',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201201000',
#       'impDlr': '9942262',
#       'impWgt': '727938',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈비',
#       'year': '2024.08'},
#      {'balPayments': '-1492156',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201209000',
#       'impDlr': '1492156',
#       'impWgt': '63558',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-64460603',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201300000',
#       'impDlr': '64460603',
#       'impWgt': '4764470',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2024.08'},
#      {'balPayments': '-65310806',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202201000',
#       'impDlr': '65310806',
#       'impWgt': '6612296',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈비',
#       'year': '2024.08'},
#      {'balPayments': '-873237',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202209000',
#       'impDlr': '873237',
#       'impWgt': '422312',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-39440579',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202300000',
#       'impDlr': '39440579',
#       'impWgt': '4997280',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2024.08'},
#      {'balPayments': '-2431387',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203191000',
#       'impDlr': '2431387',
#       'impWgt': '310555',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2024.08'},
#      {'balPayments': '-1518281',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203199000',
#       'impDlr': '1518281',
#       'impWgt': '237429',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-87279',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203291000',
#       'impDlr': '87279',
#       'impWgt': '22936',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2024.08'},
#      {'balPayments': '-41764836',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203299000',
#       'impDlr': '41764836',
#       'impWgt': '12712919',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-3954178',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206100000',
#       'impDlr': '3954178',
#       'impWgt': '284102',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 것(신선한 것이나 냉장한 것으로 한정한다)',
#       'year': '2024.08'},
#      {'balPayments': '-3328887',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206299000',
#       'impDlr': '3328887',
#       'impWgt': '389819',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-653159',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206499000',
#       'impDlr': '653159',
#       'impWgt': '244476',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-106187',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141010',
#       'impDlr': '106187',
#       'impWgt': '69285',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '다리',
#       'year': '2024.08'},
#      {'balPayments': '-37060',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0209100000',
#       'impDlr': '37060',
#       'impWgt': '23904',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '돼지의 것',
#       'year': '2024.08'},
#      {'balPayments': '-519685',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210120000',
#       'impDlr': '519685',
#       'impWgt': '65042',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '복부살(삼겹살)과 이를 절단한 것',
#       'year': '2024.08'},
#      {'balPayments': '-108855',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210190000',
#       'impDlr': '108855',
#       'impWgt': '3512',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-146',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210991090',
#       'impDlr': '146',
#       'impWgt': '25',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-4341',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301190000',
#       'impDlr': '4341',
#       'impWgt': '13',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '3067',
#       'expDlr': '3067',
#       'expWgt': '250',
#       'hsCd': '0301994091',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '참돔[파그루스 마조르(Pagrus major)]',
#       'year': '2024.08'},
#      {'balPayments': '-447818',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301997000',
#       'impDlr': '447818',
#       'impWgt': '42220',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '먹장어',
#       'year': '2024.08'},
#      {'balPayments': '1251227',
#       'expDlr': '1251227',
#       'expWgt': '51580',
#       'hsCd': '0301998000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '넙치류[플루로넥티대(Pleuronectidae)과ㆍ바디대(Bothidae)과ㆍ사이노글로시대(Cynoglossidae)과ㆍ솔레이대(Soleidae)과ㆍ스코프탈미대(Scophthalmidae)과ㆍ시타리대(Citharidae)과]',
#       'year': '2024.08'},
#      {'balPayments': '8451',
#       'expDlr': '8451',
#       'expWgt': '309',
#       'hsCd': '0301999040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '볼락(적어를 포함한다)',
#       'year': '2024.08'},
#      {'balPayments': '12767',
#       'expDlr': '12767',
#       'expWgt': '684',
#       'hsCd': '0301999070',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '미꾸라지',
#       'year': '2024.08'},
#      {'balPayments': '55908',
#       'expDlr': '55908',
#       'expWgt': '1686',
#       'hsCd': '0301999099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-6',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302140000',
#       'impDlr': '6',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대서양 연어[살모 살라(Salmo salar)]와 다뉴브 연어[후코 후코(Hucho hucho)]',
#       'year': '2024.08'},
#      {'balPayments': '185992',
#       'expDlr': '185992',
#       'expWgt': '8911',
#       'hsCd': '0302210000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '넙치[레인하드티우스 히포글러소이데스(Reinhardtius hippoglossoides)ㆍ히포글러서스 히포글러서스(Hippoglossus hippoglossus)ㆍ히포글러서스 스테노레피스(Hippoglossus stenolepis)]',
#       'year': '2024.08'},
#      {'balPayments': '72790',
#       'expDlr': '72790',
#       'expWgt': '2310',
#       'hsCd': '0302240000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '터벗(turbots)[프세타 맥시마(Psetta maxima)]',
#       'year': '2024.08'},
#      {'balPayments': '123400',
#       'expDlr': '123400',
#       'expWgt': '5423',
#       'hsCd': '0302290000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '212',
#       'expDlr': '212',
#       'expWgt': '10',
#       'hsCd': '0302450000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전갱이[트라커러스(Trachurus)속]',
#       'year': '2024.08'},
#      {'balPayments': '504',
#       'expDlr': '504',
#       'expWgt': '16',
#       'hsCd': '0302492000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '병어[팜푸스(Pampus)속]',
#       'year': '2024.08'},
#      {'balPayments': '695',
#       'expDlr': '695',
#       'expWgt': '17',
#       'hsCd': '0302740000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뱀장어[앙귈라(Anguilla)속]',
#       'year': '2024.08'},
#      {'balPayments': '199',
#       'expDlr': '199',
#       'expWgt': '10',
#       'hsCd': '0302820000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가오리와 홍어[라지대(Rajidae)과]',
#       'year': '2024.08'},
#      {'balPayments': '1402',
#       'expDlr': '1402',
#       'expWgt': '51',
#       'hsCd': '0302891000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '방어',
#       'year': '2024.08'},
#      {'balPayments': '1417',
#       'expDlr': '1417',
#       'expWgt': '37',
#       'hsCd': '0302893000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2024.08'},
#      {'balPayments': '474',
#       'expDlr': '474',
#       'expWgt': '23',
#       'hsCd': '0302896000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '돔[스파리대(Sparidae)과는 제외한다]',
#       'year': '2024.08'},
#      {'balPayments': '2253',
#       'expDlr': '2253',
#       'expWgt': '130',
#       'hsCd': '0302899040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아귀',
#       'year': '2024.08'},
#      {'balPayments': '18101',
#       'expDlr': '18101',
#       'expWgt': '850',
#       'hsCd': '0302899090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '193',
#       'expDlr': '193',
#       'expWgt': '10',
#       'hsCd': '0303290000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '4453',
#       'expDlr': '4453',
#       'expWgt': '479',
#       'hsCd': '0303320000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미[플루로넥테스 플라테사(Pleuronectes platessa)]',
#       'year': '2024.08'},
#      {'balPayments': '57980',
#       'expDlr': '57980',
#       'expWgt': '1766',
#       'hsCd': '0303330000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '서대[솔레아(Solea)속]',
#       'year': '2024.08'},
#      {'balPayments': '-411570',
#       'expDlr': '14934',
#       'expWgt': '1276',
#       'hsCd': '0303391000',
#       'impDlr': '426504',
#       'impWgt': '167853',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미[플루로넥테스 플라테사(Pleuronectes platessa)를 제외한다]',
#       'year': '2024.08'},
#      {'balPayments': '-257944',
#       'expDlr': '12369',
#       'expWgt': '3160',
#       'hsCd': '0303399000',
#       'impDlr': '270313',
#       'impWgt': '150588',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '58926',
#       'expDlr': '58926',
#       'expWgt': '15195',
#       'hsCd': '0303540000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어[스콤버 스콤브루스(Scomber scombrus)ㆍ스콤버 오스트랄라시쿠스(Scomber australasicus)ㆍ스콤버 자포니쿠스(Scomber japonicus)]',
#       'year': '2024.08'},
#      {'balPayments': '23945',
#       'expDlr': '23945',
#       'expWgt': '9200',
#       'hsCd': '0303550000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전갱이[트라커러스(Trachurus)속]',
#       'year': '2024.08'},
#      {'balPayments': '10065',
#       'expDlr': '10065',
#       'expWgt': '1741',
#       'hsCd': '0303592000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꽁치[콜로라비스 사이라(Cololabis saira)]',
#       'year': '2024.08'},
#      {'balPayments': '6949',
#       'expDlr': '6949',
#       'expWgt': '3150',
#       'hsCd': '0303599000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-346650',
#       'expDlr': '31367',
#       'expWgt': '6994',
#       'hsCd': '0303630000',
#       'impDlr': '378017',
#       'impWgt': '118641',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2024.08'},
#      {'balPayments': '2930',
#       'expDlr': '2930',
#       'expWgt': '400',
#       'hsCd': '0303660000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '민대구[메루키우스(Merluccius)속ㆍ유르피키스(Urophycis)속]',
#       'year': '2024.08'},
#      {'balPayments': '37897',
#       'expDlr': '39346',
#       'expWgt': '7112',
#       'hsCd': '0303670000',
#       'impDlr': '1449',
#       'impWgt': '1080',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태[테라그라 찰코그라마(Theragra chalcogramma)]',
#       'year': '2024.08'},
#      {'balPayments': '-180000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303821000',
#       'impDlr': '180000',
#       'impWgt': '36000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가오리',
#       'year': '2024.08'},
#      {'balPayments': '-321212',
#       'expDlr': '10992',
#       'expWgt': '489',
#       'hsCd': '0303822000',
#       'impDlr': '332204',
#       'impWgt': '64958',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '홍어',
#       'year': '2024.08'},
#      {'balPayments': '4273934',
#       'expDlr': '4273934',
#       'expWgt': '142405',
#       'hsCd': '0303830000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '이빨고기[디소스티쿠스(Dissostichus)속]',
#       'year': '2024.08'},
#      {'balPayments': '-50634',
#       'expDlr': '38728',
#       'expWgt': '5670',
#       'hsCd': '0303891000',
#       'impDlr': '89362',
#       'impWgt': '8891',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '은대구',
#       'year': '2024.08'},
#      {'balPayments': '78826',
#       'expDlr': '78826',
#       'expWgt': '4302',
#       'hsCd': '0303892000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2024.08'},
#      {'balPayments': '2743',
#       'expDlr': '2743',
#       'expWgt': '131',
#       'hsCd': '0303893010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '옥돔[브랜치오스테거스 자포니커스(Branchiostegus Japonicus)]',
#       'year': '2024.08'},
#      {'balPayments': '2458',
#       'expDlr': '2458',
#       'expWgt': '134',
#       'hsCd': '0303893020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '옥두어[브랜치오스테거스 알부스(Branchiostegus albus)]',
#       'year': '2024.08'},
#      {'balPayments': '5380',
#       'expDlr': '5380',
#       'expWgt': '973',
#       'hsCd': '0303893090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '10328',
#       'expDlr': '10328',
#       'expWgt': '748',
#       'hsCd': '0303894000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2024.08'},
#      {'balPayments': '63746',
#       'expDlr': '63746',
#       'expWgt': '2918',
#       'hsCd': '0303895010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '참조기[라리미크티스 폴리악티스(Larimichthys polyactis)]',
#       'year': '2024.08'},
#      {'balPayments': '1500',
#       'expDlr': '1500',
#       'expWgt': '25',
#       'hsCd': '0303895090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-730771',
#       'expDlr': '64470',
#       'expWgt': '10150',
#       'hsCd': '0303899040',
#       'impDlr': '795241',
#       'impWgt': '301278',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '임연수어',
#       'year': '2024.08'},
#      {'balPayments': '-408464',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303899050',
#       'impDlr': '408464',
#       'impWgt': '218306',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '볼낙(적어를 포함한다)',
#       'year': '2024.08'},
#      {'balPayments': '-274392',
#       'expDlr': '3213',
#       'expWgt': '242',
#       'hsCd': '0303899060',
#       'impDlr': '277605',
#       'impWgt': '61100',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아귀',
#       'year': '2024.08'},
#      {'balPayments': '4500',
#       'expDlr': '4500',
#       'expWgt': '150',
#       'hsCd': '0303899091',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '민어',
#       'year': '2024.08'},
#      {'balPayments': '-769407',
#       'expDlr': '156848',
#       'expWgt': '22330',
#       'hsCd': '0303899099',
#       'impDlr': '926255',
#       'impWgt': '225179',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-485294',
#       'expDlr': '46107',
#       'expWgt': '5797',
#       'hsCd': '0303912010',
#       'impDlr': '531401',
#       'impWgt': '123612',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명란',
#       'year': '2024.08'},
#      {'balPayments': '-195059',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303912090',
#       'impDlr': '195059',
#       'impWgt': '70958',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-406112',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303990000',
#       'impDlr': '406112',
#       'impWgt': '94089',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '15799',
#       'expDlr': '15799',
#       'expWgt': '350',
#       'hsCd': '0304390000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '1',
#       'expDlr': '1',
#       'expWgt': '2',
#       'hsCd': '0304431000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미',
#       'year': '2024.08'},
#      {'balPayments': '5591',
#       'expDlr': '5591',
#       'expWgt': '113',
#       'hsCd': '0304439000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '4260',
#       'expDlr': '4260',
#       'expWgt': '107',
#       'hsCd': '0304491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2024.08'},
#      {'balPayments': '1420',
#       'expDlr': '1420',
#       'expWgt': '32',
#       'hsCd': '0304499000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '1047',
#       'expDlr': '1047',
#       'expWgt': '22',
#       'hsCd': '0304511000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '연육',
#       'year': '2024.08'},
#      {'balPayments': '2650',
#       'expDlr': '2650',
#       'expWgt': '86',
#       'hsCd': '0304690000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-137726',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304710000',
#       'impDlr': '137726',
#       'impWgt': '17370',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2024.08'},
#      {'balPayments': '-724755',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304750000',
#       'impDlr': '724755',
#       'impWgt': '236350',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태[테라그라 찰코그라마(Theragra chalcogramma)]',
#       'year': '2024.08'},
#      {'balPayments': '-158288',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304810000',
#       'impDlr': '158288',
#       'impWgt': '40354',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '태평양 연어[옹코링쿠스 넬카(Oncorhynchus nerka)ㆍ옹코링쿠스 고르부스카(Oncorhynchus gorbuscha)ㆍ옹코링쿠스 케타(Oncorhynchus keta)ㆍ옹코링쿠스 차비차(Oncorhynchus tschawytscha)ㆍ옹코링쿠스 키수츠(Oncorhynchus kisutch)ㆍ옹코링쿠스 마소(Oncorhynchus masou)ㆍ옹코링쿠스 로두루스(Oncorhynchus rhodurus)], 대서양 연어[살모 살라(Salmo salar)], 다뉴브 연어[후코 후코(Hucho hucho)]',
#       'year': '2024.08'},
#      {'balPayments': '-936926',
#       'expDlr': '19600',
#       'expWgt': '3086',
#       'hsCd': '0304831000',
#       'impDlr': '956526',
#       'impWgt': '195924',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미',
#       'year': '2024.08'},
#      {'balPayments': '-1',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304839000',
#       'impDlr': '1',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '22921',
#       'expDlr': '22921',
#       'expWgt': '789',
#       'hsCd': '0304871000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '참다랑어',
#       'year': '2024.08'},
#      {'balPayments': '1044093',
#       'expDlr': '1044093',
#       'expWgt': '65983',
#       'hsCd': '0304879000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '30719',
#       'expDlr': '30719',
#       'expWgt': '850',
#       'hsCd': '0304891000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어의 것',
#       'year': '2024.08'},
#      {'balPayments': '320',
#       'expDlr': '320',
#       'expWgt': '2',
#       'hsCd': '0304894000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '쥐치의 것',
#       'year': '2024.08'},
#      {'balPayments': '35969',
#       'expDlr': '35969',
#       'expWgt': '6034',
#       'hsCd': '0304895000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어의 것',
#       'year': '2024.08'},
#      {'balPayments': '298406',
#       'expDlr': '1021466',
#       'expWgt': '79217',
#       'hsCd': '0304899000',
#       'impDlr': '723060',
#       'impWgt': '159675',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-2060550',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304941000',
#       'impDlr': '2060550',
#       'impWgt': '778600',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동 연육',
#       'year': '2024.08'},
#      {'balPayments': '21663',
#       'expDlr': '21663',
#       'expWgt': '100',
#       'hsCd': '0304991000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동 연육',
#       'year': '2024.08'},
#      {'balPayments': '62661',
#       'expDlr': '62661',
#       'expWgt': '10003',
#       'hsCd': '0304999000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '31665',
#       'expDlr': '31665',
#       'expWgt': '1768',
#       'hsCd': '0305204010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태의 것',
#       'year': '2024.08'},
#      {'balPayments': '783',
#       'expDlr': '783',
#       'expWgt': '65',
#       'hsCd': '0305204020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기의 것',
#       'year': '2024.08'},
#      {'balPayments': '370',
#       'expDlr': '370',
#       'expWgt': '20',
#       'hsCd': '0305204090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '2546',
#       'expDlr': '2546',
#       'expWgt': '204',
#       'hsCd': '0305311000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2024.08'},
#      {'balPayments': '31618',
#       'expDlr': '31618',
#       'expWgt': '6328',
#       'hsCd': '0305392000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2024.08'},
#      {'balPayments': '27202',
#       'expDlr': '27202',
#       'expWgt': '2252',
#       'hsCd': '0305491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치',
#       'year': '2024.08'},
#      {'balPayments': '50653',
#       'expDlr': '171008',
#       'expWgt': '11736',
#       'hsCd': '0305531000',
#       'impDlr': '120355',
#       'impWgt': '6000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태(북어)',
#       'year': '2024.08'},
#      {'balPayments': '350',
#       'expDlr': '350',
#       'expWgt': '12',
#       'hsCd': '0305539000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '724582',
#       'expDlr': '724582',
#       'expWgt': '46981',
#       'hsCd': '0305541000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치[엔그라울리스(Engraulis)속]',
#       'year': '2024.08'},
#      {'balPayments': '3072',
#       'expDlr': '3072',
#       'expWgt': '127',
#       'hsCd': '0305549000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '82547',
#       'expDlr': '82547',
#       'expWgt': '4078',
#       'hsCd': '0305594000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기(굴비)',
#       'year': '2024.08'},
#      {'balPayments': '183829',
#       'expDlr': '183829',
#       'expWgt': '11573',
#       'hsCd': '0305599000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-522',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305631000',
#       'impDlr': '522',
#       'impWgt': '18',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치젓',
#       'year': '2024.08'},
#      {'balPayments': '5044',
#       'expDlr': '5044',
#       'expWgt': '487',
#       'hsCd': '0305693000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2024.08'},
#      {'balPayments': '108667',
#       'expDlr': '108667',
#       'expWgt': '13079',
#       'hsCd': '0305695000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어',
#       'year': '2024.08'},
#      {'balPayments': '152015',
#       'expDlr': '152015',
#       'expWgt': '11698',
#       'hsCd': '0305699000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '27640',
#       'expDlr': '27640',
#       'expWgt': '1712',
#       'hsCd': '0305790000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-155583',
#       'expDlr': '7888',
#       'expWgt': '160',
#       'hsCd': '0306129000',
#       'impDlr': '163471',
#       'impWgt': '3092',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '12572',
#       'expDlr': '12572',
#       'expWgt': '498',
#       'hsCd': '0306141090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '152850',
#       'expDlr': '152850',
#       'expWgt': '5104',
#       'hsCd': '0306143090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-179427',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306149090',
#       'impDlr': '179427',
#       'impWgt': '4320',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-644697',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306169090',
#       'impDlr': '644697',
#       'impWgt': '230000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '28610',
#       'expDlr': '28612',
#       'expWgt': '3600',
#       'hsCd': '0306171090',
#       'impDlr': '2',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '3627',
#       'expDlr': '3627',
#       'expWgt': '1945',
#       'hsCd': '0306179099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '40330',
#       'expDlr': '40330',
#       'expWgt': '1400',
#       'hsCd': '0306199000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '2304',
#       'expDlr': '2304',
#       'expWgt': '182',
#       'hsCd': '0306331000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꽃게[포르투누스 트리투버큘라투스(Portunus trituberculatus)]',
#       'year': '2024.08'},
#      {'balPayments': '14166',
#       'expDlr': '14166',
#       'expWgt': '497',
#       'hsCd': '0306339000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '1636',
#       'expDlr': '1636',
#       'expWgt': '240',
#       'hsCd': '0306360000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 새우류',
#       'year': '2024.08'},
#      {'balPayments': '5636',
#       'expDlr': '5636',
#       'expWgt': '94',
#       'hsCd': '0306910000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '닭새우류[팔리누루스(Palinurus)속ㆍ파누리루스(Panulirus)속ㆍ자수스(Jasus)속]',
#       'year': '2024.08'},
#      {'balPayments': '2480',
#       'expDlr': '2480',
#       'expWgt': '200',
#       'hsCd': '0306951030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2024.08'},
#      {'balPayments': '7581',
#       'expDlr': '7581',
#       'expWgt': '180',
#       'hsCd': '0306959020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2024.08'},
#      {'balPayments': '105706',
#       'expDlr': '105706',
#       'expWgt': '23955',
#       'hsCd': '0306959030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2024.08'},
#      {'balPayments': '696309',
#       'expDlr': '696309',
#       'expWgt': '84714',
#       'hsCd': '0307120000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2024.08'},
#      {'balPayments': '1153',
#       'expDlr': '1153',
#       'expWgt': '38',
#       'hsCd': '0307192000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2024.08'},
#      {'balPayments': '36677',
#       'expDlr': '36677',
#       'expWgt': '3676',
#       'hsCd': '0307193000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2024.08'},
#      {'balPayments': '1278',
#       'expDlr': '1278',
#       'expWgt': '60',
#       'hsCd': '0307299000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '5452',
#       'expDlr': '5452',
#       'expWgt': '1400',
#       'hsCd': '0307320000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2024.08'},
#      {'balPayments': '2040',
#       'expDlr': '2040',
#       'expWgt': '113',
#       'hsCd': '0307431090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '646516',
#       'expDlr': '646516',
#       'expWgt': '161183',
#       'hsCd': '0307432090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '22776',
#       'expDlr': '22776',
#       'expWgt': '336',
#       'hsCd': '0307493010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갑오징어[세피아 오피시날리스(Sepia officinalis)ㆍ로시아 마크로소마(Rossia macrosoma)ㆍ세피올라(Sepiola)속]와 오징어[옴마스트레페스(Ommastrephes)속ㆍ로리고(Loligo)속ㆍ노토토다루스(Nototodarus)속ㆍ세피오투디스(Sepioteuthis)속]',
#       'year': '2024.08'},
#      {'balPayments': '38267',
#       'expDlr': '38267',
#       'expWgt': '888',
#       'hsCd': '0307493090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '16007',
#       'expDlr': '16007',
#       'expWgt': '424',
#       'hsCd': '0307511000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '낙지',
#       'year': '2024.08'},
#      {'balPayments': '183',
#       'expDlr': '183',
#       'expWgt': '6',
#       'hsCd': '0307512000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '주꾸미',
#       'year': '2024.08'},
#      {'balPayments': '10304',
#       'expDlr': '10304',
#       'expWgt': '212',
#       'hsCd': '0307519000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '59289',
#       'expDlr': '59289',
#       'expWgt': '4690',
#       'hsCd': '0307521000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '문어',
#       'year': '2024.08'},
#      {'balPayments': '1249',
#       'expDlr': '1249',
#       'expWgt': '32',
#       'hsCd': '0307522000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '낙지',
#       'year': '2024.08'},
#      {'balPayments': '2857',
#       'expDlr': '2857',
#       'expWgt': '12',
#       'hsCd': '0307729000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '1552',
#       'expDlr': '1552',
#       'expWgt': '150',
#       'hsCd': '0307793090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '138796',
#       'expDlr': '138796',
#       'expWgt': '4435',
#       'hsCd': '0307810000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아있거나, 신선하거나 냉장한 전복[할리오티스(Haliotis)속]',
#       'year': '2024.08'},
#      {'balPayments': '106897',
#       'expDlr': '106897',
#       'expWgt': '2537',
#       'hsCd': '0307830000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 전복[할리오티스(Haliotis)속]',
#       'year': '2024.08'},
#      {'balPayments': '-5529',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307913000',
#       'impDlr': '5529',
#       'impWgt': '50',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조개관자',
#       'year': '2024.08'},
#      {'balPayments': '11400',
#       'expDlr': '11400',
#       'expWgt': '733',
#       'hsCd': '0307919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '10200',
#       'expDlr': '10200',
#       'expWgt': '420',
#       'hsCd': '0307929000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '652',
#       'expDlr': '652',
#       'expWgt': '70',
#       'hsCd': '0307994110',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '밀폐용기에 넣은 것',
#       'year': '2024.08'},
#      {'balPayments': '24505',
#       'expDlr': '24505',
#       'expWgt': '706',
#       'hsCd': '0308110000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2024.08'},
#      {'balPayments': '-63964',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308210000',
#       'impDlr': '63964',
#       'impWgt': '479',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2024.08'},
#      {'balPayments': '23782',
#       'expDlr': '23782',
#       'expWgt': '5533',
#       'hsCd': '0308304000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2024.08'},
#      {'balPayments': '17745',
#       'expDlr': '17745',
#       'expWgt': '1468',
#       'hsCd': '0308901019',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '1948',
#       'expDlr': '1948',
#       'expWgt': '63',
#       'hsCd': '0308901090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '31839',
#       'expDlr': '31839',
#       'expWgt': '2715',
#       'hsCd': '0308902010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '우렁쉥이(멍게)',
#       'year': '2024.08'},
#      {'balPayments': '18185',
#       'expDlr': '18185',
#       'expWgt': '5388',
#       'hsCd': '0308902090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '6000',
#       'expDlr': '6000',
#       'expWgt': '30',
#       'hsCd': '0309909000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-3535',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401100000',
#       'impDlr': '3535',
#       'impWgt': '697',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '지방분이 전 중량의 100분의 1 이하인 것',
#       'year': '2024.08'},
#      {'balPayments': '-67',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401200000',
#       'impDlr': '67',
#       'impWgt': '4',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '지방분이 전 중량의 100분의 1 초과 100분의 6 이하인 것',
#       'year': '2024.08'},
#      {'balPayments': '-9697',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401401000',
#       'impDlr': '9697',
#       'impWgt': '1086',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동크림',
#       'year': '2024.08'},
#      {'balPayments': '-79',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0401409000',
#       'impDlr': '79',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-1301960',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402101010',
#       'impDlr': '1301960',
#       'impWgt': '457569',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '탈지(脫脂)분유',
#       'year': '2024.08'},
#      {'balPayments': '-17',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402109000',
#       'impDlr': '17',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-190519',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402211000',
#       'impDlr': '190519',
#       'impWgt': '40025',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전지분유',
#       'year': '2024.08'},
#      {'balPayments': '-207',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402911000',
#       'impDlr': '207',
#       'impWgt': '30',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '무가당연유(無加糖煉乳)',
#       'year': '2024.08'},
#      {'balPayments': '-196',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402991000',
#       'impDlr': '196',
#       'impWgt': '18',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가당연유(加糖煉乳)',
#       'year': '2024.08'},
#      {'balPayments': '812179',
#       'expDlr': '827908',
#       'expWgt': '445088',
#       'hsCd': '0402999000',
#       'impDlr': '15729',
#       'impWgt': '610',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-589925',
#       'expDlr': '5571',
#       'expWgt': '3900',
#       'hsCd': '0403201000',
#       'impDlr': '595496',
#       'impWgt': '149208',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '액체 상태인 것',
#       'year': '2024.08'},
#      {'balPayments': '273582',
#       'expDlr': '273582',
#       'expWgt': '252453',
#       'hsCd': '0403202000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2024.08'},
#      {'balPayments': '5088',
#       'expDlr': '5427',
#       'expWgt': '2426',
#       'hsCd': '0403209000',
#       'impDlr': '339',
#       'impWgt': '28',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-635',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0403901000',
#       'impDlr': '635',
#       'impWgt': '16',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '버터밀크',
#       'year': '2024.08'},
#      {'balPayments': '18492',
#       'expDlr': '18507',
#       'expWgt': '7808',
#       'hsCd': '0403909000',
#       'impDlr': '15',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-544600',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404101011',
#       'impDlr': '544600',
#       'impWgt': '532834',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2024.08'},
#      {'balPayments': '-335414',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404101019',
#       'impDlr': '335414',
#       'impWgt': '286355',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-82579',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102131',
#       'impDlr': '82579',
#       'impWgt': '1000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2024.08'},
#      {'balPayments': '-379553',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102191',
#       'impDlr': '379553',
#       'impWgt': '677985',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2024.08'},
#      {'balPayments': '-25625',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102199',
#       'impDlr': '25625',
#       'impWgt': '2500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
# ...
#       'impWgt': '442218',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-14143783',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2207200000',
#       'impDlr': '14143783',
#       'impWgt': '17804185',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '변성 에틸알코올과 그 밖의 변성 주정(알코올의 용량은 상관없다)',
#       'year': '2024.08'},
#      {'balPayments': '-134',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208201000',
#       'impDlr': '134',
#       'impWgt': '5',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꼬냑',
#       'year': '2024.08'},
#      {'balPayments': '-28160',
#       'expDlr': '34781',
#       'expWgt': '17117',
#       'hsCd': '2208301000',
#       'impDlr': '62941',
#       'impWgt': '13942',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '스카치 위스키',
#       'year': '2024.08'},
#      {'balPayments': '-1809416',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208302000',
#       'impDlr': '1809416',
#       'impWgt': '205199',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '버본 위스키',
#       'year': '2024.08'},
#      {'balPayments': '-69902',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208303000',
#       'impDlr': '69902',
#       'impWgt': '1850',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '라이(rye) 위스키',
#       'year': '2024.08'},
#      {'balPayments': '-141902',
#       'expDlr': '1138',
#       'expWgt': '175',
#       'hsCd': '2208309000',
#       'impDlr': '143040',
#       'impWgt': '5746',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-10765',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208400000',
#       'impDlr': '10765',
#       'impWgt': '4059',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '럼(rum)과 발효된 사탕수수제품을 증류하여 얻은 그 밖의 증류주',
#       'year': '2024.08'},
#      {'balPayments': '-42483',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208500000',
#       'impDlr': '42483',
#       'impWgt': '11308',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '진(gin)과 제네바(geneva)',
#       'year': '2024.08'},
#      {'balPayments': '-160220',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208600000',
#       'impDlr': '160220',
#       'impWgt': '82822',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '보드카',
#       'year': '2024.08'},
#      {'balPayments': '1533421',
#       'expDlr': '1720010',
#       'expWgt': '748422',
#       'hsCd': '2208709000',
#       'impDlr': '186589',
#       'impWgt': '31004',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '693999',
#       'expDlr': '711432',
#       'expWgt': '237111',
#       'hsCd': '2208904000',
#       'impDlr': '17433',
#       'impWgt': '999',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소주',
#       'year': '2024.08'},
#      {'balPayments': '-1407',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2208907000',
#       'impDlr': '1407',
#       'impWgt': '90',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '데낄라',
#       'year': '2024.08'},
#      {'balPayments': '17804',
#       'expDlr': '87989',
#       'expWgt': '40042',
#       'hsCd': '2208909000',
#       'impDlr': '70185',
#       'impWgt': '25203',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '71994',
#       'expDlr': '93758',
#       'expWgt': '55004',
#       'hsCd': '2209001000',
#       'impDlr': '21764',
#       'impWgt': '8536',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '양조식초',
#       'year': '2024.08'},
#      {'balPayments': '-387182',
#       'expDlr': '32537',
#       'expWgt': '15808',
#       'hsCd': '2209009000',
#       'impDlr': '419719',
#       'impWgt': '70369',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-105840',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2301201000',
#       'impDlr': '105840',
#       'impWgt': '47040',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '어류의 고운 가루ㆍ거친 가루ㆍ펠릿(pellet)',
#       'year': '2024.08'},
#      {'balPayments': '-6',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2302300000',
#       'impDlr': '6',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '밀에서 나온 것',
#       'year': '2024.08'},
#      {'balPayments': '-234648',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2303200000',
#       'impDlr': '234648',
#       'impWgt': '1133494',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '비트펄프(beet-pulp), 버개스(bagasse)와 그 밖의 설탕을 제조할 때 생기는 웨이스트(waste)',
#       'year': '2024.08'},
#      {'balPayments': '-27146041',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2303301000',
#       'impDlr': '27146041',
#       'impWgt': '111361258',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사료용',
#       'year': '2024.08'},
#      {'balPayments': '-41689',
#       'expDlr': '248',
#       'expWgt': '7',
#       'hsCd': '2304000000',
#       'impDlr': '41937',
#       'impWgt': '206275',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대두유를 추출할 때 얻는 오일 케이크와 고체 형태의 유박[잘게 부순 것인지 또는 펠릿(pellet) 모양인지에 상관없다]',
#       'year': '2024.08'},
#      {'balPayments': '-690277',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2306909000',
#       'impDlr': '690277',
#       'impWgt': '3694585',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-130273',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2308009000',
#       'impDlr': '130273',
#       'impWgt': '542869',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-3543034',
#       'expDlr': '29539',
#       'expWgt': '285',
#       'hsCd': '2309101000',
#       'impDlr': '3572573',
#       'impWgt': '766476',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개사료',
#       'year': '2024.08'},
#      {'balPayments': '-1868824',
#       'expDlr': '167629',
#       'expWgt': '11631',
#       'hsCd': '2309102000',
#       'impDlr': '2036453',
#       'impWgt': '482865',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고양이 사료',
#       'year': '2024.08'},
#      {'balPayments': '-721',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309901030',
#       'impDlr': '721',
#       'impWgt': '7',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '어류용',
#       'year': '2024.08'},
#      {'balPayments': '-3440317',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309901040',
#       'impDlr': '3440317',
#       'impWgt': '11564030',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '축우용',
#       'year': '2024.08'},
#      {'balPayments': '-1307862',
#       'expDlr': '14',
#       'expWgt': '3',
#       'hsCd': '2309901099',
#       'impDlr': '1307876',
#       'impWgt': '2828942',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-202',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309902010',
#       'impDlr': '202',
#       'impWgt': '4',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '무기물 혹은 광물질(mineral)을 주로 한 것(미량 광물질을 주로 한 것은 제외한다)',
#       'year': '2024.08'},
#      {'balPayments': '-185',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309902020',
#       'impDlr': '185',
#       'impWgt': '16',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '향미제(香味劑)를 주로 한 것',
#       'year': '2024.08'},
#      {'balPayments': '-257604',
#       'expDlr': '32743',
#       'expWgt': '19000',
#       'hsCd': '2309902099',
#       'impDlr': '290347',
#       'impWgt': '58502',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-10709',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309903020',
#       'impDlr': '10709',
#       'impWgt': '108',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '비타민을 주로 한 것',
#       'year': '2024.08'},
#      {'balPayments': '-85450',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309903090',
#       'impDlr': '85450',
#       'impWgt': '1602',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-4590',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309909010',
#       'impDlr': '4590',
#       'impWgt': '105',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '낚시용 떡밥',
#       'year': '2024.08'},
#      {'balPayments': '-824303',
#       'expDlr': '747',
#       'expWgt': '0',
#       'hsCd': '2309909090',
#       'impDlr': '825050',
#       'impWgt': '536043',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-894813',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2401201000',
#       'impDlr': '894813',
#       'impWgt': '88244',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '황색종',
#       'year': '2024.08'},
#      {'balPayments': '-18924',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2401209000',
#       'impDlr': '18924',
#       'impWgt': '1200',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-33610',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2401301000',
#       'impDlr': '33610',
#       'impWgt': '33600',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '잎의 주맥(主脈)',
#       'year': '2024.08'},
#      {'balPayments': '-38759',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2402101000',
#       'impDlr': '38759',
#       'impWgt': '183',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '시가(cigar)',
#       'year': '2024.08'},
#      {'balPayments': '-179',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2402103000',
#       'impDlr': '179',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '시가릴로(cigarillo)',
#       'year': '2024.08'},
#      {'balPayments': '1751',
#       'expDlr': '2205',
#       'expWgt': '23',
#       'hsCd': '2402201000',
#       'impDlr': '454',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '필터담배',
#       'year': '2024.08'},
#      {'balPayments': '-48',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2402209000',
#       'impDlr': '48',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-440',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403191000',
#       'impDlr': '440',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '파이프 담배',
#       'year': '2024.08'},
#      {'balPayments': '-240063',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403911000',
#       'impDlr': '240063',
#       'impWgt': '7287',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '판상엽(板狀葉)',
#       'year': '2024.08'},
#      {'balPayments': '-301',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403994000',
#       'impDlr': '301',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '입안에 머금는 담배(예: 스누스)',
#       'year': '2024.08'},
#      {'balPayments': '-733',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403999000',
#       'impDlr': '733',
#       'impWgt': '16',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-125',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404121000',
#       'impDlr': '125',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전자담배용 용액',
#       'year': '2024.08'},
#      {'balPayments': '-204',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404191000',
#       'impDlr': '204',
#       'impWgt': '3',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '담배대용물을 함유한 것',
#       'year': '2024.08'},
#      {'balPayments': '-869',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404199010',
#       'impDlr': '869',
#       'impWgt': '38',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전자담배용 용액',
#       'year': '2024.08'},
#      {'balPayments': '-10504',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404199090',
#       'impDlr': '10504',
#       'impWgt': '53',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-54',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404910000',
#       'impDlr': '54',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '경구(經口)용',
#       'year': '2024.08'},
#      {'balPayments': '-4122',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2404990000',
#       'impDlr': '4122',
#       'impWgt': '41',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '906772',
#       'expDlr': '906772',
#       'expWgt': '1047531',
#       'hsCd': '2424000000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '이사화물',
#       'year': '2024.08'},
#      {'balPayments': '-28',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2501001010',
#       'impDlr': '28',
#       'impWgt': '1',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '암염(岩鹽)',
#       'year': '2024.08'},
#      {'balPayments': '51522',
#       'expDlr': '51540',
#       'expWgt': '27155',
#       'hsCd': '2501001020',
#       'impDlr': '18',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '천일염',
#       'year': '2024.08'},
#      {'balPayments': '353567',
#       'expDlr': '449966',
#       'expWgt': '101686',
#       'hsCd': '2501009010',
#       'impDlr': '96399',
#       'impWgt': '88672',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '식염',
#       'year': '2024.08'},
#      {'balPayments': '-392587',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2501009020',
#       'impDlr': '392587',
#       'impWgt': '72264',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '순염화나트륨',
#       'year': '2024.08'},
#      {'balPayments': '37229',
#       'expDlr': '98037',
#       'expWgt': '40658',
#       'hsCd': '2501009090',
#       'impDlr': '60808',
#       'impWgt': '4357',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-3103',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2504102000',
#       'impDlr': '3103',
#       'impWgt': '907',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '토상(土狀)흑연',
#       'year': '2024.08'},
#      {'balPayments': '988067',
#       'expDlr': '1003624',
#       'expWgt': '213038',
#       'hsCd': '2504109000',
#       'impDlr': '15557',
#       'impWgt': '486',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-4360',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2504900000',
#       'impDlr': '4360',
#       'impWgt': '143',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2024.08'},
#      {'balPayments': '-98664',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2505100000',
#       'impDlr': '98664',
#       'impWgt': '28322',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '규사',
#       'year': '2024.08'},
#      ...]}}}}

# %%
import pandas as pd

pd.set_option('display.max_rows', 10)
dataset = pd.DataFrame(data["response"]["body"]["items"]["item"])
dataset
# Out:
#        balPayments       expDlr      expWgt        hsCd       impDlr  \
# 0      24423569423  52935826042  8378999837           -  28512256619
# 1            98044        98044         650  0101291000            0
# 2         -1906163            0           0  0105111000      1906163
# 3               85           85           1  0106149000            0
# 4            19581        26734         165  0106191000         7153
# ...            ...          ...         ...         ...          ...
# 32411        -5486            0           0  9705290000         5486
# 32412        -3076            0           0  9705390000         3076
# 32413          390          390           4  9706101000            0
# 32414        -7173           34           0  9706902000         7207
# 32415       -35591            0           0  9706903000        35591
#
#             impWgt statCd statCdCntnKor1 statKor     year
# 0      21394331041      -              -       -       총계
# 1                0     US             미국     경주말  2024.08
# 2             1855     US             미국     번식용  2024.08
# 3                0     US             미국      기타  2024.08
# 4               92     US             미국       개  2024.08
# ...            ...    ...            ...     ...      ...
# 32411            4     US             미국      기타  2024.12
# 32412            2     US             미국      기타  2024.12
# 32413            0     US             미국    도자기류  2024.12
# 32414            2     US             미국     악기류  2024.12
# 32415           40     US             미국      기타  2024.12
#
# [32416 rows x 10 columns]

# %% [markdown]
# ## 무역 데이터 API 응답 필드
#
# | 필드       | 설명                        | 예시                  | 상세 설명       |
# |-------------|---------------------------|----------------------|-------------|
# | year       | 연도                        | 2016.01             | 기간 정보       |
# | statCdCntnKor1 | 국가명                      | 미국                 | 국가명 정보      |
# | statCd     | 국가코드                    | US                   | ISO 국가 코드   |
# | statKor    | 품목명                      | 쇠고기(냉동한 것으로 한정) | 품목명 정보      |
# | hsCd       | HS코드                      | 0202                 | 국제 무역 품목 코드 |
# | expWgt     | 수출중량 (kg)               | 18,003               | 수출된 상품의 중량  |
# | expDlr     | 수출금액 (달러)             | 150,822              | 수출된 상품의 금액  |
# | impWgt     | 수입중량 (kg)               | 14,809,834           | 수입된 상품의 중량  |
# | impDlr     | 수입금액 (달러)             | 93,754,113           | 수입된 상품의 금액  |
# | balPayments | 무역수지 (달러)             | -93,603,291          | 수출금액 - 수입금액 |
