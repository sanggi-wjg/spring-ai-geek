# %%
import os

import requests
import xmltodict
from dotenv import load_dotenv

load_dotenv()

SERVICE_KEY = os.getenv("DATA_GO_KR_SERVICE_KEY")
query_param = {
    "serviceKey": SERVICE_KEY,
    "strtYymm": "202001",
    "endYymm": "202001",
    # "hsSgn": "1001999090",
    "cntyCd": "JP",
}
response = requests.get("http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList", params=query_param)
response.raise_for_status()

data = xmltodict.parse(response.content)

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '-728518120',
#       'expDlr': '2434633574',
#       'expWgt': '1515820077',
#       'hsCd': '-',
#       'impDlr': '3163151694',
#       'impWgt': '1427647941',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '500',
#       'expDlr': '500',
#       'expWgt': '15',
#       'hsCd': '0106191000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '개',
#       'year': '2020.01'},
#      {'balPayments': '-251751',
#       'expDlr': '10989',
#       'expWgt': '265',
#       'hsCd': '0106199000',
#       'impDlr': '262740',
#       'impWgt': '1743',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-1230',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106203000',
#       'impDlr': '1230',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '거북',
#       'year': '2020.01'},
#      {'balPayments': '-2400',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106209000',
#       'impDlr': '2400',
#       'impWgt': '5',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-9540',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106901000',
#       'impDlr': '9540',
#       'impWgt': '5',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '양서류',
#       'year': '2020.01'},
#      {'balPayments': '-4139134',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301992000',
#       'impDlr': '4139134',
#       'impWgt': '459596',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '방어',
#       'year': '2020.01'},
#      {'balPayments': '-1099601',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301994090',
#       'impDlr': '1099601',
#       'impWgt': '149691',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '1589923',
#       'expDlr': '1591760',
#       'expWgt': '151314',
#       'hsCd': '0301995000',
#       'impDlr': '1837',
#       'impWgt': '200',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '붕장어',
#       'year': '2020.01'},
#      {'balPayments': '-82567',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301997000',
#       'impDlr': '82567',
#       'impWgt': '10107',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '먹장어',
#       'year': '2020.01'},
#      {'balPayments': '1600179',
#       'expDlr': '1600179',
#       'expWgt': '159437',
#       'hsCd': '0301998000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '넙치류[플루로넥티대(Pleuronectidae)과ㆍ바디대(Bothidae)과ㆍ사이노글로시대(Cynoglossidae)과ㆍ솔레이대(Soleidae)과ㆍ스코프탈미대(Scophthalmidae)과ㆍ시타리대(Citharidae)과]',
#       'year': '2020.01'},
#      {'balPayments': '-66635',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301999010',
#       'impDlr': '66635',
#       'impWgt': '3778',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '능성어',
#       'year': '2020.01'},
#      {'balPayments': '60861',
#       'expDlr': '60861',
#       'expWgt': '2140',
#       'hsCd': '0301999020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '복어',
#       'year': '2020.01'},
#      {'balPayments': '10800',
#       'expDlr': '10800',
#       'expWgt': '1200',
#       'hsCd': '0301999040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '볼락(적어를 포함한다)',
#       'year': '2020.01'},
#      {'balPayments': '6245',
#       'expDlr': '6245',
#       'expWgt': '1000',
#       'hsCd': '0301999095',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '민어(Argyrosomus japonicus와 Sciaenops ocellatus은 제외한다)',
#       'year': '2020.01'},
#      {'balPayments': '9482',
#       'expDlr': '15056',
#       'expWgt': '4000',
#       'hsCd': '0301999099',
#       'impDlr': '5574',
#       'impWgt': '229',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '258',
#       'expDlr': '258',
#       'expWgt': '8',
#       'hsCd': '0302210000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '넙치[레인하드티우스 히포글러소이데스(Reinhardtius hippoglossoides)ㆍ히포글러서스 히포글러서스(Hippoglossus hippoglossus)ㆍ히포글러서스 스테노레피스(Hippoglossus stenolepis)]',
#       'year': '2020.01'},
#      {'balPayments': '1422',
#       'expDlr': '1422',
#       'expWgt': '744',
#       'hsCd': '0302390000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '9435',
#       'expDlr': '9435',
#       'expWgt': '1079',
#       'hsCd': '0302491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '삼치[스콤버로모러스(Scomberomorus)속]',
#       'year': '2020.01'},
#      {'balPayments': '-46709',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302510000',
#       'impDlr': '46709',
#       'impWgt': '18724',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2020.01'},
#      {'balPayments': '-769332',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302550000',
#       'impDlr': '769332',
#       'impWgt': '224462',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '명태[테라그라 찰코그라마(Theragra chalcogramma)]',
#       'year': '2020.01'},
#      {'balPayments': '-903569',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302820000',
#       'impDlr': '903569',
#       'impWgt': '138137',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '가오리와 홍어[라지대(Rajidae)과]',
#       'year': '2020.01'},
#      {'balPayments': '-63246',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302850000',
#       'impDlr': '63246',
#       'impWgt': '7623',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '돔[스파리대(Sparidae)과]',
#       'year': '2020.01'},
#      {'balPayments': '80543',
#       'expDlr': '82631',
#       'expWgt': '36087',
#       'hsCd': '0302891000',
#       'impDlr': '2088',
#       'impWgt': '126',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '방어',
#       'year': '2020.01'},
#      {'balPayments': '-354031',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302892000',
#       'impDlr': '354031',
#       'impWgt': '60736',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '갈치',
#       'year': '2020.01'},
#      {'balPayments': '50561',
#       'expDlr': '50561',
#       'expWgt': '7689',
#       'hsCd': '0302895000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '학꽁치(Hyporhampus sajori)',
#       'year': '2020.01'},
#      {'balPayments': '-1053',
#       'expDlr': '3675',
#       'expWgt': '920',
#       'hsCd': '0302896000',
#       'impDlr': '4728',
#       'impWgt': '463',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '돔[스파리대(Sparidae)과는 제외한다]',
#       'year': '2020.01'},
#      {'balPayments': '45510',
#       'expDlr': '45510',
#       'expWgt': '1767',
#       'hsCd': '0302899020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '복어',
#       'year': '2020.01'},
#      {'balPayments': '384302',
#       'expDlr': '384302',
#       'expWgt': '119972',
#       'hsCd': '0302899040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '아귀',
#       'year': '2020.01'},
#      {'balPayments': '1165206',
#       'expDlr': '1181641',
#       'expWgt': '58491',
#       'hsCd': '0302899090',
#       'impDlr': '16435',
#       'impWgt': '4793',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '260045',
#       'expDlr': '260045',
#       'expWgt': '81181',
#       'hsCd': '0303410000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '날개다랑어나 긴지느러미 다랑어[터너스 알라룽가(Thunnus alalunga)]',
#       'year': '2020.01'},
#      {'balPayments': '555329',
#       'expDlr': '555329',
#       'expWgt': '112073',
#       'hsCd': '0303420000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '황다랑어[터너스 알바카레스(Thunnus albacares)]',
#       'year': '2020.01'},
#      {'balPayments': '810248',
#       'expDlr': '812876',
#       'expWgt': '120126',
#       'hsCd': '0303440000',
#       'impDlr': '2628',
#       'impWgt': '375',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '눈다랑어[터너스 오베서스(Thunnus obesus)]',
#       'year': '2020.01'},
#      {'balPayments': '13443',
#       'expDlr': '13443',
#       'expWgt': '695',
#       'hsCd': '0303451000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '대서양 참다랑어[터너스 티너스(Thunnus thynnus)]',
#       'year': '2020.01'},
#      {'balPayments': '2448131',
#       'expDlr': '2650791',
#       'expWgt': '198054',
#       'hsCd': '0303460000',
#       'impDlr': '202660',
#       'impWgt': '22751',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '남방 참다랑어[터너스 맥코이(Thunnus maccoyii)]',
#       'year': '2020.01'},
#      {'balPayments': '-71311',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303530000',
#       'impDlr': '71311',
#       'impWgt': '73500',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '정어리[사르디나 필차르두스(Sardina pilchardus)ㆍ사르디노프스(Sardinops)속], 사르디넬라[사르디넬라(Sardinella)속], 브리스링(brisling)이나 스프랫(sprats)[스프라투스 스프라투스(Sprattus sprattus)]',
#       'year': '2020.01'},
#      {'balPayments': '113480',
#       'expDlr': '113480',
#       'expWgt': '31116',
#       'hsCd': '0303540000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '고등어[스콤버 스콤브루스(Scomber scombrus)ㆍ스콤버 오스트랄라시쿠스(Scomber australasicus)ㆍ스콤버 자포니쿠스(Scomber japonicus)]',
#       'year': '2020.01'},
#      {'balPayments': '1151429',
#       'expDlr': '1151429',
#       'expWgt': '525620',
#       'hsCd': '0303550000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '전갱이[트라커러스(Trachurus)속]',
#       'year': '2020.01'},
#      {'balPayments': '441473',
#       'expDlr': '441473',
#       'expWgt': '82566',
#       'hsCd': '0303570000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '황새치[자이피어스 글래디어스(Xiphias gladius)]',
#       'year': '2020.01'},
#      {'balPayments': '847466',
#       'expDlr': '847466',
#       'expWgt': '184764',
#       'hsCd': '0303591000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '삼치[스콤버로모러스(Scomberomorus)속]',
#       'year': '2020.01'},
#      {'balPayments': '113041',
#       'expDlr': '113041',
#       'expWgt': '61204',
#       'hsCd': '0303599000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-15887',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303810000',
#       'impDlr': '15887',
#       'impWgt': '4605',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '곱상어와 그 밖의 상어',
#       'year': '2020.01'},
#      {'balPayments': '-66320',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303822000',
#       'impDlr': '66320',
#       'impWgt': '8090',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '홍어',
#       'year': '2020.01'},
#      {'balPayments': '108415',
#       'expDlr': '108415',
#       'expWgt': '15553',
#       'hsCd': '0303830000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '이빨고기[디소스티쿠스(Dissostichus)속]',
#       'year': '2020.01'},
#      {'balPayments': '32770',
#       'expDlr': '32770',
#       'expWgt': '2307',
#       'hsCd': '0303840000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '농어[디센트라르쿠스(Dicentrarchus)속]',
#       'year': '2020.01'},
#      {'balPayments': '3',
#       'expDlr': '3',
#       'expWgt': '8',
#       'hsCd': '0303892000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '갈치',
#       'year': '2020.01'},
#      {'balPayments': '38436',
#       'expDlr': '57534',
#       'expWgt': '23324',
#       'hsCd': '0303893090',
#       'impDlr': '19098',
#       'impWgt': '2200',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '36008',
#       'expDlr': '36008',
#       'expWgt': '5760',
#       'hsCd': '0303894000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '붕장어',
#       'year': '2020.01'},
#      {'balPayments': '432',
#       'expDlr': '432',
#       'expWgt': '70',
#       'hsCd': '0303895000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '조기',
#       'year': '2020.01'},
#      {'balPayments': '-164',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303898000',
#       'impDlr': '164',
#       'impWgt': '105',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '복어',
#       'year': '2020.01'},
#      {'balPayments': '4762',
#       'expDlr': '4762',
#       'expWgt': '876',
#       'hsCd': '0303899030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '달고기',
#       'year': '2020.01'},
#      {'balPayments': '21026',
#       'expDlr': '21026',
#       'expWgt': '3020',
#       'hsCd': '0303899050',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '볼낙(적어를 포함한다)',
#       'year': '2020.01'},
#      {'balPayments': '223069',
#       'expDlr': '282720',
#       'expWgt': '199796',
#       'hsCd': '0303899099',
#       'impDlr': '59651',
#       'impWgt': '16283',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '26097',
#       'expDlr': '26131',
#       'expWgt': '5750',
#       'hsCd': '0303912010',
#       'impDlr': '34',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '명란',
#       'year': '2020.01'},
#      {'balPayments': '-1130',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303912090',
#       'impDlr': '1130',
#       'impWgt': '6',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '1350802',
#       'expDlr': '1350802',
#       'expWgt': '112561',
#       'hsCd': '0304491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '붕장어',
#       'year': '2020.01'},
#      {'balPayments': '817821',
#       'expDlr': '941592',
#       'expWgt': '115957',
#       'hsCd': '0304840000',
#       'impDlr': '123771',
#       'impWgt': '6714',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '황새치[자이피어스 글래디어스(Xiphias gladius)]',
#       'year': '2020.01'},
#      {'balPayments': '8388332',
#       'expDlr': '8495092',
#       'expWgt': '848781',
#       'hsCd': '0304879000',
#       'impDlr': '106760',
#       'impWgt': '10058',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '650263',
#       'expDlr': '650263',
#       'expWgt': '54567',
#       'hsCd': '0304891000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '붕장어의 것',
#       'year': '2020.01'},
#      {'balPayments': '200665',
#       'expDlr': '431264',
#       'expWgt': '49075',
#       'hsCd': '0304899000',
#       'impDlr': '230599',
#       'impWgt': '15873',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '231912',
#       'expDlr': '231912',
#       'expWgt': '26000',
#       'hsCd': '0304919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '24',
#       'expDlr': '24',
#       'expWgt': '4',
#       'hsCd': '0304991000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '냉동 연육',
#       'year': '2020.01'},
#      {'balPayments': '258318',
#       'expDlr': '258318',
#       'expWgt': '25418',
#       'hsCd': '0304999000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-43901',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305499000',
#       'impDlr': '43901',
#       'impWgt': '2108',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-58',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305510000',
#       'impDlr': '58',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '대구[가두스 모르화(Gadus morhua)ㆍ가두스 오각(Gadus ogac)ㆍ가두스 마크로세팔루스(Gadus macrocephalus)]',
#       'year': '2020.01'},
#      {'balPayments': '-182',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305699000',
#       'impDlr': '182',
#       'impWgt': '9',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '4125',
#       'expDlr': '4125',
#       'expWgt': '500',
#       'hsCd': '0306141090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '2031',
#       'expDlr': '2031',
#       'expWgt': '305',
#       'hsCd': '0306143090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '287812',
#       'expDlr': '287812',
#       'expWgt': '118326',
#       'hsCd': '0306149090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-25649',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306171090',
#       'impDlr': '25649',
#       'impWgt': '200',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '16212',
#       'expDlr': '30100',
#       'expWgt': '600',
#       'hsCd': '0306339000',
#       'impDlr': '13888',
#       'impWgt': '1365',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '151090',
#       'expDlr': '151090',
#       'expWgt': '17570',
#       'hsCd': '0307111090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '200682',
#       'expDlr': '200682',
#       'expWgt': '24390',
#       'hsCd': '0307119000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '259846',
#       'expDlr': '259846',
#       'expWgt': '37756',
#       'hsCd': '0307120000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '냉동한 것',
#       'year': '2020.01'},
#      {'balPayments': '-1100751',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307210000',
#       'impDlr': '1100751',
#       'impWgt': '328084',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2020.01'},
#      {'balPayments': '-89879',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307220000',
#       'impDlr': '89879',
#       'impWgt': '14830',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '냉동한 것',
#       'year': '2020.01'},
#      {'balPayments': '-3222',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307292000',
#       'impDlr': '3222',
#       'impWgt': '20',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '건조한 것',
#       'year': '2020.01'},
#      {'balPayments': '98776',
#       'expDlr': '98776',
#       'expWgt': '9288',
#       'hsCd': '0307432090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '6585',
#       'expDlr': '6585',
#       'expWgt': '905',
#       'hsCd': '0307511000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '낙지',
#       'year': '2020.01'},
#      {'balPayments': '481158',
#       'expDlr': '481158',
#       'expWgt': '33019',
#       'hsCd': '0307712090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '358120',
#       'expDlr': '518274',
#       'expWgt': '51187',
#       'hsCd': '0307719000',
#       'impDlr': '160154',
#       'impWgt': '38672',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '2892924',
#       'expDlr': '2892924',
#       'expWgt': '100190',
#       'hsCd': '0307810000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '살아있거나, 신선하거나 냉장한 전복[할리오티스(Haliotis)속]',
#       'year': '2020.01'},
#      {'balPayments': '303496',
#       'expDlr': '303496',
#       'expWgt': '80970',
#       'hsCd': '0307911000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '소라',
#       'year': '2020.01'},
#      {'balPayments': '164171',
#       'expDlr': '164171',
#       'expWgt': '6948',
#       'hsCd': '0307913000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '조개관자',
#       'year': '2020.01'},
#      {'balPayments': '22936',
#       'expDlr': '22936',
#       'expWgt': '3196',
#       'hsCd': '0307919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-63986',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307921000',
#       'impDlr': '63986',
#       'impWgt': '3000',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '조개관자',
#       'year': '2020.01'},
#      {'balPayments': '-60',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307992900',
#       'impDlr': '60',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-3439',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308110000',
#       'impDlr': '3439',
#       'impWgt': '270',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '살아 있는 것, 신선한 것, 냉장한 것',
#       'year': '2020.01'},
#      {'balPayments': '637565',
#       'expDlr': '637565',
#       'expWgt': '7708',
#       'hsCd': '0308293000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '염장이나 염수장한 것',
#       'year': '2020.01'},
#      {'balPayments': '-1073650',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0308901019',
#       'impDlr': '1073650',
#       'impWgt': '509813',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '1',
#       'expDlr': '1',
#       'expWgt': '1',
#       'hsCd': '0402101010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '탈지(脫脂)분유',
#       'year': '2020.01'},
#      {'balPayments': '909',
#       'expDlr': '909',
#       'expWgt': '196',
#       'hsCd': '0402101090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0403109000',
#       'impDlr': '152',
#       'impWgt': '4',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-4469',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404901000',
#       'impDlr': '4469',
#       'impWgt': '150',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '지방분이 전 중량의 100분의 1.5 이하인 것',
#       'year': '2020.01'},
#      {'balPayments': '1035066',
#       'expDlr': '1035066',
#       'expWgt': '290957',
#       'hsCd': '0404902000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '지방분이 전 중량의 100분의 1.5를 초과하는 것',
#       'year': '2020.01'},
#      {'balPayments': '-215',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0405100000',
#       'impDlr': '215',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '버터',
#       'year': '2020.01'},
#      {'balPayments': '-108',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101090',
#       'impDlr': '108',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-16',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406901000',
#       'impDlr': '16',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '체더 치즈(Cheddar cheese)',
#       'year': '2020.01'},
#      {'balPayments': '-1363',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406909000',
#       'impDlr': '1363',
#       'impWgt': '58',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-106',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0409000000',
#       'impDlr': '106',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '천연꿀',
#       'year': '2020.01'},
#      {'balPayments': '-124',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0410003000',
#       'impDlr': '124',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '로열젤리',
#       'year': '2020.01'},
#      {'balPayments': '37392',
#       'expDlr': '37392',
#       'expWgt': '3067',
#       'hsCd': '0410009000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-20',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0507109000',
#       'impDlr': '20',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-10',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0508001000',
#       'impDlr': '10',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '산호',
#       'year': '2020.01'},
#      {'balPayments': '-16878',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0508002090',
#       'impDlr': '16878',
#       'impWgt': '115410',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '122340',
#       'expDlr': '122340',
#       'expWgt': '9458',
#       'hsCd': '0508009000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '127397',
#       'expDlr': '127397',
#       'expWgt': '8921',
#       'hsCd': '0511919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-43',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511992090',
#       'impDlr': '43',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '105961',
#       'expDlr': '105961',
#       'expWgt': '570800',
#       'hsCd': '0511999040',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '원피의 페어링(paring)과 이와 유사한 웨이스트(waste)',
#       'year': '2020.01'},
#      {'balPayments': '17816',
#       'expDlr': '17816',
#       'expWgt': '1005',
#       'hsCd': '0511999090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-237',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0601209090',
#       'impDlr': '237',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-348',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602109000',
#       'impDlr': '348',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-4981',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602300000',
#       'impDlr': '4981',
#       'impWgt': '244',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '철쭉과 진달래속의 식물(접목했는지에 상관없다)',
#       'year': '2020.01'},
#      {'balPayments': '-2423',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602901010',
#       'impDlr': '2423',
#       'impWgt': '37',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '난초',
#       'year': '2020.01'},
#      {'balPayments': '-25475',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602901090',
#       'impDlr': '25475',
#       'impWgt': '882',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-247',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602902069',
#       'impDlr': '247',
#       'impWgt': '34',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-17968',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602902099',
#       'impDlr': '17968',
#       'impWgt': '744',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-689',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602909040',
#       'impDlr': '689',
#       'impWgt': '147',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '버섯의 종균(種菌)',
#       'year': '2020.01'},
#      {'balPayments': '-9622',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0602909090',
#       'impDlr': '9622',
#       'impWgt': '298',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '118501',
#       'expDlr': '121125',
#       'expWgt': '27659',
#       'hsCd': '0603110000',
#       'impDlr': '2624',
#       'impWgt': '85',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '장미',
#       'year': '2020.01'},
#      {'balPayments': '105925',
#       'expDlr': '105925',
#       'expWgt': '19087',
#       'hsCd': '0603131000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '심비디움(Cymbidiums)',
#       'year': '2020.01'},
#      {'balPayments': '51889',
#       'expDlr': '51889',
#       'expWgt': '4370',
#       'hsCd': '0603150000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '백합[릴리움(Lilium)속]',
#       'year': '2020.01'},
#      {'balPayments': '45223',
#       'expDlr': '45223',
#       'expWgt': '1550',
#       'hsCd': '0603191000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '튤립',
#       'year': '2020.01'},
#      {'balPayments': '60258',
#       'expDlr': '83796',
#       'expWgt': '1250',
#       'hsCd': '0603199000',
#       'impDlr': '23538',
#       'impWgt': '749',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-26131',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0603900000',
#       'impDlr': '26131',
#       'impWgt': '307',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-4693',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0604201000',
#       'impDlr': '4693',
#       'impWgt': '12',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '이끼와 지의(地衣)',
#       'year': '2020.01'},
#      {'balPayments': '918716',
#       'expDlr': '918716',
#       'expWgt': '333120',
#       'hsCd': '0702000000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '토마토(신선한 것이나 냉장한 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '42899',
#       'expDlr': '42899',
#       'expWgt': '37200',
#       'hsCd': '0705110000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '결구(結球) 상추',
#       'year': '2020.01'},
#      {'balPayments': '-12852',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0706902000',
#       'impDlr': '12852',
#       'impWgt': '110',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '고추냉이와 겨자무',
#       'year': '2020.01'},
#      {'balPayments': '17303',
#       'expDlr': '17303',
#       'expWgt': '4430',
#       'hsCd': '0707000000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '오이류(신선한 것이나 냉장한 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '6243',
#       'expDlr': '6243',
#       'expWgt': '2600',
#       'hsCd': '0709300000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '가지(에그플랜트)',
#       'year': '2020.01'},
#      {'balPayments': '34681',
#       'expDlr': '34681',
#       'expWgt': '12002',
#       'hsCd': '0709594010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '큰느타리버섯',
#       'year': '2020.01'},
#      {'balPayments': '6925515',
#       'expDlr': '6925515',
#       'expWgt': '1546844',
#       'hsCd': '0709601000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '단고추(벨타입으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '122190',
#       'expDlr': '122190',
#       'expWgt': '18501',
#       'hsCd': '0709609000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '2403',
#       'expDlr': '2403',
#       'expWgt': '1499',
#       'hsCd': '0709930000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '호박류[쿠쿠르비타(Cucurbita)속]',
#       'year': '2020.01'},
#      {'balPayments': '27905',
#       'expDlr': '27905',
#       'expWgt': '2412',
#       'hsCd': '0709999000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '8186',
#       'expDlr': '8186',
#       'expWgt': '603',
#       'hsCd': '0710802000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '마늘',
#       'year': '2020.01'},
#      {'balPayments': '118',
#       'expDlr': '118',
#       'expWgt': '70',
#       'hsCd': '0711905099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-242',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0711909000',
#       'impDlr': '242',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '채소류의 혼합물',
#       'year': '2020.01'},
#      {'balPayments': '11509',
#       'expDlr': '11509',
#       'expWgt': '2525',
#       'hsCd': '0712902050',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '호박',
#       'year': '2020.01'},
#      {'balPayments': '56142',
#       'expDlr': '56142',
#       'expWgt': '4820',
#       'hsCd': '0712902099',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-35',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0713329000',
#       'impDlr': '35',
#       'impWgt': '6',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-2',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0802120000',
#       'impDlr': '2',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '껍데기를 벗긴 것',
#       'year': '2020.01'},
#      {'balPayments': '9514',
#       'expDlr': '9514',
#       'expWgt': '1682',
#       'hsCd': '0807190000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '36',
#       'expDlr': '36',
#       'expWgt': '8',
#       'hsCd': '0810100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '초본류 딸기',
#       'year': '2020.01'},
#      {'balPayments': '258383',
#       'expDlr': '258383',
#       'expWgt': '93132',
#       'hsCd': '0810500000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '키위프루트(kiwifruit)',
#       'year': '2020.01'},
#      {'balPayments': '94939',
#       'expDlr': '94939',
#       'expWgt': '30997',
#       'hsCd': '0811100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '초본류 딸기',
#       'year': '2020.01'},
#      {'balPayments': '18090',
#       'expDlr': '18090',
#       'expWgt': '2800',
#       'hsCd': '0811901000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '밤',
#       'year': '2020.01'},
#      {'balPayments': '265446',
#       'expDlr': '265446',
#       'expWgt': '17728',
#       'hsCd': '0813401000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '감',
#       'year': '2020.01'},
#      {'balPayments': '6153',
#       'expDlr': '6153',
#       'expWgt': '144',
#       'hsCd': '0813402000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '대추',
#       'year': '2020.01'},
#      {'balPayments': '1921',
#       'expDlr': '1921',
#       'expWgt': '20',
#       'hsCd': '0813409000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '5122',
#       'expDlr': '5122',
#       'expWgt': '109',
#       'hsCd': '0813500000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '이 류의 견과류나 건조한 과실의 혼합물',
#       'year': '2020.01'},
#      {'balPayments': '4425',
#       'expDlr': '4435',
#       'expWgt': '180',
#       'hsCd': '0901110000',
#       'impDlr': '10',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '카페인을 제거하지 않은 것',
#       'year': '2020.01'},
#      {'balPayments': '-570304',
#       'expDlr': '661',
#       'expWgt': '21',
#       'hsCd': '0901210000',
#       'impDlr': '570965',
#       'impWgt': '70835',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '카페인을 제거하지 않은 것',
#       'year': '2020.01'},
#      {'balPayments': '-57',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0901220000',
#       'impDlr': '57',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '카페인을 제거한 것',
#       'year': '2020.01'},
#      {'balPayments': '56',
#       'expDlr': '56',
#       'expWgt': '5',
#       'hsCd': '0901902000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '커피를 함유한 커피 대용물',
#       'year': '2020.01'},
#      {'balPayments': '-4035',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0902100000',
#       'impDlr': '4035',
#       'impWgt': '147',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '녹차(발효하지 않은 것으로서 내용물의 무게가 3킬로그램 이하로 내용물에 직접 접하여 포장된 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '1200',
#       'expDlr': '1200',
#       'expWgt': '1',
#       'hsCd': '0902200000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '그 밖의 녹차(발효하지 않은 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '-163',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0902300000',
#       'impDlr': '163',
#       'impWgt': '23',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '홍차(발효차)와 부분 발효차(내용물의 무게가 3킬로그램 이하로 내용물에 직접 접하여 포장된 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '-8639',
#       'expDlr': '1134',
#       'expWgt': '915',
#       'hsCd': '0902400000',
#       'impDlr': '9773',
#       'impWgt': '237',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '그 밖의 홍차(발효차)와 그 밖의 부분 발효차',
#       'year': '2020.01'},
#      {'balPayments': '-6891',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0904120000',
#       'impDlr': '6891',
#       'impWgt': '260',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '부수거나 잘게 부순 것',
#       'year': '2020.01'},
#      {'balPayments': '283314',
#       'expDlr': '283314',
#       'expWgt': '44200',
#       'hsCd': '0904220000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '부수거나 잘게 부순 것',
#       'year': '2020.01'},
#      {'balPayments': '-105',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0906201000',
#       'impDlr': '105',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '계피',
#       'year': '2020.01'},
#      {'balPayments': '-26',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0910300000',
#       'impDlr': '26',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '심황[강황(薑黃)]',
#       'year': '2020.01'},
#      {'balPayments': '-15',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1003901000',
#       'impDlr': '15',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '맥주보리',
#       'year': '2020.01'},
#      {'balPayments': '-1759',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1101001000',
#       'impDlr': '1759',
#       'impWgt': '1070',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '밀가루',
#       'year': '2020.01'},
#      {'balPayments': '-249',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1102901000',
#       'impDlr': '249',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '보릿가루',
#       'year': '2020.01'},
#      {'balPayments': '12',
#       'expDlr': '12',
#       'expWgt': '1',
#       'hsCd': '1102902000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '쌀가루',
#       'year': '2020.01'},
#      {'balPayments': '30',
#       'expDlr': '30',
#       'expWgt': '2',
#       'hsCd': '1103193000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '쌀로 만든 것',
#       'year': '2020.01'},
#      {'balPayments': '6315',
#       'expDlr': '6315',
#       'expWgt': '800',
#       'hsCd': '1103199000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-56',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1202420000',
#       'impDlr': '56',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '꼬투리를 벗긴 것(부수었는지에 상관없다)',
#       'year': '2020.01'},
#      {'balPayments': '-11859',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1206000000',
#       'impDlr': '11859',
#       'impWgt': '51',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '해바라기씨(부수었는지에 상관없다)',
#       'year': '2020.01'},
#      {'balPayments': '63930',
#       'expDlr': '63930',
#       'expWgt': '185156',
#       'hsCd': '1207291000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '사료용',
#       'year': '2020.01'},
#      {'balPayments': '-51',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1207300000',
#       'impDlr': '51',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '피마자',
#       'year': '2020.01'},
#      {'balPayments': '-2122',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1207500000',
#       'impDlr': '2122',
#       'impWgt': '160',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '겨자씨',
#       'year': '2020.01'},
#      {'balPayments': '-1381',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1207700000',
#       'impDlr': '1381',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '멜론 종자',
#       'year': '2020.01'},
#      {'balPayments': '534',
#       'expDlr': '534',
#       'expWgt': '56',
#       'hsCd': '1207991000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '들깨',
#       'year': '2020.01'},
#      {'balPayments': '-3961',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1208100000',
#       'impDlr': '3961',
#       'impWgt': '510',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '대두로 만든 것',
#       'year': '2020.01'},
#      {'balPayments': '-114150',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209300000',
#       'impDlr': '114150',
#       'impWgt': '27',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '화초용 초본(草本)식물의 종자',
#       'year': '2020.01'},
#      {'balPayments': '24584',
#       'expDlr': '24584',
#       'expWgt': '108',
#       'hsCd': '1209911010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '양파 종자',
#       'year': '2020.01'},
#      {'balPayments': '-59024',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209911090',
#       'impDlr': '59024',
#       'impWgt': '500',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '177147',
#       'expDlr': '177147',
#       'expWgt': '1000',
#       'hsCd': '1209912000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '무 종자',
#       'year': '2020.01'},
#      {'balPayments': '140648',
#       'expDlr': '141137',
#       'expWgt': '471',
#       'hsCd': '1209913000',
#       'impDlr': '489',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '고추ㆍ단고추류(Capsicum annuum)의 종자',
#       'year': '2020.01'},
#      {'balPayments': '-954',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209914000',
#       'impDlr': '954',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
# ...
#      {'balPayments': '-3104',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2907291000',
#       'impDlr': '3104',
#       'impWgt': '10',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '카테콜',
#       'year': '2020.01'},
#      {'balPayments': '190947',
#       'expDlr': '551205',
#       'expWgt': '165270',
#       'hsCd': '2907299000',
#       'impDlr': '360258',
#       'impWgt': '37565',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-4843',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2908191000',
#       'impDlr': '4843',
#       'impWgt': '460',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '클로로페놀(펜타클로로페놀은 제외한다)',
#       'year': '2020.01'},
#      {'balPayments': '-652575',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2908192000',
#       'impDlr': '652575',
#       'impWgt': '180000',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '테트라브로모비스페놀에이',
#       'year': '2020.01'},
#      {'balPayments': '-2912',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2908199000',
#       'impDlr': '2912',
#       'impWgt': '29',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-1369',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2908999000',
#       'impDlr': '1369',
#       'impWgt': '57',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-7263',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909110000',
#       'impDlr': '7263',
#       'impWgt': '1460',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '디에틸에테르',
#       'year': '2020.01'},
#      {'balPayments': '-282490',
#       'expDlr': '35',
#       'expWgt': '1',
#       'hsCd': '2909199000',
#       'impDlr': '282525',
#       'impWgt': '37493',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-16798',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909200000',
#       'impDlr': '16798',
#       'impWgt': '703',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '포화지환식ㆍ불포화지환식ㆍ시클로테르펜에테르와 이들의 할로겐화유도체ㆍ술폰화유도체ㆍ니트로화유도체ㆍ니트로소화유도체',
#       'year': '2020.01'},
#      {'balPayments': '-20',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909303000',
#       'impDlr': '20',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '디페닐 에테르',
#       'year': '2020.01'},
#      {'balPayments': '13350',
#       'expDlr': '13350',
#       'expWgt': '2160',
#       'hsCd': '2909305000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '데카브로모디페닐 옥사이드(데카브로모디페닐 에테르)',
#       'year': '2020.01'},
#      {'balPayments': '-758247',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909309010',
#       'impDlr': '758247',
#       'impWgt': '17200',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '농약원제(農藥原劑)(｢농약관리법｣에 따라 등록된 것으로 한정한다)',
#       'year': '2020.01'},
#      {'balPayments': '-540094',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909309090',
#       'impDlr': '540094',
#       'impWgt': '2372',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-13',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909410000',
#       'impDlr': '13',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': "2,2'-옥시디에탄올(디에틸렌글리콜, 디골)",
#       'year': '2020.01'},
#      {'balPayments': '-23324',
#       'expDlr': '34384',
#       'expWgt': '360',
#       'hsCd': '2909430000',
#       'impDlr': '57708',
#       'impWgt': '9363',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '에틸렌글리콜의 모노부틸에테르와 디에틸렌글리콜의 모노부틸에테르',
#       'year': '2020.01'},
#      {'balPayments': '264586',
#       'expDlr': '318348',
#       'expWgt': '80570',
#       'hsCd': '2909449000',
#       'impDlr': '53762',
#       'impWgt': '14826',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-27220',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909491000',
#       'impDlr': '27220',
#       'impWgt': '18000',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '트리에틸렌 글리콜',
#       'year': '2020.01'},
#      {'balPayments': '-961362',
#       'expDlr': '193236',
#       'expWgt': '90006',
#       'hsCd': '2909499000',
#       'impDlr': '1154598',
#       'impWgt': '115854',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-89',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909502000',
#       'impDlr': '89',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '이소오이게놀',
#       'year': '2020.01'},
#      {'balPayments': '60',
#       'expDlr': '60',
#       'expWgt': '0',
#       'hsCd': '2909503000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '에테르알코올페놀',
#       'year': '2020.01'},
#      {'balPayments': '-6656',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909509000',
#       'impDlr': '6656',
#       'impWgt': '10',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-41350',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909602000',
#       'impDlr': '41350',
#       'impWgt': '10286',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '디쿠밀퍼록사이드',
#       'year': '2020.01'},
#      {'balPayments': '-354575',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2909609000',
#       'impDlr': '354575',
#       'impWgt': '104572',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '174',
#       'expDlr': '174',
#       'expWgt': '12',
#       'hsCd': '2910100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '옥시란(에틸렌옥사이드)',
#       'year': '2020.01'},
#      {'balPayments': '-20',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2910200000',
#       'impDlr': '20',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '메틸옥시란(프로필렌옥사이드)',
#       'year': '2020.01'},
#      {'balPayments': '-5460892',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2910300000',
#       'impDlr': '5460892',
#       'impWgt': '3521240',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '1-클로로-2,3-에폭시프로판(에피클로로히드린)',
#       'year': '2020.01'},
#      {'balPayments': '164809',
#       'expDlr': '226865',
#       'expWgt': '30403',
#       'hsCd': '2910900000',
#       'impDlr': '62056',
#       'impWgt': '1248',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-109',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2911001010',
#       'impDlr': '109',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '아세탈',
#       'year': '2020.01'},
#      {'balPayments': '85716',
#       'expDlr': '89130',
#       'expWgt': '32000',
#       'hsCd': '2911009000',
#       'impDlr': '3414',
#       'impWgt': '607',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-111',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912110000',
#       'impDlr': '111',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '메탄알(포름알데히드)',
#       'year': '2020.01'},
#      {'balPayments': '-120',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912120000',
#       'impDlr': '120',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '에탄알(아세트알데히드)',
#       'year': '2020.01'},
#      {'balPayments': '-328',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912193000',
#       'impDlr': '328',
#       'impWgt': '8',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '부탄알(부티르알데히드, 노르말-이성체)',
#       'year': '2020.01'},
#      {'balPayments': '-5014',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912199000',
#       'impDlr': '5014',
#       'impWgt': '258',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-933',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912299000',
#       'impDlr': '933',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-39',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912410000',
#       'impDlr': '39',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '바닐린(4-히드록시-3-메톡시벤즈알데히드)',
#       'year': '2020.01'},
#      {'balPayments': '-12',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912420000',
#       'impDlr': '12',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '에틸바닐린(3-에톡시-4-히드록시벤즈알데히드)',
#       'year': '2020.01'},
#      {'balPayments': '-3323',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912499000',
#       'impDlr': '3323',
#       'impWgt': '6',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-640',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2912600000',
#       'impDlr': '640',
#       'impWgt': '21',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '파라포름알데히드',
#       'year': '2020.01'},
#      {'balPayments': '-1849',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2913000000',
#       'impDlr': '1849',
#       'impWgt': '7',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '제2912호의 물품의 할로겐화유도체ㆍ술폰화유도체ㆍ니트로화유도체ㆍ니트로소화유도체',
#       'year': '2020.01'},
#      {'balPayments': '-1197469',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914110000',
#       'impDlr': '1197469',
#       'impWgt': '2003083',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '아세톤',
#       'year': '2020.01'},
#      {'balPayments': '-4190324',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914120000',
#       'impDlr': '4190324',
#       'impWgt': '4051441',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '부탄온(메틸에틸케톤)',
#       'year': '2020.01'},
#      {'balPayments': '-39',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914130000',
#       'impDlr': '39',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '4-메틸펜탄-2-온(메틸이소부틸케톤)',
#       'year': '2020.01'},
#      {'balPayments': '-143161',
#       'expDlr': '53245',
#       'expWgt': '60',
#       'hsCd': '2914199000',
#       'impDlr': '196406',
#       'impWgt': '16698',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-138993',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914221000',
#       'impDlr': '138993',
#       'impWgt': '38898',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '시클로헥사논',
#       'year': '2020.01'},
#      {'balPayments': '-2459',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914299000',
#       'impDlr': '2459',
#       'impWgt': '10',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-4027',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914390000',
#       'impDlr': '4027',
#       'impWgt': '18',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-22006',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914401000',
#       'impDlr': '22006',
#       'impWgt': '15470',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '디아세톤 알코올(4-히드록시-4-메틸펜탄-2-온)',
#       'year': '2020.01'},
#      {'balPayments': '62454',
#       'expDlr': '62953',
#       'expWgt': '15200',
#       'hsCd': '2914409000',
#       'impDlr': '499',
#       'impWgt': '3',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '270068',
#       'expDlr': '272113',
#       'expWgt': '7860',
#       'hsCd': '2914509000',
#       'impDlr': '2045',
#       'impWgt': '9',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-13',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914610000',
#       'impDlr': '13',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '안트라퀴논',
#       'year': '2020.01'},
#      {'balPayments': '-152741',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914691000',
#       'impDlr': '152741',
#       'impWgt': '10000',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '안트라퀴논의 유도체',
#       'year': '2020.01'},
#      {'balPayments': '-74151',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914699090',
#       'impDlr': '74151',
#       'impWgt': '226',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-5120',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2914799000',
#       'impDlr': '5120',
#       'impWgt': '16',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-431',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915110000',
#       'impDlr': '431',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '포름산',
#       'year': '2020.01'},
#      {'balPayments': '-11286',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915121000',
#       'impDlr': '11286',
#       'impWgt': '5000',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '포름산 칼슘',
#       'year': '2020.01'},
#      {'balPayments': '164',
#       'expDlr': '164',
#       'expWgt': '0',
#       'hsCd': '2915129000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '-14',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915131000',
#       'impDlr': '14',
#       'impWgt': '2',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '포름산 메틸',
#       'year': '2020.01'},
#      {'balPayments': '77871',
#       'expDlr': '77871',
#       'expWgt': '30400',
#       'hsCd': '2915132000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '2-에틸헥실클로로포메이트',
#       'year': '2020.01'},
#      {'balPayments': '-55551',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915139000',
#       'impDlr': '55551',
#       'impWgt': '5801',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '기타',
#       'year': '2020.01'},
#      {'balPayments': '2722638',
#       'expDlr': '2725791',
#       'expWgt': '9236457',
#       'hsCd': '2915210000',
#       'impDlr': '3153',
#       'impWgt': '544',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '초산',
#       'year': '2020.01'},
#      {'balPayments': '-39',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915291000',
#       'impDlr': '39',
#       'impWgt': '1',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '초산칼슘',
#       'year': '2020.01'},
#      {'balPayments': '-29460',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2915292000',
#       'impDlr': '29460',
#       'impWgt': '26060',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'statKor': '초산나트륨',
#       'year': '2020.01'},
#      ...]}}}}

# %%
import pandas as pd

pd.set_option('display.max_rows', 10)
dataset = pd.DataFrame(data["response"]["body"]["items"]["item"])
dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 4
#       1 import pandas as pd
#       3 pd.set_option('display.max_rows', 10)
# ----> 4 dataset = pd.DataFrame(data["response"]["body"]["items"].get("item"))
#       5 dataset
#
# AttributeError: 'NoneType' object has no attribute 'get'

# %% [markdown]
# ## 무역 데이터 API 응답 필드
#
# | 필드       | 설명                        | 예시                  | 상세 설명       |
# |-------------|---------------------------|----------------------|-------------|
# | year       | 연도                        | 2016.01             | 기간 정보       |
# | statCdCntnKor1 | 국가명                      | 미국                 | 국가명 정보      |
# | statCd     | 국가코드                    | US                   | ISO 국가 코드   |
# | statKor    | 품목명                      | 쇠고기(냉동한 것으로 한정) | 품목명 정보      |
# | hsCd       | HS코드                      | 0202                 | 국제 무역 품목 코드 |
# | expWgt     | 수출중량 (kg)               | 18,003               | 수출된 상품의 중량  |
# | expDlr     | 수출금액 (달러)             | 150,822              | 수출된 상품의 금액  |
# | impWgt     | 수입중량 (kg)               | 14,809,834           | 수입된 상품의 중량  |
# | impDlr     | 수입금액 (달러)             | 93,754,113           | 수입된 상품의 금액  |
# | balPayments | 무역수지 (달러)             | -93,603,291          | 수출금액 - 수입금액 |
