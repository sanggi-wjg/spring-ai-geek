# %%
import os

import requests
import xmltodict
from dotenv import load_dotenv

load_dotenv()

SERVICE_KEY = os.getenv("DATA_GO_KR_SERVICE_KEY")
query_param = {
    "serviceKey": SERVICE_KEY,
    "strtYymm": "200001",
    "endYymm": "200001",
    # "hsSgn": "1001999090",
    "cntyCd": "US",
}
response = requests.get("http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList", params=query_param)
response.raise_for_status()

data = xmltodict.parse(response.content)

# %%
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '394877802',
#       'expDlr': '2608766338',
#       'expWgt': '794635094',
#       'hsCd': '-',
#       'impDlr': '2213888536',
#       'impWgt': '2071894275',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '-864',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106001010',
#       'impDlr': '864',
#       'impWgt': '61',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개',
#       'year': '2000.01'},
#      {'balPayments': '-11047',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106001090',
#       'impDlr': '11047',
#       'impWgt': '168',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-222548',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106002090',
#       'impDlr': '222548',
#       'impWgt': '24420',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-3050',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0106004090',
#       'impDlr': '3050',
#       'impWgt': '100',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '700',
#       'expDlr': '700',
#       'expWgt': '27',
#       'hsCd': '0106006010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갯지렁이',
#       'year': '2000.01'},
#      {'balPayments': '-1035099',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0201300000',
#       'impDlr': '1035099',
#       'impWgt': '290039',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2000.01'},
#      {'balPayments': '-22934560',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202200000',
#       'impDlr': '22934560',
#       'impWgt': '5601116',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타의 것으로서 뼈채로 절단한 것',
#       'year': '2000.01'},
#      {'balPayments': '-10802472',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202300000',
#       'impDlr': '10802472',
#       'impWgt': '3307490',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '뼈 없는 것',
#       'year': '2000.01'},
#      {'balPayments': '-64691',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203191000',
#       'impDlr': '64691',
#       'impWgt': '19188',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2000.01'},
#      {'balPayments': '-25396',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203199000',
#       'impDlr': '25396',
#       'impWgt': '7098',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-89417',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203290000',
#       'impDlr': '89417',
#       'impWgt': '94792',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-25178',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203291000',
#       'impDlr': '25178',
#       'impWgt': '11427',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '삼겹살',
#       'year': '2000.01'},
#      {'balPayments': '-1216454',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203299000',
#       'impDlr': '1216454',
#       'impWgt': '866578',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-50734',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0204420000',
#       'impDlr': '50734',
#       'impWgt': '5773',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 것으로서 뼈째로 절단한 것',
#       'year': '2000.01'},
#      {'balPayments': '-28941',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206100000',
#       'impDlr': '28941',
#       'impWgt': '3756',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 것(신선한 것이나 냉장한 것으로 한정한다)',
#       'year': '2000.01'},
#      {'balPayments': '-721100',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206291000',
#       'impDlr': '721100',
#       'impWgt': '225402',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꼬리',
#       'year': '2000.01'},
#      {'balPayments': '-421361',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206292000',
#       'impDlr': '421361',
#       'impWgt': '329872',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '족',
#       'year': '2000.01'},
#      {'balPayments': '-2873207',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206299000',
#       'impDlr': '2873207',
#       'impWgt': '672019',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-23502',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206491000',
#       'impDlr': '23502',
#       'impWgt': '41001',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '족',
#       'year': '2000.01'},
#      {'balPayments': '-129399',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206499000',
#       'impDlr': '129399',
#       'impWgt': '74114',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-3017684',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141010',
#       'impDlr': '3017684',
#       'impWgt': '4161881',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '다리',
#       'year': '2000.01'},
#      {'balPayments': '-13151',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141020',
#       'impDlr': '13151',
#       'impWgt': '6744',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가슴',
#       'year': '2000.01'},
#      {'balPayments': '-51939',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141030',
#       'impDlr': '51939',
#       'impWgt': '45632',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '날개',
#       'year': '2000.01'},
#      {'balPayments': '-3457',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207142090',
#       'impDlr': '3457',
#       'impWgt': '435',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-639433',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207271000',
#       'impDlr': '639433',
#       'impWgt': '553494',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '절단육',
#       'year': '2000.01'},
#      {'balPayments': '-30555',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207361000',
#       'impDlr': '30555',
#       'impWgt': '8543',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '절단육',
#       'year': '2000.01'},
#      {'balPayments': '-19748',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0208200000',
#       'impDlr': '19748',
#       'impWgt': '1986',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개구리 다리',
#       'year': '2000.01'},
#      {'balPayments': '-11230',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210120000',
#       'impDlr': '11230',
#       'impWgt': '1141',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '복부살(삼겹살)과 이를 절단한 것',
#       'year': '2000.01'},
#      {'balPayments': '-787',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210201000',
#       'impDlr': '787',
#       'impWgt': '31',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조하거나 훈제한 것',
#       'year': '2000.01'},
#      {'balPayments': '-28022',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0210901030',
#       'impDlr': '28022',
#       'impWgt': '5442',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가금류의 것',
#       'year': '2000.01'},
#      {'balPayments': '-5599',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301102000',
#       'impDlr': '5599',
#       'impWgt': '56',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '열대어',
#       'year': '2000.01'},
#      {'balPayments': '-2274',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301911000',
#       'impDlr': '2274',
#       'impWgt': '150',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '살모 트루타(Salmo trutta)ㆍ옹코링쿠스 미키스(Oncorhynchus mykiss)ㆍ옹코링쿠스 클라키(Oncorhynchus clarki)ㆍ옹코링쿠스 아구아보니타(Oncorhynchus aguabonita)ㆍ옹코링쿠스 길래(Oncorhynchus gilae)',
#       'year': '2000.01'},
#      {'balPayments': '-2310',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0301929000',
#       'impDlr': '2310',
#       'impWgt': '191',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-60156',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302500000',
#       'impDlr': '60156',
#       'impWgt': '15138',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대구(가두스 모르화ㆍ가두스 오각ㆍ가두스 마크로세팔루스). 다만, 간과 어란을 제외한다.',
#       'year': '2000.01'},
#      {'balPayments': '-331680',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302699040',
#       'impDlr': '331680',
#       'impWgt': '45450',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아귀',
#       'year': '2000.01'},
#      {'balPayments': '-7447',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0302701000',
#       'impDlr': '7447',
#       'impWgt': '360',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '간',
#       'year': '2000.01'},
#      {'balPayments': '-34428',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303220000',
#       'impDlr': '34428',
#       'impWgt': '19089',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '대서양연어(살모 살라)와 다뉴브연어(후코 후코)',
#       'year': '2000.01'},
#      {'balPayments': '8273',
#       'expDlr': '8273',
#       'expWgt': '3000',
#       'hsCd': '0303310000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '넙치[레인하드티우스 히포글러소이데스(Reinhardtius hippoglossoides)ㆍ히포글러서스 히포글러서스(Hippoglossus hippoglossus)ㆍ히포글러서스 스테노레피스(Hippoglossus stenolepis)]',
#       'year': '2000.01'},
#      {'balPayments': '-31216',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303390000',
#       'impDlr': '31216',
#       'impWgt': '41112',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '22852',
#       'expDlr': '22852',
#       'expWgt': '23000',
#       'hsCd': '0303740000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어(스콤버 스콤브루스ㆍ스콤버 오스트랄라시쿠스ㆍ스콤버 자포니쿠스)',
#       'year': '2000.01'},
#      {'balPayments': '315905',
#       'expDlr': '315905',
#       'expWgt': '39367',
#       'hsCd': '0303780000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '민대구(메루키우스종ㆍ유르피키스종)',
#       'year': '2000.01'},
#      {'balPayments': '-100711',
#       'expDlr': '28087',
#       'expWgt': '21452',
#       'hsCd': '0303791000',
#       'impDlr': '128798',
#       'impWgt': '169488',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태',
#       'year': '2000.01'},
#      {'balPayments': '-2722',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303792000',
#       'impDlr': '2722',
#       'impWgt': '748',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '은대구',
#       'year': '2000.01'},
#      {'balPayments': '24590',
#       'expDlr': '24590',
#       'expWgt': '3193',
#       'hsCd': '0303795000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어',
#       'year': '2000.01'},
#      {'balPayments': '108074',
#       'expDlr': '108074',
#       'expWgt': '17882',
#       'hsCd': '0303796000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기',
#       'year': '2000.01'},
#      {'balPayments': '69154',
#       'expDlr': '115108',
#       'expWgt': '37373',
#       'hsCd': '0303798000',
#       'impDlr': '45954',
#       'impWgt': '19980',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꽁치(학꽁치를 포함한다)',
#       'year': '2000.01'},
#      {'balPayments': '-376952',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799060',
#       'impDlr': '376952',
#       'impWgt': '620187',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '임연수어',
#       'year': '2000.01'},
#      {'balPayments': '-44952',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799070',
#       'impDlr': '44952',
#       'impWgt': '15241',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '볼낙(적어를 포함한다)',
#       'year': '2000.01'},
#      {'balPayments': '-3330866',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799091',
#       'impDlr': '3330866',
#       'impWgt': '717180',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아귀',
#       'year': '2000.01'},
#      {'balPayments': '-239663',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799092',
#       'impDlr': '239663',
#       'impWgt': '149919',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '먹장어(대서양 또는 태평양)',
#       'year': '2000.01'},
#      {'balPayments': '-163336',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799093',
#       'impDlr': '163336',
#       'impWgt': '120057',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '홍어',
#       'year': '2000.01'},
#      {'balPayments': '-20000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799095',
#       'impDlr': '20000',
#       'impWgt': '20000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '민어',
#       'year': '2000.01'},
#      {'balPayments': '-3157',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303799096',
#       'impDlr': '3157',
#       'impWgt': '2745',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가오리',
#       'year': '2000.01'},
#      {'balPayments': '4085',
#       'expDlr': '4602',
#       'expWgt': '300',
#       'hsCd': '0303799099',
#       'impDlr': '517',
#       'impWgt': '520',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-523138',
#       'expDlr': '8346',
#       'expWgt': '544',
#       'hsCd': '0303802010',
#       'impDlr': '531484',
#       'impWgt': '34500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명란',
#       'year': '2000.01'},
#      {'balPayments': '-58008',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0303802090',
#       'impDlr': '58008',
#       'impWgt': '14900',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '1292',
#       'expDlr': '1292',
#       'expWgt': '192',
#       'hsCd': '0304202000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '붕장어의 것',
#       'year': '2000.01'},
#      {'balPayments': '24951',
#       'expDlr': '24951',
#       'expWgt': '4513',
#       'hsCd': '0304204000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가자미의 것',
#       'year': '2000.01'},
#      {'balPayments': '21074',
#       'expDlr': '21074',
#       'expWgt': '3305',
#       'hsCd': '0304209000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-3366587',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304901010',
#       'impDlr': '3366587',
#       'impWgt': '2045660',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태의 것',
#       'year': '2000.01'},
#      {'balPayments': '-1256414',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0304901090',
#       'impDlr': '1256414',
#       'impWgt': '685000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타의 것',
#       'year': '2000.01'},
#      {'balPayments': '52195',
#       'expDlr': '52195',
#       'expWgt': '3091',
#       'hsCd': '0305204010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태의 것',
#       'year': '2000.01'},
#      {'balPayments': '-52161',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305410000',
#       'impDlr': '52161',
#       'impWgt': '3687',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '태평양 연어[옹코링쿠스 넬카(Oncorhynchus nerka)ㆍ옹코링쿠스 고르부스카(Oncorhynchus gorbuscha)ㆍ옹코링쿠스 케타(Oncorhynchus keta)ㆍ옹코링쿠스 차비차(Oncorhynchus tschawytscha)ㆍ옹코링쿠스 키수츠(Oncorhynchus kisutch)ㆍ옹코링쿠스 마소(Oncorhynchus masou)ㆍ옹코링쿠스 로두루스(Oncorhynchus rhodurus)], 대서양 연어[살모 살라(Salmo salar)], 다뉴브 연어[후코 후코(Hucho hucho)]',
#       'year': '2000.01'},
#      {'balPayments': '32301',
#       'expDlr': '32301',
#       'expWgt': '10130',
#       'hsCd': '0305499000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '101334',
#       'expDlr': '101334',
#       'expWgt': '31593',
#       'hsCd': '0305592000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '멸치',
#       'year': '2000.01'},
#      {'balPayments': '50264',
#       'expDlr': '50264',
#       'expWgt': '6994',
#       'hsCd': '0305593000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '명태(북어)',
#       'year': '2000.01'},
#      {'balPayments': '-3586',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305599000',
#       'impDlr': '3586',
#       'impWgt': '712',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1697',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0305691000',
#       'impDlr': '1697',
#       'impWgt': '63',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '연어',
#       'year': '2000.01'},
#      {'balPayments': '35411',
#       'expDlr': '35411',
#       'expWgt': '6326',
#       'hsCd': '0305693000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '갈치',
#       'year': '2000.01'},
#      {'balPayments': '37940',
#       'expDlr': '37940',
#       'expWgt': '9072',
#       'hsCd': '0305695000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '고등어',
#       'year': '2000.01'},
#      {'balPayments': '10479',
#       'expDlr': '10479',
#       'expWgt': '2181',
#       'hsCd': '0305696000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '조기',
#       'year': '2000.01'},
#      {'balPayments': '75666',
#       'expDlr': '75666',
#       'expWgt': '15010',
#       'hsCd': '0305699000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1575',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306131000',
#       'impDlr': '1575',
#       'impWgt': '103',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '새우살',
#       'year': '2000.01'},
#      {'balPayments': '121610',
#       'expDlr': '121610',
#       'expWgt': '12247',
#       'hsCd': '0306141000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '게살',
#       'year': '2000.01'},
#      {'balPayments': '-10110',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306142000',
#       'impDlr': '10110',
#       'impWgt': '726',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '왕게',
#       'year': '2000.01'},
#      {'balPayments': '-119202',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0306220000',
#       'impDlr': '119202',
#       'impWgt': '7818',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '바닷가재(호마루스종)',
#       'year': '2000.01'},
#      {'balPayments': '311175',
#       'expDlr': '311175',
#       'expWgt': '70968',
#       'hsCd': '0307102000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '냉동한 것',
#       'year': '2000.01'},
#      {'balPayments': '11770',
#       'expDlr': '11770',
#       'expWgt': '1201',
#       'hsCd': '0307412000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오징어',
#       'year': '2000.01'},
#      {'balPayments': '-27647',
#       'expDlr': '95069',
#       'expWgt': '30751',
#       'hsCd': '0307491020',
#       'impDlr': '122716',
#       'impWgt': '165746',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오징어',
#       'year': '2000.01'},
#      {'balPayments': '122942',
#       'expDlr': '122942',
#       'expWgt': '24924',
#       'hsCd': '0307493000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2000.01'},
#      {'balPayments': '-5359',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307510000',
#       'impDlr': '5359',
#       'impWgt': '1219',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '산것·신선 또는 냉장한 것',
#       'year': '2000.01'},
#      {'balPayments': '9481',
#       'expDlr': '9481',
#       'expWgt': '593',
#       'hsCd': '0307591010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '문어',
#       'year': '2000.01'},
#      {'balPayments': '-16808',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307911200',
#       'impDlr': '16808',
#       'impWgt': '500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전복',
#       'year': '2000.01'},
#      {'balPayments': '21859',
#       'expDlr': '21859',
#       'expWgt': '2275',
#       'hsCd': '0307919020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '해삼',
#       'year': '2000.01'},
#      {'balPayments': '-1603',
#       'expDlr': '6097',
#       'expWgt': '9900',
#       'hsCd': '0307991140',
#       'impDlr': '7700',
#       'impWgt': '499',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '개아지살',
#       'year': '2000.01'},
#      {'balPayments': '2802',
#       'expDlr': '2802',
#       'expWgt': '72',
#       'hsCd': '0307991150',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '피조개',
#       'year': '2000.01'},
#      {'balPayments': '-586',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0307991190',
#       'impDlr': '586',
#       'impWgt': '26',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '10536',
#       'expDlr': '10536',
#       'expWgt': '1780',
#       'hsCd': '0307991920',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '우렁쉥이',
#       'year': '2000.01'},
#      {'balPayments': '23747',
#       'expDlr': '23747',
#       'expWgt': '5266',
#       'hsCd': '0307993930',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '해파리',
#       'year': '2000.01'},
#      {'balPayments': '-5750',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0402219000',
#       'impDlr': '5750',
#       'impWgt': '250',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '96480',
#       'expDlr': '96480',
#       'expWgt': '128030',
#       'hsCd': '0403101000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '액체 상태인 것',
#       'year': '2000.01'},
#      {'balPayments': '42975',
#       'expDlr': '42975',
#       'expWgt': '54171',
#       'hsCd': '0403109000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-3572',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0403909000',
#       'impDlr': '3572',
#       'impWgt': '650',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1129024',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404101010',
#       'impDlr': '1129024',
#       'impWgt': '2186989',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '유장분말',
#       'year': '2000.01'},
#      {'balPayments': '-13526',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102110',
#       'impDlr': '13526',
#       'impWgt': '38919',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '유당을 제거한 것',
#       'year': '2000.01'},
#      {'balPayments': '-138448',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102190',
#       'impDlr': '138448',
#       'impWgt': '294900',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-3922',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0405100000',
#       'impDlr': '3922',
#       'impWgt': '496',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '버터',
#       'year': '2000.01'},
#      {'balPayments': '-186395',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101000',
#       'impDlr': '186395',
#       'impWgt': '54294',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '신선한 치즈',
#       'year': '2000.01'},
#      {'balPayments': '-303562',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406300000',
#       'impDlr': '303562',
#       'impWgt': '64915',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '가공치즈(갈았거나 가루 모양의 것은 제외한다)',
#       'year': '2000.01'},
#      {'balPayments': '-272756',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406900000',
#       'impDlr': '272756',
#       'impWgt': '85032',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타 치즈',
#       'year': '2000.01'},
#      {'balPayments': '-12181',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0407001090',
#       'impDlr': '12181',
#       'impWgt': '1311',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-82384',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408110000',
#       'impDlr': '82384',
#       'impWgt': '19097',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2000.01'},
#      {'balPayments': '-8146',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408190000',
#       'impDlr': '8146',
#       'impWgt': '1360',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-3978',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408910000',
#       'impDlr': '3978',
#       'impWgt': '907',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2000.01'},
#      {'balPayments': '-2491',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0409000000',
#       'impDlr': '2491',
#       'impWgt': '762',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '천연꿀',
#       'year': '2000.01'},
#      {'balPayments': '-800502',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504001010',
#       'impDlr': '800502',
#       'impWgt': '763375',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 것',
#       'year': '2000.01'},
#      {'balPayments': '-280161',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504001090',
#       'impDlr': '280161',
#       'impWgt': '103380',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-400148',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504003000',
#       'impDlr': '400148',
#       'impWgt': '185621',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '위',
#       'year': '2000.01'},
#      {'balPayments': '-1337',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0506901090',
#       'impDlr': '1337',
#       'impWgt': '210',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-31000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0507901110',
#       'impDlr': '31000',
#       'impWgt': '775',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '전지(全枝)',
#       'year': '2000.01'},
#      {'balPayments': '-45493',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0507901190',
#       'impDlr': '45493',
#       'impWgt': '302',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-100130',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0507901200',
#       'impDlr': '100130',
#       'impWgt': '10000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '녹각',
#       'year': '2000.01'},
#      {'balPayments': '-25117',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0508002030',
#       'impDlr': '25117',
#       'impWgt': '2427',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '첩패각과 지첩패각',
#       'year': '2000.01'},
#      {'balPayments': '-4750',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0508002090',
#       'impDlr': '4750',
#       'impWgt': '1000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0508009000',
#       'impDlr': '1000',
#       'impWgt': '200',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-81350',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511100000',
#       'impDlr': '81350',
#       'impWgt': '7',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '소의 정액',
#       'year': '2000.01'},
#      {'balPayments': '-204619',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511911010',
#       'impDlr': '204619',
#       'impWgt': '4971',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '브라인 슈림프(brine shrimp) 알',
#       'year': '2000.01'},
#      {'balPayments': '-3167',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511911090',
#       'impDlr': '3167',
#       'impWgt': '50',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1357',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511991000',
#       'impDlr': '1357',
#       'impWgt': '45',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '동물의 피',
#       'year': '2000.01'},
#      {'balPayments': '-1991',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511999090',
#       'impDlr': '1991',
#       'impWgt': '2',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-2303',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0601209090',
#       'impDlr': '2303',
#       'impWgt': '240',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '5971',
#       'expDlr': '5971',
#       'expWgt': '465',
#       'hsCd': '0602901010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '난초',
#       'year': '2000.01'},
#      {'balPayments': '17800',
#       'expDlr': '17800',
#       'expWgt': '1885',
#       'hsCd': '0602901060',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '선인장류',
#       'year': '2000.01'},
#      {'balPayments': '-8544',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0603900000',
#       'impDlr': '8544',
#       'impWgt': '210',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '33306',
#       'expDlr': '33306',
#       'expWgt': '4311',
#       'hsCd': '0604911090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-41086',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0701900000',
#       'impDlr': '41086',
#       'impWgt': '119069',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-20',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0704100000',
#       'impDlr': '20',
#       'impWgt': '13',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '꽃양배추와 브로콜리(broccoli)',
#       'year': '2000.01'},
#      {'balPayments': '-360',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0705110000',
#       'impDlr': '360',
#       'impWgt': '46',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '결구(結球) 상추',
#       'year': '2000.01'},
#      {'balPayments': '3100',
#       'expDlr': '3100',
#       'expWgt': '1548',
#       'hsCd': '0705190000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-4098',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0705210000',
#       'impDlr': '4098',
#       'impWgt': '889',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '위트루프 치커리(Witloof chicory)[시코리엄 인티부스 변종 포리오섬(Cichorium intybus var. foliosum)]',
#       'year': '2000.01'},
#      {'balPayments': '-9890',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0705290000',
#       'impDlr': '9890',
#       'impWgt': '2228',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-5644',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0708100000',
#       'impDlr': '5644',
#       'impWgt': '20866',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '완두[피섬 새티범(Pisum sativum)]',
#       'year': '2000.01'},
#      {'balPayments': '-4489',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0709100000',
#       'impDlr': '4489',
#       'impWgt': '540',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '1. 구상(球狀)의 양엉겅퀴',
#       'year': '2000.01'},
#      {'balPayments': '-9992',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0709200000',
#       'impDlr': '9992',
#       'impWgt': '1658',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아스파라거스(asparagus)',
#       'year': '2000.01'},
#      {'balPayments': '-2428',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0709400000',
#       'impDlr': '2428',
#       'impWgt': '500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '셀러리(celery)[셀러리액(celeriac)은 제외한다]',
#       'year': '2000.01'},
#      {'balPayments': '1476',
#       'expDlr': '1476',
#       'expWgt': '452',
#       'hsCd': '0709515000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '느타리버섯',
#       'year': '2000.01'},
#      {'balPayments': '2811',
#       'expDlr': '2811',
#       'expWgt': '979',
#       'hsCd': '0709516000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '팽이버섯',
#       'year': '2000.01'},
#      {'balPayments': '3700',
#       'expDlr': '4936',
#       'expWgt': '5',
#       'hsCd': '0709600000',
#       'impDlr': '1236',
#       'impWgt': '250',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '6. 고추류(캐프시컴속 또는 피멘타속의 열매)',
#       'year': '2000.01'},
#      {'balPayments': '70652',
#       'expDlr': '70652',
#       'expWgt': '21382',
#       'hsCd': '0709909000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-68252',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710100000',
#       'impDlr': '68252',
#       'impWgt': '60115',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '감자',
#       'year': '2000.01'},
#      {'balPayments': '-10328',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710210000',
#       'impDlr': '10328',
#       'impWgt': '7298',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '완두[피섬 새티범(Pisum sativum)]',
#       'year': '2000.01'},
#      {'balPayments': '-32884',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710220000',
#       'impDlr': '32884',
#       'impWgt': '3550',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '콩[비그나(Vigna)속ㆍ파세러스(Phaseolus)속)]',
#       'year': '2000.01'},
#      {'balPayments': '-4355',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710290000',
#       'impDlr': '4355',
#       'impWgt': '2699',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-505',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710300000',
#       'impDlr': '505',
#       'impWgt': '326',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '시금치류',
#       'year': '2000.01'},
#      {'balPayments': '-25088',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710400000',
#       'impDlr': '25088',
#       'impWgt': '30352',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '스위트콘',
#       'year': '2000.01'},
#      {'balPayments': '-10300',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710804000',
#       'impDlr': '10300',
#       'impWgt': '6936',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '당근',
#       'year': '2000.01'},
#      {'balPayments': '-16640',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710809000',
#       'impDlr': '16640',
#       'impWgt': '9558',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-37957',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0710900000',
#       'impDlr': '37957',
#       'impWgt': '22982',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '채소류의 혼합물',
#       'year': '2000.01'},
#      {'balPayments': '-3217',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0711200000',
#       'impDlr': '3217',
#       'impWgt': '560',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '올리브',
#       'year': '2000.01'},
#      {'balPayments': '-4977',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0712200000',
#       'impDlr': '4977',
#       'impWgt': '1814',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '양파',
#       'year': '2000.01'},
#      {'balPayments': '2380',
#       'expDlr': '2380',
#       'expWgt': '113',
#       'hsCd': '0712301030',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '표고버섯',
#       'year': '2000.01'},
#      {'balPayments': '24950',
#       'expDlr': '24950',
#       'expWgt': '1073',
#       'hsCd': '0712301090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-542',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0712901000',
#       'impDlr': '542',
#       'impWgt': '90',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '마늘',
#       'year': '2000.01'},
#      {'balPayments': '28784',
#       'expDlr': '28784',
#       'expWgt': '7870',
#       'hsCd': '0712902070',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '토란줄기',
#       'year': '2000.01'},
#      {'balPayments': '-13761',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0712902093',
#       'impDlr': '13761',
#       'impWgt': '7716',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '감자',
#       'year': '2000.01'},
#      {'balPayments': '171',
#       'expDlr': '557',
#       'expWgt': '45',
#       'hsCd': '0712902099',
#       'impDlr': '386',
#       'impWgt': '136',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-48026',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0713109000',
#       'impDlr': '48026',
#       'impWgt': '172361',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-100820',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0713339000',
#       'impDlr': '100820',
#       'impWgt': '297408',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-14850',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0713390000',
#       'impDlr': '14850',
#       'impWgt': '40820',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-233',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0714909090',
#       'impDlr': '233',
#       'impWgt': '176',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-1124534',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0802120000',
#       'impDlr': '1124534',
#       'impWgt': '424764',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '껍데기를 벗긴 것',
#       'year': '2000.01'},
#      {'balPayments': '-47657',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0802220000',
#       'impDlr': '47657',
#       'impWgt': '9990',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '껍데기를 벗긴 것',
#       'year': '2000.01'},
#      {'balPayments': '-372720',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0802320000',
#       'impDlr': '372720',
#       'impWgt': '99800',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '껍데기를 벗긴 것',
#       'year': '2000.01'},
#      {'balPayments': '161403',
#       'expDlr': '161403',
#       'expWgt': '63000',
#       'hsCd': '0802401000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '탈각하지 아니한 것',
#       'year': '2000.01'},
#      {'balPayments': '-68002',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0802500000',
#       'impDlr': '68002',
#       'impWgt': '24267',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '피스타치오',
#       'year': '2000.01'},
#      {'balPayments': '-7130',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0803000000',
#       'impDlr': '7130',
#       'impWgt': '18538',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '바나나(플랜틴을 포함하며, 신선 또는 건조한 것에 한한다)',
#       'year': '2000.01'},
#      {'balPayments': '-7087',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0804300000',
#       'impDlr': '7087',
#       'impWgt': '1500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '파인애플',
#       'year': '2000.01'},
#      {'balPayments': '-5425',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0804400000',
#       'impDlr': '5425',
#       'impWgt': '1043',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아보카도(avocado)',
#       'year': '2000.01'},
#      {'balPayments': '-1628044',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0805100000',
#       'impDlr': '1628044',
#       'impWgt': '2389340',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오렌지',
#       'year': '2000.01'},
#      {'balPayments': '-377334',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0805300000',
#       'impDlr': '377334',
#       'impWgt': '285968',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '레몬(시트리스리몬·시트리스 리머늄)과 라임(시트리스 오란티풀리아)',
#       'year': '2000.01'},
#      {'balPayments': '-137128',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0805400000',
#       'impDlr': '137128',
#       'impWgt': '155381',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그레이프프루트(grapefruit)와 포멜로(pomelo)',
#       'year': '2000.01'},
#      {'balPayments': '-220376',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0806100000',
#       'impDlr': '220376',
#       'impWgt': '110025',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '신선한 것',
#       'year': '2000.01'},
#      {'balPayments': '-583579',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0806200000',
#       'impDlr': '583579',
#       'impWgt': '405820',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '건조한 것',
#       'year': '2000.01'},
#      {'balPayments': '122396',
#       'expDlr': '122396',
#       'expWgt': '51900',
#       'hsCd': '0808201000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '배',
#       'year': '2000.01'},
#      {'balPayments': '-187312',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0810500000',
#       'impDlr': '187312',
#       'impWgt': '84459',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '키위프루트(kiwifruit)',
#       'year': '2000.01'},
#      {'balPayments': '-1731',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0811100000',
#       'impDlr': '1731',
#       'impWgt': '930',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '초본류 딸기',
#       'year': '2000.01'},
#      {'balPayments': '-478',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0811200000',
#       'impDlr': '478',
#       'impWgt': '109',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '나무딸기, 검은나무딸기, 오디, 로간베리(loganberry), 흑색ㆍ백색ㆍ적색의 커런트(currant), 구즈베리(gooseberry)',
#       'year': '2000.01'},
#      {'balPayments': '-3357',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0811909000',
#       'impDlr': '3357',
#       'impWgt': '735',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-289249',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0901210000',
#       'impDlr': '289249',
#       'impWgt': '30568',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '카페인을 제거하지 않은 것',
#       'year': '2000.01'},
#      {'balPayments': '-38434',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0901220000',
#       'impDlr': '38434',
#       'impWgt': '2831',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '카페인을 제거한 것',
#       'year': '2000.01'},
#      {'balPayments': '2235',
#       'expDlr': '2235',
#       'expWgt': '110',
#       'hsCd': '0902100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '녹차(발효하지 않은 것으로서 내용물의 무게가 3킬로그램 이하로 내용물에 직접 접하여 포장된 것으로 한정한다)',
#       'year': '2000.01'},
#      {'balPayments': '-73188',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0902300000',
#       'impDlr': '73188',
#       'impWgt': '10930',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '홍차(발효차)와 부분 발효차(내용물의 무게가 3킬로그램 이하로 내용물에 직접 접하여 포장된 것으로 한정한다)',
#       'year': '2000.01'},
#      {'balPayments': '40030',
#       'expDlr': '41946',
#       'expWgt': '18720',
#       'hsCd': '0902400000',
#       'impDlr': '1916',
#       'impWgt': '247',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 홍차(발효차)와 그 밖의 부분 발효차',
#       'year': '2000.01'},
#      {'balPayments': '-7440',
# ...
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921291000',
#       'impDlr': '191612',
#       'impWgt': '91838',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디에틸렌 트리아민',
#       'year': '2000.01'},
#      {'balPayments': '-6053',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921292000',
#       'impDlr': '6053',
#       'impWgt': '3905',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '트리에틸렌 테트라아민',
#       'year': '2000.01'},
#      {'balPayments': '-169630',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921299000',
#       'impDlr': '169630',
#       'impWgt': '47860',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-93993',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921301000',
#       'impDlr': '93993',
#       'impWgt': '14449',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '시클로 헥실아민',
#       'year': '2000.01'},
#      {'balPayments': '-24345',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921309000',
#       'impDlr': '24345',
#       'impWgt': '8397',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-614119',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921429000',
#       'impDlr': '614119',
#       'impWgt': '51520',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '175360',
#       'expDlr': '175360',
#       'expWgt': '108851',
#       'hsCd': '2921431000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '파라-톨루이딘-메타-술폰산과 그 염',
#       'year': '2000.01'},
#      {'balPayments': '142941',
#       'expDlr': '142941',
#       'expWgt': '40000',
#       'hsCd': '2921433000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '3-아미노-6-클로로톨루엔-4-술폰산과 그 염',
#       'year': '2000.01'},
#      {'balPayments': '38963',
#       'expDlr': '38963',
#       'expWgt': '19981',
#       'hsCd': '2921441000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디페닐아민',
#       'year': '2000.01'},
#      {'balPayments': '-2544',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921449000',
#       'impDlr': '2544',
#       'impWgt': '408',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-15600',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921459090',
#       'impDlr': '15600',
#       'impWgt': '2000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-80395',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921499000',
#       'impDlr': '80395',
#       'impWgt': '15725',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-88309',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921519020',
#       'impDlr': '88309',
#       'impWgt': '18189',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '메타-페닐렌 디아민',
#       'year': '2000.01'},
#      {'balPayments': '-5778',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921519030',
#       'impDlr': '5778',
#       'impWgt': '199',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '파라-페닐렌 디아민',
#       'year': '2000.01'},
#      {'balPayments': '-283751',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921519040',
#       'impDlr': '283751',
#       'impWgt': '210186',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디아미노톨루엔',
#       'year': '2000.01'},
#      {'balPayments': '-618605',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921519090',
#       'impDlr': '618605',
#       'impWgt': '157856',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '1055399',
#       'expDlr': '1067952',
#       'expWgt': '222954',
#       'hsCd': '2921599090',
#       'impDlr': '12553',
#       'impWgt': '3062',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-52764',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922111000',
#       'impDlr': '52764',
#       'impWgt': '55250',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '모노에탄올아민',
#       'year': '2000.01'},
#      {'balPayments': '-31710',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922121000',
#       'impDlr': '31710',
#       'impWgt': '34656',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디에탄올아민',
#       'year': '2000.01'},
#      {'balPayments': '-23166',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922193010',
#       'impDlr': '23166',
#       'impWgt': '14040',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '엔,엔-디메틸-2-아미노에탄올과 그의 수소화된 염들',
#       'year': '2000.01'},
#      {'balPayments': '-8083',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922194000',
#       'impDlr': '8083',
#       'impWgt': '3674',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '에틸디에탄올아민',
#       'year': '2000.01'},
#      {'balPayments': '-24640',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922195000',
#       'impDlr': '24640',
#       'impWgt': '14516',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '메틸디에탄올아민',
#       'year': '2000.01'},
#      {'balPayments': '-247511',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922199000',
#       'impDlr': '247511',
#       'impWgt': '117397',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-20000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922212000',
#       'impDlr': '20000',
#       'impWgt': '8000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '8-아미노-1-나프톨-3, 6-디술폰산(에이치 에시드)과 그 염',
#       'year': '2000.01'},
#      {'balPayments': '-2107',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922299020',
#       'impDlr': '2107',
#       'impWgt': '89',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '오르토-아미노페놀',
#       'year': '2000.01'},
#      {'balPayments': '-6481',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922299090',
#       'impDlr': '6481',
#       'impWgt': '75',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '999068',
#       'expDlr': '1063868',
#       'expWgt': '818360',
#       'hsCd': '2922411000',
#       'impDlr': '64800',
#       'impWgt': '40000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '리신',
#       'year': '2000.01'},
#      {'balPayments': '807226',
#       'expDlr': '807226',
#       'expWgt': '1000274',
#       'hsCd': '2922422000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '글루탐산 나트륨',
#       'year': '2000.01'},
#      {'balPayments': '-1416',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922439000',
#       'impDlr': '1416',
#       'impWgt': '150',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '안트라닐산의 염',
#       'year': '2000.01'},
#      {'balPayments': '133620',
#       'expDlr': '133620',
#       'expWgt': '51000',
#       'hsCd': '2922491000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '글리신',
#       'year': '2000.01'},
#      {'balPayments': '-18761',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922499000',
#       'impDlr': '18761',
#       'impWgt': '8886',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-15105',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2922509000',
#       'impDlr': '15105',
#       'impWgt': '3',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-143796',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2923201000',
#       'impDlr': '143796',
#       'impWgt': '113492',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '레시틴',
#       'year': '2000.01'},
#      {'balPayments': '-4388',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2923202000',
#       'impDlr': '4388',
#       'impWgt': '375',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '그 밖의 포스포아미노리피드',
#       'year': '2000.01'},
#      {'balPayments': '-346421',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2923900000',
#       'impDlr': '346421',
#       'impWgt': '126855',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-70844',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924101000',
#       'impDlr': '70844',
#       'impWgt': '49198',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디메틸아세트아미드',
#       'year': '2000.01'},
#      {'balPayments': '-268000',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924102000',
#       'impDlr': '268000',
#       'impWgt': '400000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디메틸포름아미드',
#       'year': '2000.01'},
#      {'balPayments': '-1870',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924103000',
#       'impDlr': '1870',
#       'impWgt': '200',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아크릴아미드',
#       'year': '2000.01'},
#      {'balPayments': '440746',
#       'expDlr': '622257',
#       'expWgt': '151400',
#       'hsCd': '2924109000',
#       'impDlr': '181511',
#       'impWgt': '40011',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '마.기 타',
#       'year': '2000.01'},
#      {'balPayments': '-15500',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924210000',
#       'impDlr': '15500',
#       'impWgt': '500',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '우레인과 그들의 유도체 및 그들의 염',
#       'year': '2000.01'},
#      {'balPayments': '4043',
#       'expDlr': '4043',
#       'expWgt': '2720',
#       'hsCd': '2924291010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아미노아세트아닐리드와 그 유도체',
#       'year': '2000.01'},
#      {'balPayments': '-85920',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924291020',
#       'impDlr': '85920',
#       'impWgt': '16000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아세트아미노펜',
#       'year': '2000.01'},
#      {'balPayments': '-311040',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924291090',
#       'impDlr': '311040',
#       'impWgt': '94058',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '1209996',
#       'expDlr': '1358176',
#       'expWgt': '56224',
#       'hsCd': '2924299090',
#       'impDlr': '148180',
#       'impWgt': '8164',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '105416',
#       'expDlr': '105416',
#       'expWgt': '18144',
#       'hsCd': '2925111000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사카린',
#       'year': '2000.01'},
#      {'balPayments': '-76497',
#       'expDlr': '10031',
#       'expWgt': '2268',
#       'hsCd': '2925112000',
#       'impDlr': '86528',
#       'impWgt': '8780',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '사카린의 염',
#       'year': '2000.01'},
#      {'balPayments': '-10780',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2925191000',
#       'impDlr': '10780',
#       'impWgt': '4990',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '프탈이미드',
#       'year': '2000.01'},
#      {'balPayments': '-94965',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2925199000',
#       'impDlr': '94965',
#       'impWgt': '14750',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-3448441',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2926100000',
#       'impDlr': '3448441',
#       'impWgt': '4633773',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아크릴로니트릴',
#       'year': '2000.01'},
#      {'balPayments': '-17476',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2926200000',
#       'impDlr': '17476',
#       'impWgt': '16000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '1-시아노구아니딘(디시안디아미드)',
#       'year': '2000.01'},
#      {'balPayments': '-9478',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2926901000',
#       'impDlr': '9478',
#       'impWgt': '1120',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아세토니트릴',
#       'year': '2000.01'},
#      {'balPayments': '-190940',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2926909090',
#       'impDlr': '190940',
#       'impWgt': '17464',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-6070',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2927001900',
#       'impDlr': '6070',
#       'impWgt': '68',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '462005',
#       'expDlr': '462005',
#       'expWgt': '202544',
#       'hsCd': '2927002100',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '아조디카본아미드',
#       'year': '2000.01'},
#      {'balPayments': '-24003',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2928009020',
#       'impDlr': '24003',
#       'impWgt': '13335',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '메틸에틸 케토옥심',
#       'year': '2000.01'},
#      {'balPayments': '13936',
#       'expDlr': '16764',
#       'expWgt': '3402',
#       'hsCd': '2928009090',
#       'impDlr': '2828',
#       'impWgt': '202',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기 타',
#       'year': '2000.01'},
#      {'balPayments': '-25212',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2929101000',
#       'impDlr': '25212',
#       'impWgt': '1497',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '톨루엔 디이소시아네이트',
#       'year': '2000.01'},
#      {'balPayments': '-57333',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2929102000',
#       'impDlr': '57333',
#       'impWgt': '6469',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디페닐메탄 디이소시아네이트',
#       'year': '2000.01'},
#      {'balPayments': '-223630',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2929109000',
#       'impDlr': '223630',
#       'impWgt': '32967',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '기타',
#       'year': '2000.01'},
#      {'balPayments': '-38030',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2930202000',
#       'impDlr': '38030',
#       'impWgt': '1814',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '디티오카르메이트',
#       'year': '2000.01'},
#      {'balPayments': '-413',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2930302000',
#       'impDlr': '413',
#       'impWgt': '20',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '티우람디술파이드',
#       'year': '2000.01'},
#      {'balPayments': '-157700',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2930400000',
#       'impDlr': '157700',
#       'impWgt': '58000',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'statKor': '메티오닌',
#       'year': '2000.01'},
#      ...]}}}}

# %%
import pandas as pd

pd.set_option('display.max_rows', 10)
dataset = pd.DataFrame(data["response"]["body"]["items"]["item"])
dataset
# Out:
#      balPayments      expDlr     expWgt        hsCd      impDlr      impWgt  \
# 0      394877802  2608766338  794635094           -  2213888536  2071894275
# 1           -864           0          0  0106001010         864          61
# 2         -11047           0          0  0106001090       11047         168
# 3        -222548           0          0  0106002090      222548       24420
# 4          -3050           0          0  0106004090        3050         100
# ...          ...         ...        ...         ...         ...         ...
# 5232      -15381           0          0  9999999286       15381         249
# 5233        -595           0          0  9999999287         595           1
# 5234        -253           0          0  9999999288         253           6
# 5235       -2553           0          0  9999999289        2553          46
# 5236     -249339           0          0  9999999290      249339      362385
#
#      statCd statCdCntnKor1 statKor     year
# 0         -              -       -       총계
# 1        US             미국       개  2000.01
# 2        US             미국     기 타  2000.01
# 3        US             미국     기 타  2000.01
# 4        US             미국     기 타  2000.01
# ...     ...            ...     ...      ...
# 5232     US             미국       -  2000.01
# 5233     US             미국       -  2000.01
# 5234     US             미국       -  2000.01
# 5235     US             미국       -  2000.01
# 5236     US             미국       -  2000.01
#
# [5237 rows x 10 columns]

# %% [markdown]
# ## 무역 데이터 API 응답 필드
#
# | 필드       | 설명                        | 예시                  | 상세 설명       |
# |-------------|---------------------------|----------------------|-------------|
# | year       | 연도                        | 2016.01             | 기간 정보       |
# | statCdCntnKor1 | 국가명                      | 미국                 | 국가명 정보      |
# | statCd     | 국가코드                    | US                   | ISO 국가 코드   |
# | statKor    | 품목명                      | 쇠고기(냉동한 것으로 한정) | 품목명 정보      |
# | hsCd       | HS코드                      | 0202                 | 국제 무역 품목 코드 |
# | expWgt     | 수출중량 (kg)               | 18,003               | 수출된 상품의 중량  |
# | expDlr     | 수출금액 (달러)             | 150,822              | 수출된 상품의 금액  |
# | impWgt     | 수입중량 (kg)               | 14,809,834           | 수입된 상품의 중량  |
# | impDlr     | 수입금액 (달러)             | 93,754,113           | 수입된 상품의 금액  |
# | balPayments | 무역수지 (달러)             | -93,603,291          | 수출금액 - 수입금액 |
