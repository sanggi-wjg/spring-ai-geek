# %%
import os

import requests
import xmltodict
from dotenv import load_dotenv

load_dotenv()

SERVICE_KEY = os.getenv("DATA_GO_KR_SERVICE_KEY")
query_param = {
    "serviceKey": SERVICE_KEY,
    "strtYymm": "202412",
    "endYymm": "202412",
    # "hsSgn": "1001999090",
    "cntyCd": "DK",
}
response = requests.get("http://apis.data.go.kr/1220000/nitemtrade/getNitemtradeList", params=query_param, headers={"Content-Type": "application/json"})
response.raise_for_status()

# %%
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>정상서비스.</resultMsg></header><body><items><item><balPayments>120202932</balPayments><expDlr>230391081</expDlr><expWgt>55349825</expWgt><hsCd>-</hsCd><impDlr>110188149</impDlr><impWgt>10979602</impWgt><statCd>-</statCd><statCdCntnKor1>-</statCdCntnKor1><statKor>-</statKor><year>총계</year></item><item><balPayments>-279735</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0202201000</hsCd><impDlr>279735</impDlr><impWgt>57150</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>갈비</statKor><year>2024.12</year></item><item><balPayments>-464781</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0202300000</hsCd><impDlr>464781</impDlr><impWgt>77372</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>뼈 없는 것</statKor><year>2024.12</year></item><item><balPayments>-390272</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0203291000</hsCd><impDlr>390272</impDlr><impWgt>87768</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>삼겹살</statKor><year>2024.12</year></item><item><balPayments>-766500</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0203299000</hsCd><impDlr>766500</impDlr><impWgt>439891</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>기타</statKor><year>2024.12</year></item><item><balPayments>-39975</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0206299000</hsCd><impDlr>39975</impDlr><impWgt>3511</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>기타</statKor><year>2024.12</year></item><item><balPayments>-37050</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0207141010</hsCd><impDlr>37050</impDlr><impWgt>19000</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>다리</statKor><year>2024.12</year></item><item><balPayments>-439024</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0207141030</hsCd><impDlr>439024</impDlr><impWgt>196004</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>날개</statKor><year>2024.12</year></item><item><balPayments>-183666</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0207142090</hsCd><impDlr>183666</impDlr><impWgt>140380</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>기타</statKor><year>2024.12</year></item><item><balPayments>-1112</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0209100000</hsCd><impDlr>1112</impDlr><impWgt>100</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>돼지의 것</statKor><year>2024.12</year></item><item><balPayments>-52062</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0404102990</hsCd><impDlr>52062</impDlr><impWgt>6600</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>기타</statKor><year>2024.12</year></item><item><balPayments>-590879</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0405100000</hsCd><impDlr>590879</impDlr><impWgt>70938</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>버터</statKor><year>2024.12</year></item><item><balPayments>-7699520</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0406101010</hsCd><impDlr>7699520</impDlr><impWgt>1953041</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>모차렐라 치즈(Mozzarella cheese)</statKor><year>2024.12</year></item><item><balPayments>-66194</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0406101020</hsCd><impDlr>66194</impDlr><impWgt>10928</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>크림 치즈</statKor><year>2024.12</year></item><item><balPayments>-290</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0406101090</hsCd><impDlr>290</impDlr><impWgt>15</impWgt><statCd>DK</statCd><statCdCntnKor1>덴마크</statCdCntnKor1><statKor>기타</statKor><year>2024.12</year></item><item><balPayments>-773929</balPayments><expDlr>0</expDlr><expWgt>0</expWgt><hsCd>0406200000</hsCd><impDlr>773929</impDlr ...

# %%
data = xmltodict.parse(response.content)
data
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '120202932',
#       'expDlr': '230391081',
#       'expWgt': '55349825',
#       'hsCd': '-',
#       'impDlr': '110188149',
#       'impWgt': '10979602',
#       'statCd': '-',
#       'statCdCntnKor1': '-',
#       'statKor': '-',
#       'year': '총계'},
#      {'balPayments': '-279735',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202201000',
#       'impDlr': '279735',
#       'impWgt': '57150',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '갈비',
#       'year': '2024.12'},
#      {'balPayments': '-464781',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0202300000',
#       'impDlr': '464781',
#       'impWgt': '77372',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '뼈 없는 것',
#       'year': '2024.12'},
#      {'balPayments': '-390272',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203291000',
#       'impDlr': '390272',
#       'impWgt': '87768',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '삼겹살',
#       'year': '2024.12'},
#      {'balPayments': '-766500',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0203299000',
#       'impDlr': '766500',
#       'impWgt': '439891',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-39975',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0206299000',
#       'impDlr': '39975',
#       'impWgt': '3511',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-37050',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141010',
#       'impDlr': '37050',
#       'impWgt': '19000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '다리',
#       'year': '2024.12'},
#      {'balPayments': '-439024',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207141030',
#       'impDlr': '439024',
#       'impWgt': '196004',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '날개',
#       'year': '2024.12'},
#      {'balPayments': '-183666',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0207142090',
#       'impDlr': '183666',
#       'impWgt': '140380',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1112',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0209100000',
#       'impDlr': '1112',
#       'impWgt': '100',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '돼지의 것',
#       'year': '2024.12'},
#      {'balPayments': '-52062',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0404102990',
#       'impDlr': '52062',
#       'impWgt': '6600',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-590879',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0405100000',
#       'impDlr': '590879',
#       'impWgt': '70938',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '버터',
#       'year': '2024.12'},
#      {'balPayments': '-7699520',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101010',
#       'impDlr': '7699520',
#       'impWgt': '1953041',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '모차렐라 치즈(Mozzarella cheese)',
#       'year': '2024.12'},
#      {'balPayments': '-66194',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101020',
#       'impDlr': '66194',
#       'impWgt': '10928',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '크림 치즈',
#       'year': '2024.12'},
#      {'balPayments': '-290',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406101090',
#       'impDlr': '290',
#       'impWgt': '15',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-773929',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406200000',
#       'impDlr': '773929',
#       'impWgt': '66749',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '갈았거나 가루 모양으로 한 모든 종류의 치즈',
#       'year': '2024.12'},
#      {'balPayments': '-10226',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406400000',
#       'impDlr': '10226',
#       'impWgt': '701',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '블루바인 치즈(blue-veined cheese)와 페니실리움 로우크포티(Penicillium roqueforti)로 생산된 바인(vein)을 함유한 그 밖의 치즈',
#       'year': '2024.12'},
#      {'balPayments': '-23607',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406902000',
#       'impDlr': '23607',
#       'impWgt': '2678',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '하우다 치즈(Gouda cheese)',
#       'year': '2024.12'},
#      {'balPayments': '-25754',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406903000',
#       'impDlr': '25754',
#       'impWgt': '2280',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '카망베르 치즈(Camembert cheese)',
#       'year': '2024.12'},
#      {'balPayments': '-139854',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0406909000',
#       'impDlr': '139854',
#       'impWgt': '13775',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-64999',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408110000',
#       'impDlr': '64999',
#       'impWgt': '6000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '건조한 것',
#       'year': '2024.12'},
#      {'balPayments': '-160931',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408190000',
#       'impDlr': '160931',
#       'impWgt': '32910',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-290034',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0408910000',
#       'impDlr': '290034',
#       'impWgt': '36000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '건조한 것',
#       'year': '2024.12'},
#      {'balPayments': '-9633',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0504003000',
#       'impDlr': '9633',
#       'impWgt': '5070',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '위',
#       'year': '2024.12'},
#      {'balPayments': '-9947',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0511911090',
#       'impDlr': '9947',
#       'impWgt': '24',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-142050',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0712902099',
#       'impDlr': '142050',
#       'impWgt': '1296',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-10579',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '0901210000',
#       'impDlr': '10579',
#       'impWgt': '157',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '카페인을 제거하지 않은 것',
#       'year': '2024.12'},
#      {'balPayments': '-1217154',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1107100000',
#       'impDlr': '1217154',
#       'impWgt': '1525928',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '볶지 않은 것',
#       'year': '2024.12'},
#      {'balPayments': '-1834299',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1108130000',
#       'impDlr': '1834299',
#       'impWgt': '1903250',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '감자로 만든 것',
#       'year': '2024.12'},
#      {'balPayments': '-492',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209300000',
#       'impDlr': '492',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '화초용 초본(草本)식물의 종자',
#       'year': '2024.12'},
#      {'balPayments': '-34097',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209912000',
#       'impDlr': '34097',
#       'impWgt': '9000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '무 종자',
#       'year': '2024.12'},
#      {'balPayments': '-3152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1209913000',
#       'impDlr': '3152',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '고추ㆍ단고추류(Capsicum annuum)의 종자',
#       'year': '2024.12'},
#      {'balPayments': '-61003',
#       'expDlr': '5',
#       'expWgt': '60',
#       'hsCd': '1209919000',
#       'impDlr': '61008',
#       'impWgt': '13669',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-47926',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1302200000',
#       'impDlr': '47926',
#       'impWgt': '2400',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '펙틴질ㆍ펙티닝산염(pectinate)과 펙틴산염(pectate)',
#       'year': '2024.12'},
#      {'balPayments': '-717420',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1302320000',
#       'impDlr': '717420',
#       'impWgt': '17600',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '로커스트콩(locust bean)ㆍ로커스트콩(locust bean)의 씨나 구아(guar)의 씨로부터 얻은 점질물과 시커너(thickener)(변성 가공했는지에 상관없다)',
#       'year': '2024.12'},
#      {'balPayments': '-230257',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1302390000',
#       'impDlr': '230257',
#       'impWgt': '7042',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1188',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1515909090',
#       'impDlr': '1188',
#       'impWgt': '25',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-9',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1516202090',
#       'impDlr': '9',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1602329000',
#       'impDlr': '152',
#       'impWgt': '40',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-428890',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1602491000',
#       'impDlr': '428890',
#       'impWgt': '79187',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '밀폐용기에 넣은 것',
#       'year': '2024.12'},
#      {'balPayments': '-43',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1605219000',
#       'impDlr': '43',
#       'impWgt': '5',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-535',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1702111000',
#       'impDlr': '535',
#       'impWgt': '125',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '유당(乳糖)',
#       'year': '2024.12'},
#      {'balPayments': '-346057',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1702909000',
#       'impDlr': '346057',
#       'impWgt': '100800',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-107',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1704902090',
#       'impDlr': '107',
#       'impWgt': '5',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-144',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1704909000',
#       'impDlr': '144',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-32',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1806100000',
#       'impDlr': '32',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '코코아 가루(설탕이나 그 밖의 감미료를 첨가한 것으로 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-16',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1806201000',
#       'impDlr': '16',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '초콜릿과 초콜릿 과자',
#       'year': '2024.12'},
#      {'balPayments': '-97',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1806311000',
#       'impDlr': '97',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '초콜릿과 초콜릿 과자',
#       'year': '2024.12'},
#      {'balPayments': '-34',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1806319000',
#       'impDlr': '34',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-127',
#       'expDlr': '1',
#       'expWgt': '0',
#       'hsCd': '1806901000',
#       'impDlr': '128',
#       'impWgt': '3',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '초콜릿과 초콜릿 과자',
#       'year': '2024.12'},
#      {'balPayments': '-6',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1806909090',
#       'impDlr': '6',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-229355',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1901101010',
#       'impDlr': '229355',
#       'impWgt': '22560',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 분유',
#       'year': '2024.12'},
#      {'balPayments': '-233603',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1901209000',
#       'impDlr': '233603',
#       'impWgt': '61530',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-14412',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1901902010',
#       'impDlr': '14412',
#       'impWgt': '6533',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '지방분이 전 중량의 100분의 30 이하인 것',
#       'year': '2024.12'},
#      {'balPayments': '-40149',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1901909099',
#       'impDlr': '40149',
#       'impWgt': '8100',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '0',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1902301010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '라면',
#       'year': '2024.12'},
#      {'balPayments': '-207861',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1905310000',
#       'impDlr': '207861',
#       'impWgt': '34958',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '스위트 비스킷',
#       'year': '2024.12'},
#      {'balPayments': '-115',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1905901040',
#       'impDlr': '115',
#       'impWgt': '7',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '비스킷, 쿠키와 크래커',
#       'year': '2024.12'},
#      {'balPayments': '-63651',
#       'expDlr': '10470',
#       'expWgt': '5800',
#       'hsCd': '1905901090',
#       'impDlr': '74121',
#       'impWgt': '24891',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-42',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1905909020',
#       'impDlr': '42',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '라이스 페이퍼',
#       'year': '2024.12'},
#      {'balPayments': '-221',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '1905909090',
#       'impDlr': '221',
#       'impWgt': '16',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-50',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2005209000',
#       'impDlr': '50',
#       'impWgt': '5',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-43',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2007911000',
#       'impDlr': '43',
#       'impWgt': '4',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '잼ㆍ과실젤리와 마멀레이드(marmalade)',
#       'year': '2024.12'},
#      {'balPayments': '-11875',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2102101000',
#       'impDlr': '11875',
#       'impWgt': '54',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '양조효모',
#       'year': '2024.12'},
#      {'balPayments': '512',
#       'expDlr': '512',
#       'expWgt': '200',
#       'hsCd': '2102202000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '누룩',
#       'year': '2024.12'},
#      {'balPayments': '7',
#       'expDlr': '14',
#       'expWgt': '1',
#       'hsCd': '2103909090',
#       'impDlr': '7',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '73',
#       'expDlr': '73',
#       'expWgt': '2',
#       'hsCd': '2106901090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-30108',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2106909040',
#       'impDlr': '30108',
#       'impWgt': '2100',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '자기소화효모(autolyzed yeast)와 그 밖의 효모 추출물(extract)',
#       'year': '2024.12'},
#      {'balPayments': '-10',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2106909050',
#       'impDlr': '10',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '향미(香味)용 조제품',
#       'year': '2024.12'},
#      {'balPayments': '-4258522',
#       'expDlr': '289464',
#       'expWgt': '1401',
#       'hsCd': '2106909099',
#       'impDlr': '4547986',
#       'impWgt': '34354',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '180246',
#       'expDlr': '180246',
#       'expWgt': '247520',
#       'hsCd': '2202999000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-164766',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2203000000',
#       'impDlr': '164766',
#       'impWgt': '209952',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '맥주',
#       'year': '2024.12'},
#      {'balPayments': '-111',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2204219000',
#       'impDlr': '111',
#       'impWgt': '7',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-489640',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2206001010',
#       'impDlr': '489640',
#       'impWgt': '385362',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '사과술',
#       'year': '2024.12'},
#      {'balPayments': '-5009',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2206001090',
#       'impDlr': '5009',
#       'impWgt': '4428',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-114844',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2301201000',
#       'impDlr': '114844',
#       'impWgt': '48040',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '어류의 고운 가루ㆍ거친 가루ㆍ펠릿(pellet)',
#       'year': '2024.12'},
#      {'balPayments': '-105721',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309901091',
#       'impDlr': '105721',
#       'impWgt': '46000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '대용유(代用乳)',
#       'year': '2024.12'},
#      {'balPayments': '-31743',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309901099',
#       'impDlr': '31743',
#       'impWgt': '11000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-6270',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2309903090',
#       'impDlr': '6270',
#       'impWgt': '150',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-9735',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403199000',
#       'impDlr': '9735',
#       'impWgt': '224',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-70',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2403994000',
#       'impDlr': '70',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '입안에 머금는 담배(예: 스누스)',
#       'year': '2024.12'},
#      {'balPayments': '7452',
#       'expDlr': '7452',
#       'expWgt': '4043',
#       'hsCd': '2424000000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '이사화물',
#       'year': '2024.12'},
#      {'balPayments': '-121281',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2501009020',
#       'impDlr': '121281',
#       'impWgt': '85648',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '순염화나트륨',
#       'year': '2024.12'},
#      {'balPayments': '-1373',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2501009090',
#       'impDlr': '1373',
#       'impWgt': '56',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1436',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2710199000',
#       'impDlr': '1436',
#       'impWgt': '29',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-172511',
#       'expDlr': '230353',
#       'expWgt': '817',
#       'hsCd': '2804619000',
#       'impDlr': '402864',
#       'impWgt': '1427',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-4062',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2807001090',
#       'impDlr': '4062',
#       'impWgt': '14',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '56759',
#       'expDlr': '56759',
#       'expWgt': '60000',
#       'hsCd': '2815200000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '수산화칼륨[가성(苛性)칼륨]',
#       'year': '2024.12'},
#      {'balPayments': '-90551',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2818301000',
#       'impDlr': '90551',
#       'impWgt': '1003',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '알루미나겔',
#       'year': '2024.12'},
#      {'balPayments': '-481',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2818309000',
#       'impDlr': '481',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-59863',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2826300000',
#       'impDlr': '59863',
#       'impWgt': '57600',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '육플루오르화알루미늄산나트륨[인조 빙정석(氷晶石)]',
#       'year': '2024.12'},
#      {'balPayments': '-4010',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2835291000',
#       'impDlr': '4010',
#       'impWgt': '22',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '인산알루미늄',
#       'year': '2024.12'},
#      {'balPayments': '-2553',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2841909090',
#       'impDlr': '2553',
#       'impWgt': '121',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-23',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2849909090',
#       'impDlr': '23',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-257',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2906199000',
#       'impDlr': '257',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-197',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2911000000',
#       'impDlr': '197',
#       'impWgt': '10',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '아세탈ㆍ헤미아세탈(그 밖의 산소관능 결합을 한 것인지에 상관없다)과 이들의 할로겐화유도체ㆍ술폰화유도체ㆍ니트로화유도체ㆍ니트로소화유도체',
#       'year': '2024.12'},
#      {'balPayments': '-2130',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2921299000',
#       'impDlr': '2130',
#       'impWgt': '20',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '589',
#       'expDlr': '589',
#       'expWgt': '600',
#       'hsCd': '2922199000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-42869',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2923202000',
#       'impDlr': '42869',
#       'impWgt': '4000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '그 밖의 포스포아미노리피드',
#       'year': '2024.12'},
#      {'balPayments': '-750',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2924299099',
#       'impDlr': '750',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-672',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2932209099',
#       'impDlr': '672',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-605',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2936281000',
#       'impDlr': '605',
#       'impWgt': '25',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '초산알파토코페롤',
#       'year': '2024.12'},
#      {'balPayments': '-19855',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2936901000',
#       'impDlr': '19855',
#       'impWgt': '475',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '프로비타민(혼합하지 아니한 것으로 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-1449',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2937120000',
#       'impDlr': '1449',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '인슐린과 그 염',
#       'year': '2024.12'},
#      {'balPayments': '-77',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2937299000',
#       'impDlr': '77',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-24459',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '2941909000',
#       'impDlr': '24459',
#       'impWgt': '7',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-8042',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002122000',
#       'impDlr': '8042',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '면역혈청',
#       'year': '2024.12'},
#      {'balPayments': '-2058227',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002123000',
#       'impDlr': '2058227',
#       'impWgt': '101',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '그 밖의 혈액 분획물',
#       'year': '2024.12'},
#      {'balPayments': '-18980963',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002140000',
#       'impDlr': '18980963',
#       'impWgt': '238',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '면역물품(혼합된 것에 한정하며, 일정한 투여량으로 한 것, 소매용 모양이나 포장을 한 것은 제외한다)',
#       'year': '2024.12'},
#      {'balPayments': '-71233',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002150000',
#       'impDlr': '71233',
#       'impWgt': '115',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '면역물품(일정한 투여량으로 한 것, 소매용 모양이나 포장을 한 것에 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-1932457',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002410000',
#       'impDlr': '1932457',
#       'impWgt': '70',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '백신(인체의약용으로 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-409284',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002492000',
#       'impDlr': '409284',
#       'impWgt': '1220',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '미생물 배양체',
#       'year': '2024.12'},
#      {'balPayments': '-5671',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3002909000',
#       'impDlr': '5671',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1325254',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3004391010',
#       'impDlr': '1325254',
#       'impWgt': '1545',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '뇌하수체 전엽 호르몬제제',
#       'year': '2024.12'},
#      {'balPayments': '-11064769',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3004399000',
#       'impDlr': '11064769',
#       'impWgt': '7058',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-321174',
#       'expDlr': '91613',
#       'expWgt': '214',
#       'hsCd': '3004909900',
#       'impDlr': '412787',
#       'impWgt': '2349',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '75189',
#       'expDlr': '75211',
#       'expWgt': '734',
#       'hsCd': '3005109000',
#       'impDlr': '22',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-6348',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3005903000',
#       'impDlr': '6348',
#       'impWgt': '162',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '붕대',
#       'year': '2024.12'},
#      {'balPayments': '5288',
#       'expDlr': '5288',
#       'expWgt': '6',
#       'hsCd': '3006101020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '살균한 봉합재(살균한 외과용이나 치과용 흡수성 실을 포함한다)',
#       'year': '2024.12'},
#      {'balPayments': '-18219',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3006930000',
#       'impDlr': '18219',
#       'impWgt': '214',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '공인된 임상시험에 사용하는 플라세보(placebo)와 맹검(또는 이중 맹검) 임상시험 키트(일정한 투여량으로 한 것으로 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-21663',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3203003000',
#       'impDlr': '21663',
#       'impWgt': '335',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '식물성이나 동물성 착색제를 기본 재료로 한 조제품',
#       'year': '2024.12'},
#      {'balPayments': '-4869',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3204170000',
#       'impDlr': '4869',
#       'impWgt': '16',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '안료 색소와 이들을 기본 재료로 한 조제품',
#       'year': '2024.12'},
#      {'balPayments': '-2222',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3204191000',
#       'impDlr': '2222',
#       'impWgt': '60',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '유기용제 용해염료와 이들을 기본 재료로 한 조제품',
#       'year': '2024.12'},
#      {'balPayments': '-1227',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3205009000',
#       'impDlr': '1227',
#       'impWgt': '20',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '1372',
#       'expDlr': '1372',
#       'expWgt': '15',
#       'hsCd': '3206499000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-7',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3208101090',
#       'impDlr': '7',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-24928',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3208102000',
#       'impDlr': '24928',
#       'impWgt': '4042',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '바니시(varnish)[래커(lacquer)를 포함한다]',
#       'year': '2024.12'},
#      {'balPayments': '-19172',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3208901019',
#       'impDlr': '19172',
#       'impWgt': '3759',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-41',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3208909019',
#       'impDlr': '41',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-31761',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3209101020',
#       'impDlr': '31761',
#       'impWgt': '8558',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '바니시(varnish)[래커(lacquer)를 포함한다]',
#       'year': '2024.12'},
#      {'balPayments': '-197523',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3209909020',
#       'impDlr': '197523',
#       'impWgt': '54346',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '바니시(varnish)[래커(lacquer)를 포함한다]',
#       'year': '2024.12'},
#      {'balPayments': '-1',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3210003090',
#       'impDlr': '1',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-10979',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3213902000',
#       'impDlr': '10979',
#       'impWgt': '658',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '수성 물감',
#       'year': '2024.12'},
#      {'balPayments': '-19',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3214101090',
#       'impDlr': '19',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-17',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3302900000',
#       'impDlr': '17',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '921',
#       'expDlr': '921',
#       'expWgt': '4',
#       'hsCd': '3303001000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '향수',
#       'year': '2024.12'},
#      {'balPayments': '8389',
#       'expDlr': '8389',
#       'expWgt': '81',
#       'hsCd': '3304101000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '립스틱',
#       'year': '2024.12'},
#      {'balPayments': '5410',
#       'expDlr': '5410',
#       'expWgt': '167',
#       'hsCd': '3304109000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '4201',
#       'expDlr': '4201',
#       'expWgt': '121',
#       'hsCd': '3304201000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '아이섀도',
#       'year': '2024.12'},
#      {'balPayments': '917',
#       'expDlr': '917',
#       'expWgt': '12',
#       'hsCd': '3304209000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '5',
#       'expDlr': '5',
#       'expWgt': '0',
#       'hsCd': '3304309000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '1396',
#       'expDlr': '1396',
#       'expWgt': '114',
#       'hsCd': '3304911000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '페이스파우다',
#       'year': '2024.12'},
#      {'balPayments': '140',
#       'expDlr': '140',
#       'expWgt': '4',
#       'hsCd': '3304919000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '652723',
#       'expDlr': '811227',
#       'expWgt': '29481',
#       'hsCd': '3304991000',
#       'impDlr': '158504',
#       'impWgt': '610',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기초화장용 제품류',
#       'year': '2024.12'},
#      {'balPayments': '43181',
#       'expDlr': '43181',
#       'expWgt': '383',
#       'hsCd': '3304992000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '메이크업용 제품류',
#       'year': '2024.12'},
#      {'balPayments': '322772',
#       'expDlr': '324040',
#       'expWgt': '17325',
#       'hsCd': '3304999000',
#       'impDlr': '1268',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '7187',
#       'expDlr': '7187',
#       'expWgt': '426',
#       'hsCd': '3305100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '샴푸',
#       'year': '2024.12'},
#      {'balPayments': '921',
#       'expDlr': '921',
#       'expWgt': '33',
#       'hsCd': '3305901000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '헤어린스',
#       'year': '2024.12'},
#      {'balPayments': '59',
#       'expDlr': '59',
#       'expWgt': '1',
#       'hsCd': '3305902000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '헤어크림',
#       'year': '2024.12'},
#      {'balPayments': '19599',
#       'expDlr': '20714',
#       'expWgt': '598',
#       'hsCd': '3305909000',
#       'impDlr': '1115',
#       'impWgt': '8',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '278',
#       'expDlr': '278',
#       'expWgt': '35',
#       'hsCd': '3306100000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '치약',
#       'year': '2024.12'},
#      {'balPayments': '67',
#       'expDlr': '67',
#       'expWgt': '0',
#       'hsCd': '3307301000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '가향한 목욕용 염',
#       'year': '2024.12'},
#      {'balPayments': '220',
#       'expDlr': '220',
#       'expWgt': '27',
#       'hsCd': '3307490000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '121812',
#       'expDlr': '121812',
#       'expWgt': '8150',
#       'hsCd': '3307904000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '마스크 팩',
#       'year': '2024.12'},
#      {'balPayments': '47896',
#       'expDlr': '47896',
#       'expWgt': '869',
#       'hsCd': '3307909000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-25',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3401191090',
#       'impDlr': '25',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '850',
#       'expDlr': '850',
#       'expWgt': '1000',
#       'hsCd': '3401200000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '그 밖의 모양의 비누',
#       'year': '2024.12'},
#      {'balPayments': '22675',
#       'expDlr': '102578',
#       'expWgt': '2527',
#       'hsCd': '3401300000',
#       'impDlr': '79903',
#       'impWgt': '693',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '피부세척용 유기계면활성제품과 조제품(액체나 크림 형태의 소매용으로 한정하며, 비누를 함유한 것인지에 상관없다)',
#       'year': '2024.12'},
#      {'balPayments': '-4',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3402390000',
#       'impDlr': '4',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-4240',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3402429000',
#       'impDlr': '4240',
#       'impWgt': '309',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-517673',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3402501000',
#       'impDlr': '517673',
#       'impWgt': '90824',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 세제',
#       'year': '2024.12'},
#      {'balPayments': '-193580',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3402502000',
#       'impDlr': '193580',
#       'impWgt': '22523',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 청정제',
#       'year': '2024.12'},
#      {'balPayments': '-8',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3402902000',
#       'impDlr': '8',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 세제',
#       'year': '2024.12'},
#      {'balPayments': '-490',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3403191000',
#       'impDlr': '490',
#       'impWgt': '26',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 절삭유',
#       'year': '2024.12'},
#      {'balPayments': '-4719',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3403199000',
#       'impDlr': '4719',
#       'impWgt': '200',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-26807',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3403991000',
#       'impDlr': '26807',
#       'impWgt': '491',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 절삭유',
#       'year': '2024.12'},
#      {'balPayments': '-1811',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3403992000',
#       'impDlr': '1811',
#       'impWgt': '29',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '신선용(伸線用) 조제 윤활제',
#       'year': '2024.12'},
#      {'balPayments': '-3147',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3403999000',
#       'impDlr': '3147',
#       'impWgt': '16',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-50196',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3404901090',
#       'impDlr': '50196',
#       'impWgt': '8140',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-16',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3404902000',
#       'impDlr': '16',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '조제 왁스',
#       'year': '2024.12'},
#      {'balPayments': '90',
#       'expDlr': '90',
#       'expWgt': '1',
#       'hsCd': '3405200000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '목제가구ㆍ마루나 그 밖의 목제품의 유지용 광택제ㆍ크림과 이와 유사한 조제품',
#       'year': '2024.12'},
#      {'balPayments': '798',
#       'expDlr': '798',
#       'expWgt': '28',
#       'hsCd': '3405300000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '차체(coachwork)용 광택제와 이와 유사한 조제품(금속용 광택제는 제외한다)',
#       'year': '2024.12'},
#      {'balPayments': '-72646',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3405901030',
#       'impDlr': '72646',
#       'impWgt': '969',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '다이아몬드 가루나 더스트를 기본 재료로 한 것',
#       'year': '2024.12'},
#      {'balPayments': '-29179',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3405901090',
#       'impDlr': '29179',
#       'impWgt': '530',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-37043',
#       'expDlr': '784',
#       'expWgt': '20',
#       'hsCd': '3405909000',
#       'impDlr': '37827',
#       'impWgt': '650',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-323',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3406000000',
#       'impDlr': '323',
#       'impWgt': '18',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '양초와 이와 유사한 물품',
#       'year': '2024.12'},
#      {'balPayments': '-370714',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3501109000',
#       'impDlr': '370714',
#       'impWgt': '32800',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-130221',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3502110000',
#       'impDlr': '130221',
#       'impWgt': '18000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '건조한 것',
#       'year': '2024.12'},
#      {'balPayments': '-959086',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3502200000',
#       'impDlr': '959086',
#       'impWgt': '52427',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '밀크알부민(둘 이상의 유장단백질의 농축물을 포함한다)',
#       'year': '2024.12'},
#      {'balPayments': '6998',
#       'expDlr': '6998',
#       'expWgt': '3',
#       'hsCd': '3503001010',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '젤라틴',
#       'year': '2024.12'},
#      {'balPayments': '-811329',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3504002030',
#       'impDlr': '811329',
#       'impWgt': '62440',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '분리단백질',
#       'year': '2024.12'},
#      {'balPayments': '-281580',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3504002090',
#       'impDlr': '281580',
#       'impWgt': '18540',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1868204',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3505105010',
#       'impDlr': '1868204',
#       'impWgt': '1500000',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '식품용',
#       'year': '2024.12'},
#      {'balPayments': '9535',
#       'expDlr': '9536',
#       'expWgt': '213',
#       'hsCd': '3506109000',
#       'impDlr': '1',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-135',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3506919000',
#       'impDlr': '135',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-4099',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '3507100000',
#       'impDlr': '4099',
#       'impWgt': '327',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
# ...
#      {'balPayments': '-2045',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8539100000',
#       'impDlr': '2045',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '실드빔 램프 유닛(sealed beam lamp unit)',
#       'year': '2024.12'},
#      {'balPayments': '-301',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8539399000',
#       'impDlr': '301',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8539410000',
#       'impDlr': '1',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '아크램프',
#       'year': '2024.12'},
#      {'balPayments': '-152',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8539491090',
#       'impDlr': '152',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '15975',
#       'expDlr': '15975',
#       'expWgt': '77',
#       'hsCd': '8539510000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '발광다이오드(엘이디) 모듈',
#       'year': '2024.12'},
#      {'balPayments': '-23716',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8539520000',
#       'impDlr': '23716',
#       'impWgt': '139',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '발광다이오드(엘이디) 램프',
#       'year': '2024.12'},
#      {'balPayments': '-719',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8541299000',
#       'impDlr': '719',
#       'impWgt': '23',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-197',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8541609000',
#       'impDlr': '197',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '1862',
#       'expDlr': '1862',
#       'expWgt': '1',
#       'hsCd': '8542311000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '모노리식(monolithic) 집적회로',
#       'year': '2024.12'},
#      {'balPayments': '81',
#       'expDlr': '81',
#       'expWgt': '1',
#       'hsCd': '8542313000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '복합구조칩 집적회로',
#       'year': '2024.12'},
#      {'balPayments': '-1676',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8542321090',
#       'impDlr': '1676',
#       'impWgt': '4',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '10299',
#       'expDlr': '10299',
#       'expWgt': '22',
#       'hsCd': '8542391000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '모노리식(monolithic) 집적회로',
#       'year': '2024.12'},
#      {'balPayments': '-585',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8542900000',
#       'impDlr': '585',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '부분품',
#       'year': '2024.12'},
#      {'balPayments': '58022',
#       'expDlr': '58022',
#       'expWgt': '275',
#       'hsCd': '8543702020',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '미용기기',
#       'year': '2024.12'},
#      {'balPayments': '-4335',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8543702040',
#       'impDlr': '4335',
#       'impWgt': '14',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '이퀄라이저',
#       'year': '2024.12'},
#      {'balPayments': '216',
#       'expDlr': '216',
#       'expWgt': '1',
#       'hsCd': '8543702090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-9858',
#       'expDlr': '4784',
#       'expWgt': '5',
#       'hsCd': '8543709090',
#       'impDlr': '14642',
#       'impWgt': '11',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '6386',
#       'expDlr': '8780',
#       'expWgt': '500',
#       'hsCd': '8543909000',
#       'impDlr': '2394',
#       'impWgt': '38',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-46',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544200000',
#       'impDlr': '46',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '동축케이블과 그 밖의 동축 도체',
#       'year': '2024.12'},
#      {'balPayments': '-3',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544300000',
#       'impDlr': '3',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '점화용 와이어링 세트와 그 밖의 와이어링 세트(자동차용ㆍ항공기용ㆍ선박용으로 한정한다)',
#       'year': '2024.12'},
#      {'balPayments': '-26',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544421090',
#       'impDlr': '26',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '3512',
#       'expDlr': '3585',
#       'expWgt': '32',
#       'hsCd': '8544422010',
#       'impDlr': '73',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '전기통신용',
#       'year': '2024.12'},
#      {'balPayments': '10808',
#       'expDlr': '17130',
#       'expWgt': '105',
#       'hsCd': '8544422090',
#       'impDlr': '6322',
#       'impWgt': '9',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-26808',
#       'expDlr': '25449',
#       'expWgt': '216',
#       'hsCd': '8544429090',
#       'impDlr': '52257',
#       'impWgt': '501',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '317',
#       'expDlr': '317',
#       'expWgt': '0',
#       'hsCd': '8544492011',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '전압이 80볼트 이하인 것',
#       'year': '2024.12'},
#      {'balPayments': '-361',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544492090',
#       'impDlr': '361',
#       'impWgt': '4',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1699',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544499011',
#       'impDlr': '1699',
#       'impWgt': '3',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '전압이 80볼트 이하인 것',
#       'year': '2024.12'},
#      {'balPayments': '-3442',
#       'expDlr': '1348',
#       'expWgt': '44',
#       'hsCd': '8544499090',
#       'impDlr': '4790',
#       'impWgt': '52',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-1808',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8544601010',
#       'impDlr': '1808',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '플라스틱 절연전선',
#       'year': '2024.12'},
#      {'balPayments': '-2356',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8545190000',
#       'impDlr': '2356',
#       'impWgt': '10',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '95',
#       'expDlr': '95',
#       'expWgt': '1',
#       'hsCd': '8545901000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '탄소봉',
#       'year': '2024.12'},
#      {'balPayments': '1750',
#       'expDlr': '1750',
#       'expWgt': '240',
#       'hsCd': '8545909000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-12617',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8547200000',
#       'impDlr': '12617',
#       'impWgt': '162',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '플라스틱으로 만든 절연용 물품',
#       'year': '2024.12'},
#      {'balPayments': '-6979',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8548009000',
#       'impDlr': '6979',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '28106',
#       'expDlr': '28106',
#       'expWgt': '2721',
#       'hsCd': '8703217000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '신차',
#       'year': '2024.12'},
#      {'balPayments': '19813799',
#       'expDlr': '19813799',
#       'expWgt': '1311290',
#       'hsCd': '8703801000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '신차',
#       'year': '2024.12'},
#      {'balPayments': '-421516',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8705909090',
#       'impDlr': '421516',
#       'impWgt': '10800',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-6355',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8708290000',
#       'impDlr': '6355',
#       'impWgt': '76',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '7557',
#       'expDlr': '7557',
#       'expWgt': '299',
#       'hsCd': '8708309000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-384',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8708400000',
#       'impDlr': '384',
#       'impWgt': '8',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기어박스와 그 부분품',
#       'year': '2024.12'},
#      {'balPayments': '-849',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8708930000',
#       'impDlr': '849',
#       'impWgt': '56',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '클러치와 그 부분품',
#       'year': '2024.12'},
#      {'balPayments': '-582',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8708940000',
#       'impDlr': '582',
#       'impWgt': '3',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '운전대ㆍ스티어링칼럼(steering column)ㆍ운전박스와 그 부분품',
#       'year': '2024.12'},
#      {'balPayments': '-6711',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8708999000',
#       'impDlr': '6711',
#       'impWgt': '55',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '468',
#       'expDlr': '468',
#       'expWgt': '14',
#       'hsCd': '8712009090',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-626',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8714109000',
#       'impDlr': '626',
#       'impWgt': '3',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-445',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8714200000',
#       'impDlr': '445',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '신체장애인용 차량의 것',
#       'year': '2024.12'},
#      {'balPayments': '-8859',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8714990000',
#       'impDlr': '8859',
#       'impWgt': '14',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-7895',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8716801000',
#       'impDlr': '7895',
#       'impWgt': '293',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '손수레',
#       'year': '2024.12'},
#      {'balPayments': '-1',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8716809000',
#       'impDlr': '1',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-207',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8716909000',
#       'impDlr': '207',
#       'impWgt': '23',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-324387',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8807902000',
#       'impDlr': '324387',
#       'impWgt': '44',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '우주선(인공위성을 포함한다)의 것',
#       'year': '2024.12'},
#      {'balPayments': '187550000',
#       'expDlr': '187550000',
#       'expWgt': '47688000',
#       'hsCd': '8901901000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '화물선',
#       'year': '2024.12'},
#      {'balPayments': '-30822',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '8907909000',
#       'impDlr': '30822',
#       'impWgt': '405',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-341244',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '9001100000',
#       'impDlr': '341244',
#       'impWgt': '626',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '광섬유ㆍ광섬유 다발과 광섬유 케이블',
#       'year': '2024.12'},
#      {'balPayments': '168',
#       'expDlr': '168',
#       'expWgt': '2',
#       'hsCd': '9001300000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '콘택트렌즈',
#       'year': '2024.12'},
#      {'balPayments': '-150',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '9001501000',
#       'impDlr': '150',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '시력 교정용',
#       'year': '2024.12'},
#      {'balPayments': '-2500',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '9001909000',
#       'impDlr': '2500',
#       'impWgt': '1',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '335',
#       'expDlr': '335',
#       'expWgt': '1',
#       'hsCd': '9002111000',
#       'impDlr': '0',
#       'impWgt': '0',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '사진기용',
#       'year': '2024.12'},
#      {'balPayments': '-169',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '9002209000',
#       'impDlr': '169',
#       'impWgt': '2',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-25694',
#       'expDlr': '0',
#       'expWgt': '0',
#       'hsCd': '9003110000',
#       'impDlr': '25694',
#       'impWgt': '31',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '플라스틱으로 만든 것',
#       'year': '2024.12'},
#      {'balPayments': '-420552',
#       'expDlr': '27979',
#       'expWgt': '39',
#       'hsCd': '9003199000',
#       'impDlr': '448531',
#       'impWgt': '577',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      {'balPayments': '-18336',
#       'expDlr': '23298',
#       'expWgt': '29',
#       'hsCd': '9003900000',
#       'impDlr': '41634',
#       'impWgt': '173',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '부분품',
#       'year': '2024.12'},
#      {'balPayments': '-70837',
#       'expDlr': '1745',
#       'expWgt': '4',
#       'hsCd': '9004109000',
#       'impDlr': '72582',
#       'impWgt': '97',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'statKor': '기타',
#       'year': '2024.12'},
#      ...]}}}}

# %%
import pandas as pd

pd.set_option('display.max_rows', 10)
dataset = pd.DataFrame(data["response"]["body"]["items"]["item"])
dataset
# Out:
#      balPayments     expDlr    expWgt        hsCd     impDlr    impWgt statCd  \
# 0      120202932  230391081  55349825           -  110188149  10979602      -
# 1        -279735          0         0  0202201000     279735     57150     DK
# 2        -464781          0         0  0202300000     464781     77372     DK
# 3        -390272          0         0  0203291000     390272     87768     DK
# 4        -766500          0         0  0203299000     766500    439891     DK
# ...          ...        ...       ...         ...        ...       ...    ...
# 1176        1539       1893        18  9620000000        354         1     DK
# 1177         -31          0         0  9701990000         31         1     DK
# 1178       22083      22083        90  9702903000          0         0     DK
# 1179     -609836        546        50  9703901000     610382      1400     DK
# 1180       -1019          0         0  9706901000       1019         0     DK
#
#      statCdCntnKor1                 statKor     year
# 0                 -                       -       총계
# 1               덴마크                      갈비  2024.12
# 2               덴마크                  뼈 없는 것  2024.12
# 3               덴마크                     삼겹살  2024.12
# 4               덴마크                      기타  2024.12
# ...             ...                     ...      ...
# 1176            덴마크  일각대ㆍ양각대ㆍ삼각대와 이와 유사한 물품  2024.12
# 1177            덴마크                      기타  2024.12
# 1178            덴마크                     석판화  2024.12
# 1179            덴마크                      조각  2024.12
# 1180            덴마크                    도자기류  2024.12
#
# [1181 rows x 10 columns]

# %% [markdown]
# ## 무역 데이터 API 응답 필드
#
# | 필드       | 설명                        | 예시                  | 상세 설명       |
# |-------------|---------------------------|----------------------|-------------|
# | year       | 연도                        | 2016.01             | 기간 정보       |
# | statCdCntnKor1 | 국가명                      | 미국                 | 국가명 정보      |
# | statCd     | 국가코드                    | US                   | ISO 국가 코드   |
# | statKor    | 품목명                      | 쇠고기(냉동한 것으로 한정) | 품목명 정보      |
# | hsCd       | HS코드                      | 0202                 | 국제 무역 품목 코드 |
# | expWgt     | 수출중량 (kg)               | 18,003               | 수출된 상품의 중량  |
# | expDlr     | 수출금액 (달러)             | 150,822              | 수출된 상품의 금액  |
# | impWgt     | 수입중량 (kg)               | 14,809,834           | 수입된 상품의 중량  |
# | impDlr     | 수입금액 (달러)             | 93,754,113           | 수입된 상품의 금액  |
# | balPayments | 무역수지 (달러)             | -93,603,291          | 수출금액 - 수입금액 |
